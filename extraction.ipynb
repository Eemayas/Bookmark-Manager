# %%
# %pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\local\programs\python\python311\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\local\programs\python\python311\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\local\programs\python\python311\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\local\programs\python\python311\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\prash\appdata\local\programs\python\python311\lib\site-packages)

# %%
from bs4 import BeautifulSoup
import json

def parse_bookmarks(html_file):
    try:
        with open(html_file, 'r', encoding='utf-8') as file:
            html_content = file.read()
    except FileNotFoundError:
        print(f"File {html_file} not found.")
        return []

    soup = BeautifulSoup(html_content, 'html.parser')

    def process_dl(dl_tag, current_path):
        bookmarks = []
        current_folder = None
        
        all_tags = dl_tag.find_all(['dt', 'dl'], recursive=False)
        
        if len(all_tags) == 0:
            all_tags = dl_tag.find_all(['dt', 'dl'])
        
        for tag in all_tags:
            if tag.name == 'dt':
                h3_tag = tag.find('h3')
                a_tag = tag.find('a')
                if h3_tag:  
                    current_folder = h3_tag.text
                    nested_dl = tag.find_next_sibling('dl')
                    if nested_dl:
                        new_path = current_path + [current_folder]
                        bookmarks.extend(process_dl(nested_dl, new_path))
                elif a_tag:  
                    link = a_tag.get('href')
                    name = a_tag.text
                    path = " / ".join(current_path)
                    bookmarks.append({
                        'name': name,
                        'link': link,
                        'path': path
                    })
            elif tag.name == 'dl' and current_folder:  
                new_path = current_path + [current_folder]
                bookmarks.extend(process_dl(tag, new_path))
        
        return bookmarks

    dl_tag = soup.find('dl')
    if dl_tag is None:
        print("No bookmarks found in the HTML file.")
        return []
    
    bookmarks = process_dl(dl_tag, [])
    
    return bookmarks

html_file = 'bookmarks_10_13_24.html'
parsed_bookmarks = parse_bookmarks(html_file)

if parsed_bookmarks:
    print(f"Number of parsed bookmarks: {len(parsed_bookmarks)}")
    # remove the duplicate in paresed bookmarks
    bookmark_set = set()
    bookmark_list = []

    for i, bookmark in enumerate(parsed_bookmarks):
        if bookmark['link'] not in bookmark_set:
            bookmark_set.add(bookmark['link'])
            bookmark_list.append({
                "id": len(bookmark_list) + 1,
                "name": bookmark['name'],
                "url": bookmark['link'],
                "description": "No description",
                "tags": ["bookmarks"],
                "categories": bookmark['path']
            })
    output_file = 'constants/bookmarks.json'
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(bookmark_list, f, ensure_ascii=False, indent=2)
    print(f"Bookmarks saved to {output_file}")
    print(f"Number of bookmarks: {len(bookmark_list)}")
# Out:
# Number of parsed bookmarks: 1144
# Bookmarks saved to constants/bookmarks.json
# Number of bookmarks: 153
# First 5 bookmarks:
# {'id': 1, 'name': 'Planets-Flutter: creating a Planet card', 'url': 'https://sergiandreplace.com/planets-flutter-creating-a-planet-card/', 'description': 'No description', 'tags': ['bookmarks'], 'categories': 'Bookmarks bar / website / flutter / card design'}
# {'id': 2, 'name': 'Minimal UI Design in Flutter - Best Flutter apps', 'url': 'http://bestflutterapps.com/minimal-ui-design-in-flutter', 'description': 'No description', 'tags': ['bookmarks'], 'categories': 'Bookmarks bar / website / flutter / card design'}
# {'id': 3, 'name': 'Rive - Build interactive animations that run anywhere', 'url': 'https://rive.app/', 'description': 'No description', 'tags': ['bookmarks'], 'categories': 'Bookmarks bar / website / flutter / animation'}
# ...

# %%
for bookmark in bookmark_list:
    print(bookmark)
# Out:
# {'name': 'Planets-Flutter: creating a Planet card', 'link': 'https://sergiandreplace.com/planets-flutter-creating-a-planet-card/', 'path': 'Bookmarks bar / website / flutter / card design'}
# {'name': 'Minimal UI Design in Flutter - Best Flutter apps', 'link': 'http://bestflutterapps.com/minimal-ui-design-in-flutter', 'path': 'Bookmarks bar / website / flutter / card design'}
# {'name': 'Planets-Flutter: creating a Planet card', 'link': 'https://sergiandreplace.com/planets-flutter-creating-a-planet-card/', 'path': 'Bookmarks bar / website / flutter'}
# {'name': 'Minimal UI Design in Flutter - Best Flutter apps', 'link': 'http://bestflutterapps.com/minimal-ui-design-in-flutter', 'path': 'Bookmarks bar / website / flutter'}
# {'name': 'Rive - Build interactive animations that run anywhere', 'link': 'https://rive.app/', 'path': 'Bookmarks bar / website / flutter / animation'}
# ...

# %%
from bs4 import BeautifulSoup
import json

stock_photos_html_content=''' 
<ul class="rs-list svelte-4h59nz"> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://elements.envato.com//&amp;size=32" alt="Envato" class="svelte-zslw0j"></span> </div> <a href="https://elements.envato.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Envato 
Envato Elements: Unlimited Stock Videos, Music, Photos &amp; Graphics" style="">Envato</h3> <p class="description svelte-zslw0j">Envato Elements: Unlimited Stock Videos, Music, Photos &amp; Graphics</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://elements.envato.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li><li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://shutterstock.com/&amp;size=32" alt="Shutterstock" class="svelte-zslw0j"></span> </div> <a href="https://www.shutterstock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="" style="">Shutterstock</h3> <p class="description svelte-zslw0j"></p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.shutterstock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li>   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pixabay.com&amp;size=32" alt="Pixabay" class="svelte-zslw0j"></span> </div> <a href="https://pixabay.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pixabay 
Pixabay is a vibrant community of creatives, sharing copyright free images, videos and music." style="">Pixabay</h3> <p class="description svelte-zslw0j">Pixabay is a vibrant community of creatives, sharing copyright free images, videos and music.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pixabay.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://freerangestock.com/&amp;size=32" alt="Free Range" class="svelte-zslw0j"></span> </div> <a href="https://freerangestock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Free Range 
Free Stock Photos, totally Free Commercial Photography and Textures." style="">Free Range</h3> <p class="description svelte-zslw0j">Free Stock Photos, totally Free Commercial Photography and Textures.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://freerangestock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://littlevisuals.co/&amp;size=32" alt="Little Visuals" class="svelte-zslw0j"></span> </div> <a href="https://littlevisuals.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Little Visuals 
Hi-res images, use them anyway you want." style="">Little Visuals</h3> <p class="description svelte-zslw0j">Hi-res images, use them anyway you want.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://littlevisuals.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://nos.twnsnd.co/&amp;size=32" alt="New Old Stock" class="svelte-zslw0j"></span> </div> <a href="https://nos.twnsnd.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="New Old Stock 
A vintage photos from the public archives free of known copyright restrictions." style="">New Old Stock</h3> <p class="description svelte-zslw0j">A vintage photos from the public archives free of known copyright restrictions.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://nos.twnsnd.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://visualhunt.com/&amp;size=32" alt="Visual Hunt" class="svelte-zslw0j"></span> </div> <a href="https://visualhunt.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Visual Hunt 
CC0 - 100% Free High Quality Photos." style="">Visual Hunt</h3> <p class="description svelte-zslw0j">CC0 - 100% Free High Quality Photos.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://visualhunt.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://startupstockphotos.com/&amp;size=32" alt="Startup Stock" class="svelte-zslw0j"></span> </div> <a href="https://startupstockphotos.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Startup Stock 
Free photos for startups, bloggers and publishers. " style="">Startup Stock</h3> <p class="description svelte-zslw0j">Free photos for startups, bloggers and publishers. </p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://startupstockphotos.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gratisography.com/&amp;size=32" alt="Gratisography" class="svelte-zslw0j"></span> </div> <a href="https://gratisography.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gratisography 
The world's quirkiest collection of free high-resolution pictures you can use on your personal and commercial projects." style="">Gratisography</h3> <p class="description svelte-zslw0j">The world's quirkiest collection of free high-resolution pictures you can use on your personal and commercial projects.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gratisography.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pexels.com/&amp;size=32" alt="Pexels" class="svelte-zslw0j"></span> </div> <a href="https://pexels.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pexels 
The best free stock photos &amp; videos shared by talented creators." style="">Pexels</h3> <p class="description svelte-zslw0j">The best free stock photos &amp; videos shared by talented creators.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pexels.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://jaymantri.com/&amp;size=32" alt="Jay Mantri" class="svelte-zslw0j"></span> </div> <a href="https://jaymantri.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Jay Mantri 
7 new photos released every Thursday under the Creative Commons CC0." style="">Jay Mantri</h3> <p class="description svelte-zslw0j">7 new photos released every Thursday under the Creative Commons CC0.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://jaymantri.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://magdeleine.co/browse/&amp;size=32" alt="Magdeline" class="svelte-zslw0j"></span> </div> <a href="https://magdeleine.co/browse/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Magdeline 
Free high-quality stock photos for your inspiration." style="">Magdeline</h3> <p class="description svelte-zslw0j">Free high-quality stock photos for your inspiration.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://magdeleine.co/browse/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://travelcoffeebook.tumblr.com/&amp;size=32" alt="Travel Coffee" class="svelte-zslw0j"></span> </div> <a href="https://travelcoffeebook.tumblr.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Travel Coffee 
Sharing beautiful travel moments. All photos are listed under cc0. That means you can do whatever you want with them." style="">Travel Coffee</h3> <p class="description svelte-zslw0j">Sharing beautiful travel moments. All photos are listed under cc0. That means you can do whatever you want with them.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://travelcoffeebook.tumblr.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://moveast.me/&amp;size=32" alt="Moveast" class="svelte-zslw0j"></span> </div> <a href="https://moveast.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Moveast 
This is a journey of a Portuguese guy moving that decided that every photo should be used for free. Help yourselves and use them wherever you want (CC0)" style="">Moveast</h3> <p class="description svelte-zslw0j">This is a journey of a Portuguese guy moving that decided that every photo should be used for free. Help yourselves and use them wherever you want (CC0)</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://moveast.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://barnimages.com/&amp;size=32" alt="Barn Images" class="svelte-zslw0j"></span> </div> <a href="https://barnimages.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Barn Images 
Free high-resolution images: beautiful and different, with nothing that duplicates stock photos you'll generally find elsewhere." style="">Barn Images</h3> <p class="description svelte-zslw0j">Free high-resolution images: beautiful and different, with nothing that duplicates stock photos you'll generally find elsewhere.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://barnimages.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://shotstash.com/&amp;size=32" alt="Shot Stash" class="svelte-zslw0j"></span> </div> <a href="https://shotstash.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Shot Stash 
Totally free stock photos for creative professionals. No attribution required. Free for use in your commercial or personal projects. CC0 License." style="">Shot Stash</h3> <p class="description svelte-zslw0j">Totally free stock photos for creative professionals. No attribution required. Free for use in your commercial or personal projects. CC0 License.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://shotstash.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://stocksnap.io/&amp;size=32" alt="Stocksnap" class="svelte-zslw0j"></span> </div> <a href="https://stocksnap.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stocksnap 
High quality and high resolution stock images free from all copyright restrictions – no attribution required." style="">Stocksnap</h3> <p class="description svelte-zslw0j">High quality and high resolution stock images free from all copyright restrictions – no attribution required.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://stocksnap.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://burst.shopify.com/&amp;size=32" alt="Burst" class="svelte-zslw0j"></span> </div> <a href="https://burst.shopify.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Burst 
Browse thousands of beautiful copyright-free images. All their pictures are free to download for personal and commercial use, no attribution required." style="">Burst</h3> <p class="description svelte-zslw0j">Browse thousands of beautiful copyright-free images. All their pictures are free to download for personal and commercial use, no attribution required.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://burst.shopify.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.foodiesfeed.com/&amp;size=32" alt="FoodiesFeed" class="svelte-zslw0j"></span> </div> <a href="https://www.foodiesfeed.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FoodiesFeed 
Download 2000+ food pictures. The best free food photos for commercial use." style="">FoodiesFeed</h3> <p class="description svelte-zslw0j">Download 2000+ food pictures. The best free food photos for commercial use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.foodiesfeed.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://picjumbo.com/&amp;size=32" alt="Picjumbo" class="svelte-zslw0j"></span> </div> <a href="https://picjumbo.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Picjumbo 
Free stock photos and images for your projects and websites.️ Beautiful 100% free high-resolution stock images with no watermark" style="">Picjumbo</h3> <p class="description svelte-zslw0j">Free stock photos and images for your projects and websites.️ Beautiful 100% free high-resolution stock images with no watermark</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://picjumbo.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.reshot.com/&amp;size=32" alt="Reshot" class="svelte-zslw0j"></span> </div> <a href="https://www.reshot.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Reshot 
Find tons of handpicked, non-stocky images. Yours to use as you wish. Free for commercial use. No attribution required." style="">Reshot</h3> <p class="description svelte-zslw0j">Find tons of handpicked, non-stocky images. Yours to use as you wish. Free for commercial use. No attribution required.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.reshot.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://generated.photos/&amp;size=32" alt="Generated Photos" class="svelte-zslw0j"></span> </div> <a href="https://generated.photos/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Generated Photos 
Generated photos are created from scratch by AI systems." style="">Generated Photos</h3> <p class="description svelte-zslw0j">Generated photos are created from scratch by AI systems.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://generated.photos/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://userstock.io/&amp;size=32" alt="User Stock" class="svelte-zslw0j"></span> </div> <a href="https://userstock.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="User Stock 
Free photos of people's faces to use as avatars." style="">User Stock</h3> <p class="description svelte-zslw0j">Free photos of people's faces to use as avatars.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://userstock.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://freephotos.cc/en&amp;size=32" alt="Free Photos" class="svelte-zslw0j"></span> </div> <a href="https://freephotos.cc/en" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Free Photos 
Free resource where you can find creative commons photos." style="">Free Photos</h3> <p class="description svelte-zslw0j">Free resource where you can find creative commons photos.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://freephotos.cc/en" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://startupstockphotos.com/&amp;size=32" alt="Startup Stock Photos" class="svelte-zslw0j"></span> </div> <a href="https://startupstockphotos.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Startup Stock Photos 
Free startup, office, and tech stock photos." style="">Startup Stock Photos</h3> <p class="description svelte-zslw0j">Free startup, office, and tech stock photos.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://startupstockphotos.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://stockup.sitebuilderreport.com/&amp;size=32" alt="Stock Up" class="svelte-zslw0j"></span> </div> <a href="https://stockup.sitebuilderreport.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stock Up 
Searching 25,000+ free stock photos." style="">Stock Up</h3> <p class="description svelte-zslw0j">Searching 25,000+ free stock photos.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://stockup.sitebuilderreport.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://librestock.com/&amp;size=32" alt="Libre Stock" class="svelte-zslw0j"></span> </div> <a href="https://librestock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Libre Stock 
We scan and index the best free photos from the top stock sites. All photos are free for personal and commercial. No attribution required. CC0." style="">Libre Stock</h3> <p class="description svelte-zslw0j">We scan and index the best free photos from the top stock sites. All photos are free for personal and commercial. No attribution required. CC0.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://librestock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://nappy.co/&amp;size=32" alt="Nappy" class="svelte-zslw0j"></span> </div> <a href="https://nappy.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Nappy 
Beautiful photos of Black and Brown people, for free. For commercial and personal use." style="">Nappy</h3> <p class="description svelte-zslw0j">Beautiful photos of Black and Brown people, for free. For commercial and personal use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://nappy.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thenounproject.com/photos/&amp;size=32" alt="Noun Project Photos" class="svelte-zslw0j"></span> </div> <a href="https://thenounproject.com/photos/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Noun Project Photos 
Noun Project is building the best and most useful collection of stock photos. Browse a variety of royalty-free images representing a more inclusive world." style="">Noun Project Photos</h3> <p class="description svelte-zslw0j">Noun Project is building the best and most useful collection of stock photos. Browse a variety of royalty-free images representing a more inclusive world.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thenounproject.com/photos/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://focastock.com/&amp;size=32" alt="FOCA Stock" class="svelte-zslw0j"></span> </div> <a href="https://focastock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FOCA Stock 
Use them in your website, themes, templates, projects, print materials, social posts, and more. CC0 license." style="">FOCA Stock</h3> <p class="description svelte-zslw0j">Use them in your website, themes, templates, projects, print materials, social posts, and more. CC0 license.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://focastock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.freepik.com/&amp;size=32" alt="Freepik" class="svelte-zslw0j"></span> </div> <a href="https://www.freepik.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Freepik 
Millions of Free Graphic Resources. ✓ Vectors ✓ Stock Photos ✓ PSD ✓ Icons ✓ All that you need for your Creative Projects." style="">Freepik</h3> <p class="description svelte-zslw0j">Millions of Free Graphic Resources. ✓ Vectors ✓ Stock Photos ✓ PSD ✓ Icons ✓ All that you need for your Creative Projects.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.freepik.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


stock_video_html_content=''' 
<ul class="rs-list svelte-4h59nz"> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://elements.envato.com//&amp;size=32" alt="Envato" class="svelte-zslw0j"></span> </div> <a href="https://elements.envato.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Envato 
Envato Elements: Unlimited Stock Videos, Music, Photos &amp; Graphics" style="">Envato</h3> <p class="description svelte-zslw0j">Envato Elements: Unlimited Stock Videos, Music, Photos &amp; Graphics</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://elements.envato.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li><li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://shutterstock.com/&amp;size=32" alt="Shutterstock" class="svelte-zslw0j"></span> </div> <a href="https://www.shutterstock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Shutterstock 
A global marketplace for images, videos and music. Sharing photos, inspiration, design tips &amp; videos for the creative community." style="">Shutterstock</h3> <p class="description svelte-zslw0j">A global marketplace for images, videos and music. Sharing photos, inspiration, design tips &amp; videos for the creative community.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.shutterstock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li>   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pixabay.com/en/videos/&amp;size=32" alt="Pixabay" class="svelte-zslw0j"></span> </div> <a href="https://pixabay.com/en/videos/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pixabay 
Sharing photos, illustrations, vector graphics, and film footage under a proprietary license." style="">Pixabay</h3> <p class="description svelte-zslw0j">Sharing photos, illustrations, vector graphics, and film footage under a proprietary license.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pixabay.com/en/videos/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mazwai.com/#/&amp;size=32" alt="Mazwai" class="svelte-zslw0j"></span> </div> <a href="https://mazwai.com/#/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mazwai 
Free stock video footage with clips available in HD." style="">Mazwai</h3> <p class="description svelte-zslw0j">Free stock video footage with clips available in HD.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mazwai.com/#/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.videezy.com/&amp;size=32" alt="Videezy" class="svelte-zslw0j"></span> </div> <a href="https://www.videezy.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Videezy 
Videezy is a community of Videographers who download and share free HD stock video!" style="">Videezy</h3> <p class="description svelte-zslw0j">Videezy is a community of Videographers who download and share free HD stock video!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.videezy.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.videvo.net/free-stock-footage/&amp;size=32" alt="Videovo" class="svelte-zslw0j"></span> </div> <a href="https://www.videvo.net/free-stock-footage/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Videovo 
Download free  stock video footage and B-Roll with 4k and HD clips available. Click here to download royalty-free licensing videos from Videvo today." style="">Videovo</h3> <p class="description svelte-zslw0j">Download free  stock video footage and B-Roll with 4k and HD clips available. Click here to download royalty-free licensing videos from Videvo today.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.videvo.net/free-stock-footage/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.lifeofvids.com/&amp;size=32" alt="Life of Vids" class="svelte-zslw0j"></span> </div> <a href="https://www.lifeofvids.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Life of Vids 
Free videos for personal &amp; commercial uses. New videos added weekly! High-resolution videos for free for you on our Vimeo. For Designers, Web Creatives &amp; more" style="">Life of Vids</h3> <p class="description svelte-zslw0j">Free videos for personal &amp; commercial uses. New videos added weekly! High-resolution videos for free for you on our Vimeo. For Designers, Web Creatives &amp; more</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.lifeofvids.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.xstockvideo.com/&amp;size=32" alt="xStockVideo" class="svelte-zslw0j"></span> </div> <a href="https://www.xstockvideo.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="xStockVideo 
Download Free Quality HD stock footage and stock video. Hundreds of free stock footage clips." style="">xStockVideo</h3> <p class="description svelte-zslw0j">Download Free Quality HD stock footage and stock video. Hundreds of free stock footage clips.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.xstockvideo.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pond5.com/stock-video-footage/?free=1&amp;size=32" alt="Pond5" class="svelte-zslw0j"></span> </div> <a href="https://www.pond5.com/stock-video-footage/?free=1" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pond5 
Access millions of royalty-free videos in the world's largest stock footage library. Download high quality 4K and HD clips." style="">Pond5</h3> <p class="description svelte-zslw0j">Access millions of royalty-free videos in the world's largest stock footage library. Download high quality 4K and HD clips.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pond5.com/stock-video-footage/?free=1" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://videos.pexels.com/&amp;size=32" alt="Pexels" class="svelte-zslw0j"></span> </div> <a href="https://videos.pexels.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pexels 
Pexels Videos makes it easy to find free stock footage for your website, promo video or anything else. All videos are free for personal and commercial use." style="">Pexels</h3> <p class="description svelte-zslw0j">Pexels Videos makes it easy to find free stock footage for your website, promo video or anything else. All videos are free for personal and commercial use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://videos.pexels.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.coverr.co/&amp;size=32" alt="Coverr" class="svelte-zslw0j"></span> </div> <a href="https://www.coverr.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Coverr 
Coverr video is a completely free stock footage website that allows you to download and use high-quality stock videos anywhere." style="">Coverr</h3> <p class="description svelte-zslw0j">Coverr video is a completely free stock footage website that allows you to download and use high-quality stock videos anywhere.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.coverr.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.vidsplay.com/&amp;size=32" alt="Vidsplay" class="svelte-zslw0j"></span> </div> <a href="https://www.vidsplay.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Vidsplay 
Download Free stock video footage in high definition (HD). Completely free, no cost video footage." style="">Vidsplay</h3> <p class="description svelte-zslw0j">Download Free stock video footage in high definition (HD). Completely free, no cost video footage.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.vidsplay.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.motionelements.com/free/stock-footage&amp;size=32" alt="Motion Elements" class="svelte-zslw0j"></span> </div> <a href="https://www.motionelements.com/free/stock-footage" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Motion Elements 
Download 4000+ free stock footage from our AI-driven marketplace with 3,000,000+ royalty-free stock videos, templates &amp;  music." style="">Motion Elements</h3> <p class="description svelte-zslw0j">Download 4000+ free stock footage from our AI-driven marketplace with 3,000,000+ royalty-free stock videos, templates &amp;  music.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.motionelements.com/free/stock-footage" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.motionplaces.com/&amp;size=32" alt="Motion Places" class="svelte-zslw0j"></span> </div> <a href="https://www.motionplaces.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Motion Places 
Motion Places offers a curated collection of beautiful footage you can use for your projects." style="">Motion Places</h3> <p class="description svelte-zslw0j">Motion Places offers a curated collection of beautiful footage you can use for your projects.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.motionplaces.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.clipcanvas.com/free-footage/&amp;size=32" alt="Clip Canvas" class="svelte-zslw0j"></span> </div> <a href="https://www.clipcanvas.com/free-footage/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Clip Canvas 
Download some of this free stock footage to to use in your creative work. Great for filmmakers, videographers and producers alike." style="">Clip Canvas</h3> <p class="description svelte-zslw0j">Download some of this free stock footage to to use in your creative work. Great for filmmakers, videographers and producers alike.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.clipcanvas.com/free-footage/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://vimeo.com/groups/freehd/&amp;size=32" alt="Vimeo Free" class="svelte-zslw0j"></span> </div> <a href="https://vimeo.com/groups/freehd/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Vimeo Free 
All clips you find in this group is given away for free use in your productions." style="">Vimeo Free</h3> <p class="description svelte-zslw0j">All clips you find in this group is given away for free use in your productions.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://vimeo.com/groups/freehd/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.wedistill.io/&amp;size=32" alt="Distill" class="svelte-zslw0j"></span> </div> <a href="https://www.wedistill.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Distill 
Curated HD stock video footage free for your personal and commercial use. 10 new videos every 10 days. Videos are licensed under the Creative Commons Zero license." style="">Distill</h3> <p class="description svelte-zslw0j">Curated HD stock video footage free for your personal and commercial use. 10 new videos every 10 days. Videos are licensed under the Creative Commons Zero license.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.wedistill.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.123rf.com/&amp;size=32" alt="123rf" class="svelte-zslw0j"></span> </div> <a href="https://www.123rf.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="123rf 
Search and download from millions of HD stock photos, royalty free images, cliparts, vectors and illustrations." style="">123rf</h3> <p class="description svelte-zslw0j">Search and download from millions of HD stock photos, royalty free images, cliparts, vectors and illustrations.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.123rf.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mixkit.co/&amp;size=32" alt="Mixkit" class="svelte-zslw0j"></span> </div> <a href="https://mixkit.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mixkit 
Free assets for your next video project." style="">Mixkit</h3> <p class="description svelte-zslw0j">Free assets for your next video project.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mixkit.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


icons_html_content = ''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.streamlinehq.com//&amp;size=32" alt="Streamline Icons" class="svelte-zslw0j"></span> </div> <a href="https://home.streamlinehq.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Streamline Icons 
Streamline 3.0 is out! 30,000 icons in three unique weights. 53 categories. 720 subcategories. The world's largest icon library." style="">Streamline Icons</h3> <p class="description svelte-zslw0j">Streamline 3.0 is out! 30,000 icons in three unique weights. 53 categories. 720 subcategories. The world's largest icon library.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://home.streamlinehq.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thesquid.ink/flat-icons//&amp;size=32" alt="Squidink Icons" class="svelte-zslw0j"></span> </div> <a href="https://thesquid.ink/flat-icons/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Squidink Icons 
2,000+ Handcrafted Flat Icons, Line Icons, Glyph Icons. Easy to customize and scalable. Designed for applications, iOS and Android. Include Photoshop, Illustrator and SVG files." style="">Squidink Icons</h3> <p class="description svelte-zslw0j">2,000+ Handcrafted Flat Icons, Line Icons, Glyph Icons. Easy to customize and scalable. Designed for applications, iOS and Android. Include Photoshop, Illustrator and SVG files.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thesquid.ink/flat-icons/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://materialdesignicons.com/&amp;size=32" alt="Material Design Icons" class="svelte-zslw0j"></span> </div> <a href="https://materialdesignicons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Material Design Icons 
Material Design Icons' growing icon collection allows designers and developers targeting various platforms to download icons in the format, color and size they need for any project." style="">Material Design Icons</h3> <p class="description svelte-zslw0j">Material Design Icons' growing icon collection allows designers and developers targeting various platforms to download icons in the format, color and size they need for any project.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://materialdesignicons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://evil-icons.io/&amp;size=32" alt="Evil Icons" class="svelte-zslw0j"></span> </div> <a href="https://evil-icons.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Evil Icons 
Simple and clean SVG icon pack with the code to support Rails, Sprockets, Node.js, Gulp, Grunt and CDN." style="">Evil Icons</h3> <p class="description svelte-zslw0j">Simple and clean SVG icon pack with the code to support Rails, Sprockets, Node.js, Gulp, Grunt and CDN.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://evil-icons.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://simpleicons.org/&amp;size=32" alt="Simple Icons" class="svelte-zslw0j"></span> </div> <a href="https://simpleicons.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Simple Icons 
Free SVG icons for popular brands." style="">Simple Icons</h3> <p class="description svelte-zslw0j">Free SVG icons for popular brands.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://simpleicons.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontawesome.com/&amp;size=32" alt="Font Awesome" class="svelte-zslw0j"></span> </div> <a href="https://fontawesome.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Awesome 
Font Awesome is the Internet's icon library and toolkit, used by millions of designers, developers, and content creators." style="">Font Awesome</h3> <p class="description svelte-zslw0j">Font Awesome is the Internet's icon library and toolkit, used by millions of designers, developers, and content creators.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontawesome.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://leungwensen.github.io/svg-icon/&amp;size=32" alt="Svg Icon" class="svelte-zslw0j"></span> </div> <a href="https://leungwensen.github.io/svg-icon/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Svg Icon 
An ultimate SVG icons collection done right." style="">Svg Icon</h3> <p class="description svelte-zslw0j">An ultimate SVG icons collection done right.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://leungwensen.github.io/svg-icon/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconscout.com/unicons&amp;size=32" alt="Unicons" class="svelte-zslw0j"></span> </div> <a href="https://iconscout.com/unicons" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Unicons 
Pixel-perfect vector icons and Icon Font for your next project." style="">Unicons</h3> <p class="description svelte-zslw0j">Pixel-perfect vector icons and Icon Font for your next project.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconscout.com/unicons" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://saeedalipoor.github.io/icono/&amp;size=32" alt="Icono" class="svelte-zslw0j"></span> </div> <a href="https://saeedalipoor.github.io/icono/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icono 
Icono is an icon pack that needs no external resources. Every tag can be an icon made with pure CSS." style="">Icono</h3> <p class="description svelte-zslw0j">Icono is an icon pack that needs no external resources. Every tag can be an icon made with pure CSS.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://saeedalipoor.github.io/icono/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fonts.google.com/icons&amp;size=32" alt="Google Material Icons" class="svelte-zslw0j"></span> </div> <a href="https://fonts.google.com/icons" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Google Material Icons 
Material Symbols are our newest icons consolidating over 2,500 glyphs in a single font file with a wide range of design variants." style="">Google Material Icons</h3> <p class="description svelte-zslw0j">Material Symbols are our newest icons consolidating over 2,500 glyphs in a single font file with a wide range of design variants.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fonts.google.com/icons" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://feathericons.com/&amp;size=32" alt="Feather Icons" class="svelte-zslw0j"></span> </div> <a href="https://feathericons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Feather Icons 
Simply beautiful open source icons." style="">Feather Icons</h3> <p class="description svelte-zslw0j">Simply beautiful open source icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://feathericons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://weloveiconfonts.com/&amp;size=32" alt="We Love Icon Fonts" class="svelte-zslw0j"></span> </div> <a href="https://weloveiconfonts.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="We Love Icon Fonts 
Free &amp; open source icon fonts hosting service (like Google Web Fonts, but icon fonts only)." style="">We Love Icon Fonts</h3> <p class="description svelte-zslw0j">Free &amp; open source icon fonts hosting service (like Google Web Fonts, but icon fonts only).</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://weloveiconfonts.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://octicons.github.com/&amp;size=32" alt="Github Octoicons" class="svelte-zslw0j"></span> </div> <a href="https://octicons.github.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Github Octoicons 
Your project. GitHub's icons." style="">Github Octoicons</h3> <p class="description svelte-zslw0j">Your project. GitHub's icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://octicons.github.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.webalys.com/nova/index.html&amp;size=32" alt="Nova Icons" class="svelte-zslw0j"></span> </div> <a href="https://www.webalys.com/nova/index.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Nova Icons 
Material Design Icons Pack." style="">Nova Icons</h3> <p class="description svelte-zslw0j">Material Design Icons Pack.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.webalys.com/nova/index.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://danklammer.com/bytesize-icons/&amp;size=32" alt="Byte Size Icons" class="svelte-zslw0j"></span> </div> <a href="https://danklammer.com/bytesize-icons/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Byte Size Icons 
Tiny style-controlled SVG iconset." style="">Byte Size Icons</h3> <p class="description svelte-zslw0j">Tiny style-controlled SVG iconset.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://danklammer.com/bytesize-icons/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://svgicons.sparkk.fr/&amp;size=32" alt="Svg Icons" class="svelte-zslw0j"></span> </div> <a href="https://svgicons.sparkk.fr/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Svg Icons 
Ready to use SVG icons for the web." style="">Svg Icons</h3> <p class="description svelte-zslw0j">Ready to use SVG icons for the web.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://svgicons.sparkk.fr/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pictos.cc/&amp;size=32" alt="Pictos Redux" class="svelte-zslw0j"></span> </div> <a href="https://pictos.cc/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pictos Redux 
Carefully crafted interface icons." style="">Pictos Redux</h3> <p class="description svelte-zslw0j">Carefully crafted interface icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pictos.cc/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://picons.me/&amp;size=32" alt="Picons" class="svelte-zslw0j"></span> </div> <a href="https://picons.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Picons 
Vector Icons for iOS, Android, Websites &amp; Apps." style="">Picons</h3> <p class="description svelte-zslw0j">Vector Icons for iOS, Android, Websites &amp; Apps.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://picons.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.s-ings.com/typicons/&amp;size=32" alt="Typicons" class="svelte-zslw0j"></span> </div> <a href="https://www.s-ings.com/typicons/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Typicons 
Typicons are free-to-use vector icons embedded in a webfont for easy use in any UI, whether it be on the web or in a native app." style="">Typicons</h3> <p class="description svelte-zslw0j">Typicons are free-to-use vector icons embedded in a webfont for easy use in any UI, whether it be on the web or in a native app.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.s-ings.com/typicons/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://flaticons.net/&amp;size=32" alt="Flat Icons" class="svelte-zslw0j"></span> </div> <a href="https://flaticons.net/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Flat Icons 
You can create your own royalty free flat icons for your web-projects within seconds!" style="">Flat Icons</h3> <p class="description svelte-zslw0j">You can create your own royalty free flat icons for your web-projects within seconds!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://flaticons.net/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://genericons.com/&amp;size=32" alt="Genericons Neue" class="svelte-zslw0j"></span> </div> <a href="https://genericons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Genericons Neue 
Generic looking icons, suitable for a blog or simple website." style="">Genericons Neue</h3> <p class="description svelte-zslw0j">Generic looking icons, suitable for a blog or simple website.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://genericons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icon54.com/view-icons/&amp;size=32" alt="Icon 54" class="svelte-zslw0j"></span> </div> <a href="https://icon54.com/view-icons/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icon 54 
5,000 Vector Icons for iOS, Android, Websites &amp; Apps." style="">Icon 54</h3> <p class="description svelte-zslw0j">5,000 Vector Icons for iOS, Android, Websites &amp; Apps.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icon54.com/view-icons/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.macosicongallery.com/&amp;size=32" alt="MacOS Icon Gallery" class="svelte-zslw0j"></span> </div> <a href="https://www.macosicongallery.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MacOS Icon Gallery 
Showcasing beautiful icon designs from the Mac App Store." style="">MacOS Icon Gallery</h3> <p class="description svelte-zslw0j">Showcasing beautiful icon designs from the Mac App Store.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.macosicongallery.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://cssicon.space/&amp;size=32" alt="CSS Icon Animate" class="svelte-zslw0j"></span> </div> <a href="https://cssicon.space/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CSS Icon Animate 
Animating css icons." style="">CSS Icon Animate</h3> <p class="description svelte-zslw0j">Animating css icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://cssicon.space/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.potlabicons.com/&amp;size=32" alt="Potlab Icons" class="svelte-zslw0j"></span> </div> <a href="https://www.potlabicons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Potlab Icons 
Animated SVG icons for web projects" style="">Potlab Icons</h3> <p class="description svelte-zslw0j">Animated SVG icons for web projects</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.potlabicons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontello.com/&amp;size=32" alt="Fontello" class="svelte-zslw0j"></span> </div> <a href="https://fontello.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fontello 
Fontello is a web app that lists open source icon fonts, shows glyphs from them, allows you to select the icons you need from any font, and creates a new custom font from your selection. You can then use these custom font on your website." style="">Fontello</h3> <p class="description svelte-zslw0j">Fontello is a web app that lists open source icon fonts, shows glyphs from them, allows you to select the icons you need from any font, and creates a new custom font from your selection. You can then use these custom font on your website.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontello.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tabler-icons.io/&amp;size=32" alt="Tabler Icons" class="svelte-zslw0j"></span> </div> <a href="https://tabler-icons.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Tabler Icons 
Free and open source icons designed to make your website or app attractive, visually consistent and simply beautiful." style="">Tabler Icons</h3> <p class="description svelte-zslw0j">Free and open source icons designed to make your website or app attractive, visually consistent and simply beautiful.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tabler-icons.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://css.gg/&amp;size=32" alt="CSS Icons" class="svelte-zslw0j"></span> </div> <a href="https://css.gg/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CSS Icons 
Open-source CSS, SVG and Figma UI Icons Available in SVG Sprite." style="">CSS Icons</h3> <p class="description svelte-zslw0j">Open-source CSS, SVG and Figma UI Icons Available in SVG Sprite.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://css.gg/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://heroicons.dev/&amp;size=32" alt="Heroicons Dev" class="svelte-zslw0j"></span> </div> <a href="https://heroicons.dev/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Heroicons Dev 
Free and open source icons designed to make your website." style="">Heroicons Dev</h3> <p class="description svelte-zslw0j">Free and open source icons designed to make your website.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://heroicons.dev/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://remixicon.com/&amp;size=32" alt="Remix Icons" class="svelte-zslw0j"></span> </div> <a href="https://remixicon.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Remix Icons 
All of the icons are free for both personal and commercial use." style="">Remix Icons</h3> <p class="description svelte-zslw0j">All of the icons are free for both personal and commercial use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://remixicon.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ikonate.com/&amp;size=32" alt="Ikonate" class="svelte-zslw0j"></span> </div> <a href="https://ikonate.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ikonate 
Fully customisable &amp; accessible, well-optimised vector icons." style="">Ikonate</h3> <p class="description svelte-zslw0j">Fully customisable &amp; accessible, well-optimised vector icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ikonate.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://boxicons.com/&amp;size=32" alt="Boxicons" class="svelte-zslw0j"></span> </div> <a href="https://boxicons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Boxicons 
Simple vector icons carefully crafted for designers &amp; developers." style="">Boxicons</h3> <p class="description svelte-zslw0j">Simple vector icons carefully crafted for designers &amp; developers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://boxicons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://akveo.github.io/eva-icons/#/&amp;size=32" alt="Eva Icons" class="svelte-zslw0j"></span> </div> <a href="https://akveo.github.io/eva-icons/#/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Eva Icons 
Eva Icons is a pack of more than 480 beautifafted Open Source icons." style="">Eva Icons</h3> <p class="description svelte-zslw0j">Eva Icons is a pack of more than 480 beautifafted Open Source icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://akveo.github.io/eva-icons/#/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconoir.com/&amp;size=32" alt="Iconoir" class="svelte-zslw0j"></span> </div> <a href="https://iconoir.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iconoir 
Iconoir is one of the biggest open source libraries with currently 1017 SVG Icons." style="">Iconoir</h3> <p class="description svelte-zslw0j">Iconoir is one of the biggest open source libraries with currently 1017 SVG Icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconoir.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://3dicons.co/&amp;size=32" alt="3dicons" class="svelte-zslw0j"></span> </div> <a href="https://3dicons.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="3dicons 
Open source 3D icon library with over 1440+ icons." style="">3dicons</h3> <p class="description svelte-zslw0j">Open source 3D icon library with over 1440+ icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://3dicons.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icones.js.org/&amp;size=32" alt="Icônes" class="svelte-zslw0j"></span> </div> <a href="https://icones.js.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icônes 
Icon Explorer with Instant searching, powered by Iconify" style="">Icônes</h3> <p class="description svelte-zslw0j">Icon Explorer with Instant searching, powered by Iconify</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icones.js.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconhub.io/&amp;size=32" alt="iconhub" class="svelte-zslw0j"></span> </div> <a href="https://iconhub.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="iconhub 
Save your penny and time creating from scratch, use these diverse Icon set to complete your awesome design." style="">iconhub</h3> <p class="description svelte-zslw0j">Save your penny and time creating from scratch, use these diverse Icon set to complete your awesome design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconhub.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconsax.io/&amp;size=32" alt="Iconsax" class="svelte-zslw0j"></span> </div> <a href="https://iconsax.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iconsax 
Iconsax the official icons of the Vuesax framework" style="">Iconsax</h3> <p class="description svelte-zslw0j">Iconsax the official icons of the Vuesax framework</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconsax.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/file/1034432054377533052&amp;size=32" alt="Quill" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/file/1034432054377533052" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Quill 
Quill is a 120+ iconset for your next email project." style="">Quill</h3> <p class="description svelte-zslw0j">Quill is a 120+ iconset for your next email project.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/file/1034432054377533052" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.zwicon.com/cheatsheet.html&amp;size=32" alt="Zwicon" class="svelte-zslw0j"></span> </div> <a href="https://www.zwicon.com/cheatsheet.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Zwicon 
Handcrafted iconset for your next project" style="">Zwicon</h3> <p class="description svelte-zslw0j">Handcrafted iconset for your next project</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.zwicon.com/cheatsheet.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.streamlinehq.com/icons/streamline-flex---free&amp;size=32" alt="Streamline Flex" class="svelte-zslw0j"></span> </div> <a href="https://www.streamlinehq.com/icons/streamline-flex---free" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Streamline Flex 
A minimalistic set, with elegant and smooth curves. Super easy to adapt to your project with only two colors." style="">Streamline Flex</h3> <p class="description svelte-zslw0j">A minimalistic set, with elegant and smooth curves. Super easy to adapt to your project with only two colors.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.streamlinehq.com/icons/streamline-flex---free" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://typogram.github.io/Anicons/&amp;size=32" alt="Anicons" class="svelte-zslw0j"></span> </div> <a href="https://typogram.github.io/Anicons/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Anicons 
Icon fonts with baked-in animation and colors" style="">Anicons</h3> <p class="description svelte-zslw0j">Icon fonts with baked-in animation and colors</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://typogram.github.io/Anicons/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconbay.io/&amp;size=32" alt="Iconbay" class="svelte-zslw0j"></span> </div> <a href="https://iconbay.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iconbay 
Fun and modern icon for your projects with multiple styles" style="">Iconbay</h3> <p class="description svelte-zslw0j">Fun and modern icon for your projects with multiple styles</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconbay.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icons.craftwork.design/&amp;size=32" alt="Icons by Crafwork" class="svelte-zslw0j"></span> </div> <a href="https://icons.craftwork.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icons by Crafwork 
500 open source icons in fill and stroke versions. 17 categories of use, universal minimalistic style, and vector shapes. For Figma." style="">Icons by Crafwork</h3> <p class="description svelte-zslw0j">500 open source icons in fill and stroke versions. 17 categories of use, universal minimalistic style, and vector shapes. For Figma.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icons.craftwork.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconbrew.com/&amp;size=32" alt="IconBrew" class="svelte-zslw0j"></span> </div> <a href="https://iconbrew.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="IconBrew 
A free and open source icon pack. With 280+ icons and new ones being added weekly." style="">IconBrew</h3> <p class="description svelte-zslw0j">A free and open source icon pack. With 280+ icons and new ones being added weekly.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconbrew.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://humbleicons.com/&amp;size=32" alt="Humbleicons" class="svelte-zslw0j"></span> </div> <a href="https://humbleicons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Humbleicons 
A pack of 223 simple, neutral, carefully crafted icons that you can use in your personal and commercial projects for free." style="">Humbleicons</h3> <p class="description svelte-zslw0j">A pack of 223 simple, neutral, carefully crafted icons that you can use in your personal and commercial projects for free.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://humbleicons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://circumicons.com/&amp;size=32" alt="Circum" class="svelte-zslw0j"></span> </div> <a href="https://circumicons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Circum 
Consistent open source icons." style="">Circum</h3> <p class="description svelte-zslw0j">Consistent open source icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://circumicons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


icon_finder_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thenounproject.com&amp;size=32" alt="Noun Project" class="svelte-zslw0j"></span> </div> <a href="https://thenounproject.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Noun Project 
Noun Project features the most diverse collection of icons and stock photos ever. Download SVG and PNG. Browse over 3 million art-quality icons and photos." style="">Noun Project</h3> <p class="description svelte-zslw0j">Noun Project features the most diverse collection of icons and stock photos ever. Download SVG and PNG. Browse over 3 million art-quality icons and photos.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thenounproject.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.iconfinder.com/&amp;size=32" alt="Iconfinder" class="svelte-zslw0j"></span> </div> <a href="https://www.iconfinder.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iconfinder 
Iconfinder is the leading search engine and market place for vector icons in SVG, PNG, CSH and AI format." style="">Iconfinder</h3> <p class="description svelte-zslw0j">Iconfinder is the leading search engine and market place for vector icons in SVG, PNG, CSH and AI format.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.iconfinder.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.flaticon.com/&amp;size=32" alt="Flaticon" class="svelte-zslw0j"></span> </div> <a href="https://www.flaticon.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Flaticon 
Access +6.8M vector icons &amp; stickers" style="">Flaticon</h3> <p class="description svelte-zslw0j">Access +6.8M vector icons &amp; stickers</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.flaticon.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icomoon.io/app/#/select&amp;size=32" alt="Icomoon" class="svelte-zslw0j"></span> </div> <a href="https://icomoon.io/app/#/select" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icomoon 
Using IcoMoon you can easily search and download vector icons or generate fonts (icon fonts). This tool can also be used for icon set management. It can generate icon fonts, SVGs, PDFs, PNGs and sprites." style="">Icomoon</h3> <p class="description svelte-zslw0j">Using IcoMoon you can easily search and download vector icons or generate fonts (icon fonts). This tool can also be used for icon set management. It can generate icon fonts, SVGs, PDFs, PNGs and sprites.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icomoon.io/app/#/select" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconmonstr.com/&amp;size=32" alt="Iconmonstr" class="svelte-zslw0j"></span> </div> <a href="https://iconmonstr.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iconmonstr 
Free, monstrously big and continuously growing source of simple icons" style="">Iconmonstr</h3> <p class="description svelte-zslw0j">Free, monstrously big and continuously growing source of simple icons</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconmonstr.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconstore.co/&amp;size=32" alt="Icon Store" class="svelte-zslw0j"></span> </div> <a href="https://iconstore.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icon Store 
A library of free vector icons for personal and commercial projects, designed by first-class designers." style="">Icon Store</h3> <p class="description svelte-zslw0j">A library of free vector icons for personal and commercial projects, designed by first-class designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconstore.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.toicon.com/&amp;size=32" alt="To Icons" class="svelte-zslw0j"></span> </div> <a href="https://www.toicon.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="To Icons 
Pixel-perfect vector icons with personality, free for your use." style="">To Icons</h3> <p class="description svelte-zslw0j">Pixel-perfect vector icons with personality, free for your use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.toicon.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://nucleoapp.com/app/&amp;size=32" alt="Nucleo App" class="svelte-zslw0j"></span> </div> <a href="https://nucleoapp.com/app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Nucleo App 
Use this web app to manage, customize and export all Nucleo icons." style="">Nucleo App</h3> <p class="description svelte-zslw0j">Use this web app to manage, customize and export all Nucleo icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://nucleoapp.com/app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://smashicons.com/&amp;size=32" alt="Smashicons" class="svelte-zslw0j"></span> </div> <a href="https://smashicons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Smashicons 
Smashicons is the world's largest and most complete icon set with over 207,996 icons for designers and developers." style="">Smashicons</h3> <p class="description svelte-zslw0j">Smashicons is the world's largest and most complete icon set with over 207,996 icons for designers and developers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://smashicons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://freeiconshop.com/&amp;size=32" alt="Free Icon Shop" class="svelte-zslw0j"></span> </div> <a href="https://freeiconshop.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Free Icon Shop 
Download free icons for commercial use. All free icons can be downloaded for free for all project uses. Free icons can be downloaded in vector formats." style="">Free Icon Shop</h3> <p class="description svelte-zslw0j">Download free icons for commercial use. All free icons can be downloaded for free for all project uses. Free icons can be downloaded in vector formats.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://freeiconshop.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://simpleicons.org/&amp;size=32" alt="Simple Icons" class="svelte-zslw0j"></span> </div> <a href="https://simpleicons.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Simple Icons 
Free SVG icons for popular brands." style="">Simple Icons</h3> <p class="description svelte-zslw0j">Free SVG icons for popular brands.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://simpleicons.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icons8.com/icons&amp;size=32" alt="Icons8" class="svelte-zslw0j"></span> </div> <a href="https://icons8.com/icons" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icons8 
Professional icons by the rockstar team to beautify your work. " style="">Icons8</h3> <p class="description svelte-zslw0j">Professional icons by the rockstar team to beautify your work. </p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icons8.com/icons" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.iconshock.com/&amp;size=32" alt="Iconshock" class="svelte-zslw0j"></span> </div> <a href="https://www.iconshock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iconshock 
The biggest bounty of professional icons to be found anywhere. Over 2 million icons: 400+ icon sets in more than 30 styles part of Unusual Minds." style="">Iconshock</h3> <p class="description svelte-zslw0j">The biggest bounty of professional icons to be found anywhere. Over 2 million icons: 400+ icon sets in more than 30 styles part of Unusual Minds.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.iconshock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconscout.com/icons&amp;size=32" alt="Iconscout" class="svelte-zslw0j"></span> </div> <a href="https://iconscout.com/icons" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iconscout 
Download 3.6 Million+ high-quality free vector Icons." style="">Iconscout</h3> <p class="description svelte-zslw0j">Download 3.6 Million+ high-quality free vector Icons.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconscout.com/icons" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.svggobbler.com/&amp;size=32" alt="SVG Gobbler" class="svelte-zslw0j"></span> </div> <a href="https://www.svggobbler.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="SVG Gobbler 
SVG Gobbler is a browser extension that finds the vector content on the page you're viewing and gives you the option to download, optimize, copy, view the ..." style="">SVG Gobbler</h3> <p class="description svelte-zslw0j">SVG Gobbler is a browser extension that finds the vector content on the page you're viewing and gives you the option to download, optimize, copy, view the ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.svggobbler.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://emojipedia.org/&amp;size=32" alt="Emojipedia" class="svelte-zslw0j"></span> </div> <a href="https://emojipedia.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Emojipedia 
The emoji search engine. A fast emoji search experience with options to browse every emoji by name, category, or platform." style="">Emojipedia</h3> <p class="description svelte-zslw0j">The emoji search engine. A fast emoji search experience with options to browse every emoji by name, category, or platform.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://emojipedia.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://shape.so/&amp;size=32" alt="Shape" class="svelte-zslw0j"></span> </div> <a href="https://shape.so/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Shape 
36,500 icons and illustrations fully customizable" style="">Shape</h3> <p class="description svelte-zslw0j">36,500 icons and illustrations fully customizable</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://shape.so/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iconbros.com/&amp;size=32" alt="IconBros" class="svelte-zslw0j"></span> </div> <a href="https://iconbros.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="IconBros 
Free and continuously growing high quality icons" style="">IconBros</h3> <p class="description svelte-zslw0j">Free and continuously growing high quality icons</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iconbros.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.koloicons.com/&amp;size=32" alt="Koloicons" class="svelte-zslw0j"></span> </div> <a href="https://www.koloicons.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Koloicons 
SVG Icons in constant style - Koloicons. Thousands of free PNG icons. Download SVG and PNG. The same consistency. The same quality." style="">Koloicons</h3> <p class="description svelte-zslw0j">SVG Icons in constant style - Koloicons. Thousands of free PNG icons. Download SVG and PNG. The same consistency. The same quality.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.koloicons.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


color_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://flatuicolors.com&amp;size=32" alt="Flat UI Colors" class="svelte-zslw0j"></span> </div> <a href="https://flatuicolors.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Flat UI Colors 
13 color palettes from 13 designers from all over the world." style="">Flat UI Colors</h3> <p class="description svelte-zslw0j">13 color palettes from 13 designers from all over the world.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://flatuicolors.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pigment.shapefactory.co/&amp;size=32" alt="Pigment" class="svelte-zslw0j"></span> </div> <a href="https://pigment.shapefactory.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pigment 
A unique way to generate fresh and vibrant colors based on lighting and pigment, instead of math." style="">Pigment</h3> <p class="description svelte-zslw0j">A unique way to generate fresh and vibrant colors based on lighting and pigment, instead of math.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pigment.shapefactory.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://materialuicolors.co&amp;size=32" alt="Material UI Colors" class="svelte-zslw0j"></span> </div> <a href="https://materialuicolors.co" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Material UI Colors 
Color Palette for Material Design." style="">Material UI Colors</h3> <p class="description svelte-zslw0j">Color Palette for Material Design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://materialuicolors.co" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.vanschneider.com/colors/&amp;size=32" alt="Color Claim" class="svelte-zslw0j"></span> </div> <a href="https://www.vanschneider.com/colors/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Color Claim 
Color Claim was created in 2012 by Tobias van Schneider with the goal to collect &amp; combine unique colors for his future projects." style="">Color Claim</h3> <p class="description svelte-zslw0j">Color Claim was created in 2012 by Tobias van Schneider with the goal to collect &amp; combine unique colors for his future projects.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.vanschneider.com/colors/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colourco.de/&amp;size=32" alt="Colour Code" class="svelte-zslw0j"></span> </div> <a href="https://colourco.de/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colour Code 
An online designer tool, which allows you to easily and intuitively combine colours." style="">Colour Code</h3> <p class="description svelte-zslw0j">An online designer tool, which allows you to easily and intuitively combine colours.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colourco.de/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://palettte.app/&amp;size=32" alt="Palette App" class="svelte-zslw0j"></span> </div> <a href="https://palettte.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Palette App 
Build smooth color schemes that flow from one color to another." style="">Palette App</h3> <p class="description svelte-zslw0j">Build smooth color schemes that flow from one color to another.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://palettte.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colordrop.io/&amp;size=32" alt="Color Drop" class="svelte-zslw0j"></span> </div> <a href="https://colordrop.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Color Drop 
Thousands of curated colors, palettes for use in your products." style="">Color Drop</h3> <p class="description svelte-zslw0j">Thousands of curated colors, palettes for use in your products.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colordrop.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorhunt.co/&amp;size=32" alt="Color Hunt" class="svelte-zslw0j"></span> </div> <a href="https://colorhunt.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Color Hunt 
Color Hunt is a free and open platform for color inspiration with thousands of trendy hand-picked color palettes." style="">Color Hunt</h3> <p class="description svelte-zslw0j">Color Hunt is a free and open platform for color inspiration with thousands of trendy hand-picked color palettes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorhunt.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://coolors.co/app&amp;size=32" alt="Coolors" class="svelte-zslw0j"></span> </div> <a href="https://coolors.co/app" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Coolors 
Create, save and share beautiful palettes in seconds!" style="">Coolors</h3> <p class="description svelte-zslw0j">Create, save and share beautiful palettes in seconds!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://coolors.co/app" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorleap.app/home&amp;size=32" alt="Colorleap" class="svelte-zslw0j"></span> </div> <a href="https://colorleap.app/home" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colorleap 
Search through 180 Color Palettes used throughout the last 4000 years. Find color combinations that stand the test of time and spark your imagination from history’s masters." style="">Colorleap</h3> <p class="description svelte-zslw0j">Search through 180 Color Palettes used throughout the last 4000 years. Find color combinations that stand the test of time and spark your imagination from history’s masters.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorleap.app/home" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.palettable.io/&amp;size=32" alt="Palet Table" class="svelte-zslw0j"></span> </div> <a href="https://www.palettable.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Palet Table 
Generate beautiful color palettes using the knowledge of millions of designers." style="">Palet Table</h3> <p class="description svelte-zslw0j">Generate beautiful color palettes using the knowledge of millions of designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.palettable.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://culrs.com/#/lightanalogous&amp;size=32" alt="Culrs" class="svelte-zslw0j"></span> </div> <a href="https://culrs.com/#/lightanalogous" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Culrs 
Thoughtfully crafted and easy-to-use color palettes." style="">Culrs</h3> <p class="description svelte-zslw0j">Thoughtfully crafted and easy-to-use color palettes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://culrs.com/#/lightanalogous" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://brandcolors.net/&amp;size=32" alt="Brand Colors" class="svelte-zslw0j"></span> </div> <a href="https://brandcolors.net/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Brand Colors 
The biggest collection of official brand color codes around." style="">Brand Colors</h3> <p class="description svelte-zslw0j">The biggest collection of official brand color codes around.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://brandcolors.net/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://materialpalettes.com/&amp;size=32" alt="Material Palettes" class="svelte-zslw0j"></span> </div> <a href="https://materialpalettes.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Material Palettes 
Get perfect Material Design color palettes from any hex color." style="">Material Palettes</h3> <p class="description svelte-zslw0j">Get perfect Material Design color palettes from any hex color.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://materialpalettes.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://color.hailpixel.com/&amp;size=32" alt="Color Dot" class="svelte-zslw0j"></span> </div> <a href="https://color.hailpixel.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Color Dot 
Simple color picker everyone." style="">Color Dot</h3> <p class="description svelte-zslw0j">Simple color picker everyone.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://color.hailpixel.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://color.review/&amp;size=32" alt="Color Review" class="svelte-zslw0j"></span> </div> <a href="https://color.review/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Color Review 
Colors that look and work great for everyone." style="">Color Review</h3> <p class="description svelte-zslw0j">Colors that look and work great for everyone.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://color.review/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://hue.tools/&amp;size=32" alt="hue.tools" class="svelte-zslw0j"></span> </div> <a href="https://hue.tools/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="hue.tools 
Intuitive open source toolbox for colors" style="">hue.tools</h3> <p class="description svelte-zslw0j">Intuitive open source toolbox for colors</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://hue.tools/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorhuddle.co/&amp;size=32" alt="ColorHuddle" class="svelte-zslw0j"></span> </div> <a href="https://colorhuddle.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ColorHuddle 
Ready-to-use color palettes with live previews" style="">ColorHuddle</h3> <p class="description svelte-zslw0j">Ready-to-use color palettes with live previews</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorhuddle.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fffuel.co/cccolor/&amp;size=32" alt="cccolor" class="svelte-zslw0j"></span> </div> <a href="https://fffuel.co/cccolor/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="cccolor 
Clean &amp; simple color picker for web designers" style="">cccolor</h3> <p class="description svelte-zslw0j">Clean &amp; simple color picker for web designers</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fffuel.co/cccolor/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://randomcolor.design/&amp;size=32" alt="Random Color" class="svelte-zslw0j"></span> </div> <a href="https://randomcolor.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Random Color 
Generate random color for your new application and web app" style="">Random Color</h3> <p class="description svelte-zslw0j">Generate random color for your new application and web app</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://randomcolor.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://couleur.io/&amp;size=32" alt="couleur.io" class="svelte-zslw0j"></span> </div> <a href="https://couleur.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="couleur.io 
Create harmonizing color palettes" style="">couleur.io</h3> <p class="description svelte-zslw0j">Create harmonizing color palettes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://couleur.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorhub.vercel.app/select-palette&amp;size=32" alt="ColorHub" class="svelte-zslw0j"></span> </div> <a href="https://colorhub.vercel.app/select-palette" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ColorHub 
Find the perfect color palette for your next project" style="">ColorHub</h3> <p class="description svelte-zslw0j">Find the perfect color palette for your next project</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorhub.vercel.app/select-palette" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://image-to-tailwind.netlify.app/&amp;size=32" alt="Image-to-Tailwind" class="svelte-zslw0j"></span> </div> <a href="https://image-to-tailwind.netlify.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Image-to-Tailwind 
Generate a Tailwind-ready color palette from an image" style="">Image-to-Tailwind</h3> <p class="description svelte-zslw0j">Generate a Tailwind-ready color palette from an image</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://image-to-tailwind.netlify.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorffy.com/&amp;size=32" alt="Colorffy 2.0" class="svelte-zslw0j"></span> </div> <a href="https://colorffy.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colorffy 2.0 
Find or create harmonious color combinations" style="">Colorffy 2.0</h3> <p class="description svelte-zslw0j">Find or create harmonious color combinations</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorffy.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://palitra.app/&amp;size=32" alt="Palitra App" class="svelte-zslw0j"></span> </div> <a href="https://palitra.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Palitra App 
The easiest way to find a color palette!" style="">Palitra App</h3> <p class="description svelte-zslw0j">The easiest way to find a color palette!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://palitra.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorpalettes.colorion.co/&amp;size=32" alt="Actionable Color Palettes" class="svelte-zslw0j"></span> </div> <a href="https://colorpalettes.colorion.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Actionable Color Palettes 
Collection of 30+ color palettes with preview" style="">Actionable Color Palettes</h3> <p class="description svelte-zslw0j">Collection of 30+ color palettes with preview</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorpalettes.colorion.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tailwind-color-palette.netlify.app/&amp;size=32" alt="Tailwind Palette" class="svelte-zslw0j"></span> </div> <a href="https://tailwind-color-palette.netlify.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Tailwind Palette 
Generate shades &amp; tints for color with its Tailwind config" style="">Tailwind Palette</h3> <p class="description svelte-zslw0j">Generate shades &amp; tints for color with its Tailwind config</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tailwind-color-palette.netlify.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://naevner.com/&amp;size=32" alt="Naevner" class="svelte-zslw0j"></span> </div> <a href="https://naevner.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Naevner 
Color descriptions generated from hex color codes" style="">Naevner</h3> <p class="description svelte-zslw0j">Color descriptions generated from hex color codes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://naevner.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://nira-app.com/&amp;size=32" alt="Nira" class="svelte-zslw0j"></span> </div> <a href="https://nira-app.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Nira 
Change color scheme of an SVG in an instant" style="">Nira</h3> <p class="description svelte-zslw0j">Change color scheme of an SVG in an instant</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://nira-app.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://hexcolorpedia.com/&amp;size=32" alt="Hexcolorpedia" class="svelte-zslw0j"></span> </div> <a href="https://hexcolorpedia.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Hexcolorpedia 
Color info and Color Palettes" style="">Hexcolorpedia</h3> <p class="description svelte-zslw0j">Color info and Color Palettes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://hexcolorpedia.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.radix-ui.com/colors&amp;size=32" alt="Radix Colors" class="svelte-zslw0j"></span> </div> <a href="https://www.radix-ui.com/colors" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Radix Colors 
A gorgeous, accessible, open-source color system" style="">Radix Colors</h3> <p class="description svelte-zslw0j">A gorgeous, accessible, open-source color system</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.radix-ui.com/colors" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tinter.uxie.io/&amp;size=32" alt="Tinter" class="svelte-zslw0j"></span> </div> <a href="https://tinter.uxie.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Tinter 
Generate color variations of images" style="">Tinter</h3> <p class="description svelte-zslw0j">Generate color variations of images</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tinter.uxie.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.colors.tools/&amp;size=32" alt="Colors Tools" class="svelte-zslw0j"></span> </div> <a href="https://www.colors.tools/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colors Tools 
Dive into the world of colors, and get excited" style="">Colors Tools</h3> <p class="description svelte-zslw0j">Dive into the world of colors, and get excited</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.colors.tools/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mobilepalette.colorion.co/&amp;size=32" alt="Mobile Palette Generator" class="svelte-zslw0j"></span> </div> <a href="https://mobilepalette.colorion.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mobile Palette Generator 
Generate color palettes with a click of the mouse" style="">Mobile Palette Generator</h3> <p class="description svelte-zslw0j">Generate color palettes with a click of the mouse</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mobilepalette.colorion.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://darker.vercel.app/&amp;size=32" alt="Darker" class="svelte-zslw0j"></span> </div> <a href="https://darker.vercel.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Darker 
Generate color tints &amp; shades" style="">Darker</h3> <p class="description svelte-zslw0j">Generate color tints &amp; shades</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://darker.vercel.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colpic.netlify.app/gradients&amp;size=32" alt="Colpic" class="svelte-zslw0j"></span> </div> <a href="https://colpic.netlify.app/gradients" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colpic 
Color and gradient picker" style="">Colpic</h3> <p class="description svelte-zslw0j">Color and gradient picker</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colpic.netlify.app/gradients" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://picular.co/&amp;size=32" alt="Picular" class="svelte-zslw0j"></span> </div> <a href="https://picular.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Picular 
Picular is a rocket fast primary color generator using Google’s image search." style="">Picular</h3> <p class="description svelte-zslw0j">Picular is a rocket fast primary color generator using Google’s image search.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://picular.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorable.jxnblk.com/&amp;size=32" alt="Colorable" class="svelte-zslw0j"></span> </div> <a href="https://colorable.jxnblk.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colorable 
Contrast is the difference in luminance or color that makes an object (or its representation in an image or display) distinguishable." style="">Colorable</h3> <p class="description svelte-zslw0j">Contrast is the difference in luminance or color that makes an object (or its representation in an image or display) distinguishable.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorable.jxnblk.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorinspire.webflow.io/&amp;size=32" alt="Colorinspire" class="svelte-zslw0j"></span> </div> <a href="https://colorinspire.webflow.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colorinspire 
A small website to showcase beautiful color combinations in one place." style="">Colorinspire</h3> <p class="description svelte-zslw0j">A small website to showcase beautiful color combinations in one place.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorinspire.webflow.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mycolor.space/&amp;size=32" alt="ColorSpace" class="svelte-zslw0j"></span> </div> <a href="https://mycolor.space/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ColorSpace 
ColorSpace is a currently developed tool to generate color palettes, gradients and much more!" style="">ColorSpace</h3> <p class="description svelte-zslw0j">ColorSpace is a currently developed tool to generate color palettes, gradients and much more!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mycolor.space/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://color.hailpixel.com/&amp;size=32" alt="Colordot" class="svelte-zslw0j"></span> </div> <a href="https://color.hailpixel.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colordot 
It’s intuitive, fast, and beautiful. Build palettes with a swipe of your finger or use your camera to capture colors from the world around you." style="">Colordot</h3> <p class="description svelte-zslw0j">It’s intuitive, fast, and beautiful. Build palettes with a swipe of your finger or use your camera to capture colors from the world around you.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://color.hailpixel.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorbox.io/&amp;size=32" alt="ColorBox" class="svelte-zslw0j"></span> </div> <a href="https://colorbox.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ColorBox 
A tool to produce color sets open-sourced by Lyft's design team." style="">ColorBox</h3> <p class="description svelte-zslw0j">A tool to produce color sets open-sourced by Lyft's design team.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorbox.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colors.eva.design/&amp;size=32" alt="Eva Design" class="svelte-zslw0j"></span> </div> <a href="https://colors.eva.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Eva Design 
Eva Design is deep learning color generator." style="">Eva Design</h3> <p class="description svelte-zslw0j">Eva Design is deep learning color generator.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colors.eva.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.happyhues.co/&amp;size=32" alt="Happy Hues" class="svelte-zslw0j"></span> </div> <a href="https://www.happyhues.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Happy Hues 
Happy Hues solves the problem of not knowing how to apply a color palette to your designs." style="">Happy Hues</h3> <p class="description svelte-zslw0j">Happy Hues solves the problem of not knowing how to apply a color palette to your designs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.happyhues.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorsinspo.com/&amp;size=32" alt="Colorsinspo" class="svelte-zslw0j"></span> </div> <a href="https://colorsinspo.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colorsinspo 
All in one resource for finding everything about color." style="">Colorsinspo</h3> <p class="description svelte-zslw0j">All in one resource for finding everything about color.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorsinspo.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://khroma.co/&amp;size=32" alt="Khroma" class="svelte-zslw0j"></span> </div> <a href="https://khroma.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Khroma 
Uses AI to learn which colors you like and creates palettes." style="">Khroma</h3> <p class="description svelte-zslw0j">Uses AI to learn which colors you like and creates palettes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://khroma.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorspark.app/&amp;size=32" alt="Color Spark" class="svelte-zslw0j"></span> </div> <a href="https://colorspark.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Color Spark 
A simple tool that generates random colors and gradients." style="">Color Spark</h3> <p class="description svelte-zslw0j">A simple tool that generates random colors and gradients.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorspark.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.culrs.com/&amp;size=32" alt="Сulrs" class="svelte-zslw0j"></span> </div> <a href="https://www.culrs.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Сulrs 
Thoughtfully crafted and easy-to-use color palettes." style="">Сulrs</h3> <p class="description svelte-zslw0j">Thoughtfully crafted and easy-to-use color palettes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.culrs.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorslurp.com&amp;size=32" alt="ColorSlurp" class="svelte-zslw0j"></span> </div> <a href="https://colorslurp.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ColorSlurp 
ColorSlurp is the ultimate color tool for developers and designers. Pick any color on your screen using the high-precision magnifier." style="">ColorSlurp</h3> <p class="description svelte-zslw0j">ColorSlurp is the ultimate color tool for developers and designers. Pick any color on your screen using the high-precision magnifier.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorslurp.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://stylifyme.com/&amp;size=32" alt="Stylify Me" class="svelte-zslw0j"></span> </div> <a href="https://stylifyme.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stylify Me 
Stylify Me was created to help designers quickly gain an overview of the style guide of a site, including colours, fonts, sizing and spacing." style="">Stylify Me</h3> <p class="description svelte-zslw0j">Stylify Me was created to help designers quickly gain an overview of the style guide of a site, including colours, fonts, sizing and spacing.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://stylifyme.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://color.adobe.com/fr/create/color-wheel&amp;size=32" alt="Adobe Color" class="svelte-zslw0j"></span> </div> <a href="https://color.adobe.com/fr/create/color-wheel" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Adobe Color 
Create color palettes with the color wheel or image, browse thousands of color combinations from the Adobe Color community." style="">Adobe Color</h3> <p class="description svelte-zslw0j">Create color palettes with the color wheel or image, browse thousands of color combinations from the Adobe Color community.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://color.adobe.com/fr/create/color-wheel" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.colorsandfonts.com/&amp;size=32" alt="Colors and fonts" class="svelte-zslw0j"></span> </div> <a href="https://www.colorsandfonts.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colors and fonts 
Color and typography for Web Developers and Digital Designers." style="">Colors and fonts</h3> <p class="description svelte-zslw0j">Color and typography for Web Developers and Digital Designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.colorsandfonts.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://htmlcolorcodes.com/&amp;size=32" alt="Html Color Codes" class="svelte-zslw0j"></span> </div> <a href="https://htmlcolorcodes.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Html Color Codes 
Easily find HTML color codes for your website using our color picker, color chart and HTML color names with Hex color codes, RGB and HSL values." style="">Html Color Codes</h3> <p class="description svelte-zslw0j">Easily find HTML color codes for your website using our color picker, color chart and HTML color names with Hex color codes, RGB and HSL values.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://htmlcolorcodes.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uicolors.app/create&amp;size=32" alt="UI Color " class="svelte-zslw0j"></span> </div> <a href="https://uicolors.app/create" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Color  
Create Tailwind CSS color families" style="">UI Color </h3> <p class="description svelte-zslw0j">Create Tailwind CSS color families</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uicolors.app/create" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.palettelyst.ml/&amp;size=32" alt="Palette Lyst" class="svelte-zslw0j"></span> </div> <a href="https://www.palettelyst.ml/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Palette Lyst 
Generate more than 10000+ color palette by just single click" style="">Palette Lyst</h3> <p class="description svelte-zslw0j">Generate more than 10000+ color palette by just single click</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.palettelyst.ml/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.token-master.com/&amp;size=32" alt="Token Master" class="svelte-zslw0j"></span> </div> <a href="https://www.token-master.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Token Master 
Edit design tokens and create new color modes in Figma" style="">Token Master</h3> <p class="description svelte-zslw0j">Edit design tokens and create new color modes in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.token-master.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colourpalette.xyz/&amp;size=32" alt="Colour Palette" class="svelte-zslw0j"></span> </div> <a href="https://colourpalette.xyz/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colour Palette 
Go through some of the most beautiful colours on Earth" style="">Colour Palette</h3> <p class="description svelte-zslw0j">Go through some of the most beautiful colours on Earth</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colourpalette.xyz/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorspectrum.design/&amp;size=32" alt="Spectrum: Figma Plugin &amp; Web App" class="svelte-zslw0j"></span> </div> <a href="https://colorspectrum.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Spectrum: Figma Plugin &amp; Web App 
Generate color palettes and apply instantly to anything!" style="">Spectrum: Figma Plugin &amp; Web App</h3> <p class="description svelte-zslw0j">Generate color palettes and apply instantly to anything!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorspectrum.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.everypixel.com/color-trends&amp;size=32" alt="Color Trends" class="svelte-zslw0j"></span> </div> <a href="https://www.everypixel.com/color-trends" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Color Trends 
Top colors in stock photography" style="">Color Trends</h3> <p class="description svelte-zslw0j">Top colors in stock photography</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.everypixel.com/color-trends" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


illustrations_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://undraw.co/&amp;size=32" alt="UnDraw" class="svelte-zslw0j"></span> </div> <a href="https://undraw.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UnDraw 
The design project with open-source illustrations for any idea you can imagine and create." style="">UnDraw</h3> <p class="description svelte-zslw0j">The design project with open-source illustrations for any idea you can imagine and create.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://undraw.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://absurd.design/&amp;size=32" alt="Absurd Illustrations" class="svelte-zslw0j"></span> </div> <a href="https://absurd.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Absurd Illustrations 
With this project, they try to introduce a new way and visual perception for websites, presentations, apps, articles… everything!" style="">Absurd Illustrations</h3> <p class="description svelte-zslw0j">With this project, they try to introduce a new way and visual perception for websites, presentations, apps, articles… everything!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://absurd.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icons8.com/illustrations&amp;size=32" alt="Ouch!" class="svelte-zslw0j"></span> </div> <a href="https://icons8.com/illustrations" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ouch! 
Free vector and 3D illustrations." style="">Ouch!</h3> <p class="description svelte-zslw0j">Free vector and 3D illustrations.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icons8.com/illustrations" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.humaaans.com/&amp;size=32" alt="Humaaans" class="svelte-zslw0j"></span> </div> <a href="https://www.humaaans.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Humaaans 
Mix-&amp;-match illustrations of people with a design library" style="">Humaaans</h3> <p class="description svelte-zslw0j">Mix-&amp;-match illustrations of people with a design library</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.humaaans.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iradesign.io/&amp;size=32" alt="IRA Design" class="svelte-zslw0j"></span> </div> <a href="https://iradesign.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="IRA Design 
Ira Design comes with a great variety of ready-to-use examples made with gradients." style="">IRA Design</h3> <p class="description svelte-zslw0j">Ira Design comes with a great variety of ready-to-use examples made with gradients.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iradesign.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://interfacer.xyz/&amp;size=32" alt="Interfacer" class="svelte-zslw0j"></span> </div> <a href="https://interfacer.xyz/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Interfacer 
Interfacer is a collection of 300+ free design resources found on the Web." style="">Interfacer</h3> <p class="description svelte-zslw0j">Interfacer is a collection of 300+ free design resources found on the Web.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://interfacer.xyz/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://freebiesupply.com/&amp;size=32" alt="Freebie Supply" class="svelte-zslw0j"></span> </div> <a href="https://freebiesupply.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Freebie Supply 
Free, high-quality design resources for Photoshop, Sketch, Illustrator, Adobe XD and Figma" style="">Freebie Supply</h3> <p class="description svelte-zslw0j">Free, high-quality design resources for Photoshop, Sketch, Illustrator, Adobe XD and Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://freebiesupply.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.blackillustrations.com/&amp;size=32" alt="Black Illustrations" class="svelte-zslw0j"></span> </div> <a href="https://www.blackillustrations.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Black Illustrations 
Black illustrations is a series of FREE digital designs of black people for your next online project. Free for commercial and personal use." style="">Black Illustrations</h3> <p class="description svelte-zslw0j">Black illustrations is a series of FREE digital designs of black people for your next online project. Free for commercial and personal use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.blackillustrations.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://designstripe.com/&amp;size=32" alt="Designstripe" class="svelte-zslw0j"></span> </div> <a href="https://designstripe.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Designstripe 
Create beautiful illustrations, no design skills needed." style="">Designstripe</h3> <p class="description svelte-zslw0j">Create beautiful illustrations, no design skills needed.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://designstripe.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://error404.fun/&amp;size=32" alt="404 Illustrations" class="svelte-zslw0j"></span> </div> <a href="https://error404.fun/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="404 Illustrations 
Royalty free illustrations for 404 pages." style="">404 Illustrations</h3> <p class="description svelte-zslw0j">Royalty free illustrations for 404 pages.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://error404.fun/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://stubborn.fun/&amp;size=32" alt="Stubborn" class="svelte-zslw0j"></span> </div> <a href="https://stubborn.fun/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stubborn 
Free illustrations constructor for Figma &amp; Sketch." style="">Stubborn</h3> <p class="description svelte-zslw0j">Free illustrations constructor for Figma &amp; Sketch.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://stubborn.fun/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://doodleipsum.com/&amp;size=32" alt="Doodle Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://doodleipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Doodle Ipsum 
The lorem ipsum of illustrations, just customize your doodles." style="">Doodle Ipsum</h3> <p class="description svelte-zslw0j">The lorem ipsum of illustrations, just customize your doodles.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://doodleipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://usesmash.com/&amp;size=32" alt="Smash" class="svelte-zslw0j"></span> </div> <a href="https://usesmash.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Smash 
Awesome illustration constructor with colorful and trendy characters." style="">Smash</h3> <p class="description svelte-zslw0j">Awesome illustration constructor with colorful and trendy characters.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://usesmash.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://control.rocks/&amp;size=32" alt="Control" class="svelte-zslw0j"></span> </div> <a href="https://control.rocks/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Control 
Combo set of 108 customizable illustrations." style="">Control</h3> <p class="description svelte-zslw0j">Combo set of 108 customizable illustrations.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://control.rocks/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://storyset.com/&amp;size=32" alt="Storyset" class="svelte-zslw0j"></span> </div> <a href="https://storyset.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Storyset 
Edit and animate all our customizable illustrations to enhance your projects totally free. Start now to be creative in our online editor." style="">Storyset</h3> <p class="description svelte-zslw0j">Edit and animate all our customizable illustrations to enhance your projects totally free. Start now to be creative in our online editor.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://storyset.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://niceillustrations.com/&amp;size=32" alt="Nice Illustrations" class="svelte-zslw0j"></span> </div> <a href="https://niceillustrations.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Nice Illustrations 
Nice Illustrations is the ultimate library of royalty free illustrations you can use for your design projects. Click to download hundreds of free ..." style="">Nice Illustrations</h3> <p class="description svelte-zslw0j">Nice Illustrations is the ultimate library of royalty free illustrations you can use for your design projects. Click to download hundreds of free ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://niceillustrations.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pixeltrue.com/free-illustrations&amp;size=32" alt="Pixeltrue" class="svelte-zslw0j"></span> </div> <a href="https://www.pixeltrue.com/free-illustrations" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pixeltrue 
High-quality SVG illustrations &amp; Lottie animations in 12 different styles. Supercharge your website, newsletters, blogs and e-books with high-quality ..." style="">Pixeltrue</h3> <p class="description svelte-zslw0j">High-quality SVG illustrations &amp; Lottie animations in 12 different styles. Supercharge your website, newsletters, blogs and e-books with high-quality ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pixeltrue.com/free-illustrations" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://weareskribbl.com/&amp;size=32" alt="Skribbl" class="svelte-zslw0j"></span> </div> <a href="https://weareskribbl.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Skribbl 
A growing collection of freely-usable, hand-drawn illustrations brought to you by a global community of aspiring creatives. You can use our illustrations for ..." style="">Skribbl</h3> <p class="description svelte-zslw0j">A growing collection of freely-usable, hand-drawn illustrations brought to you by a global community of aspiring creatives. You can use our illustrations for ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://weareskribbl.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://opendoodles.com/&amp;size=32" alt="Open Doodles" class="svelte-zslw0j"></span> </div> <a href="https://opendoodles.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Open Doodles 
A library of sketchy illustrations of people free for personal and commercial use." style="">Open Doodles</h3> <p class="description svelte-zslw0j">A library of sketchy illustrations of people free for personal and commercial use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://opendoodles.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://alohe.github.io/emojicloud/&amp;size=32" alt="Emoji cloud" class="svelte-zslw0j"></span> </div> <a href="https://alohe.github.io/emojicloud/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Emoji cloud 
Emoji cloud. A CDN for SVG emoji's. Airplane. Angry face. Anguished face. Anxious face with sweat. Astonished face. Avocado. Backhand index pointing down ..." style="">Emoji cloud</h3> <p class="description svelte-zslw0j">Emoji cloud. A CDN for SVG emoji's. Airplane. Angry face. Anguished face. Anxious face with sweat. Astonished face. Avocado. Backhand index pointing down ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://alohe.github.io/emojicloud/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://blush.design/&amp;size=32" alt="Blush" class="svelte-zslw0j"></span> </div> <a href="https://blush.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Blush 
Blush makes it easy to add free illustrations to your designs. Play with fully customizable graphics made by artists across the globe." style="">Blush</h3> <p class="description svelte-zslw0j">Blush makes it easy to add free illustrations to your designs. Play with fully customizable graphics made by artists across the globe.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://blush.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://app.haikei.app/&amp;size=32" alt="Haikei" class="svelte-zslw0j"></span> </div> <a href="https://app.haikei.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Haikei 
Haikei is a web app to generate unique SVG shapes, backgrounds, and patterns – ready to use with your design tools and workflow. Start designing for free." style="">Haikei</h3> <p class="description svelte-zslw0j">Haikei is a web app to generate unique SVG shapes, backgrounds, and patterns – ready to use with your design tools and workflow. Start designing for free.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://app.haikei.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.thedoodlelibrary.com/&amp;size=32" alt="The Doodle Library" class="svelte-zslw0j"></span> </div> <a href="https://www.thedoodlelibrary.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="The Doodle Library 
Increase comprehension, retention, and delight audiences with hundreds of unique hand drawn SVG line art doodles and animated PNGs." style="">The Doodle Library</h3> <p class="description svelte-zslw0j">Increase comprehension, retention, and delight audiences with hundreds of unique hand drawn SVG line art doodles and animated PNGs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.thedoodlelibrary.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://cocomaterial.com/&amp;size=32" alt="Coco Material" class="svelte-zslw0j"></span> </div> <a href="https://cocomaterial.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Coco Material 
Discover CocoMaterial, the Open Source hand-drawn illustration library with 1,358 images. Customize &amp; download! Search. Person thinking illustration ..." style="">Coco Material</h3> <p class="description svelte-zslw0j">Discover CocoMaterial, the Open Source hand-drawn illustration library with 1,358 images. Customize &amp; download! Search. Person thinking illustration ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://cocomaterial.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://personas.draftbit.com/&amp;size=32" alt="Personas Avatar Generator" class="svelte-zslw0j"></span> </div> <a href="https://personas.draftbit.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Personas Avatar Generator 
A playful avatar generator for the modern age. Randomize. SKIN. HAIR. FACIAL HAIR. BODY. EYES. MOUTH. NOSE. BACKGROUND. Download Avatar." style="">Personas Avatar Generator</h3> <p class="description svelte-zslw0j">A playful avatar generator for the modern age. Randomize. SKIN. HAIR. FACIAL HAIR. BODY. EYES. MOUTH. NOSE. BACKGROUND. Download Avatar.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://personas.draftbit.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://openpeeps.com/&amp;size=32" alt="Open Peeps" class="svelte-zslw0j"></span> </div> <a href="https://openpeeps.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Open Peeps 
Open Peeps is a hand-drawn illustration library to create scenes of people. You can use them in product illustration, marketing, comics, product states, .." style="">Open Peeps</h3> <p class="description svelte-zslw0j">Open Peeps is a hand-drawn illustration library to create scenes of people. You can use them in product illustration, marketing, comics, product states, ..</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://openpeeps.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://shape.so/&amp;size=32" alt="Shape" class="svelte-zslw0j"></span> </div> <a href="https://shape.so/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Shape 
36000+ Icons &amp; Illustrations to SVG, Lottie, React. Shape lets you customize the style, colors and border of static &amp; animated icons and illustrations." style="">Shape</h3> <p class="description svelte-zslw0j">36000+ Icons &amp; Illustrations to SVG, Lottie, React. Shape lets you customize the style, colors and border of static &amp; animated icons and illustrations.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://shape.so/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://overflow.design/ec.html&amp;size=32" alt="Ecommerce Club" class="svelte-zslw0j"></span> </div> <a href="https://overflow.design/ec.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ecommerce Club 
Notion style e-commerce and payment illustrations." style="">Ecommerce Club</h3> <p class="description svelte-zslw0j">Notion style e-commerce and payment illustrations.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://overflow.design/ec.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


figma_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.academy/&amp;size=32" alt="Figma Academy" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.academy/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figma Academy 
Learn advanced design tactics directly in Figma" style="">Figma Academy</h3> <p class="description svelte-zslw0j">Learn advanced design tactics directly in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.academy/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://automator.design/&amp;size=32" alt="Automator for Figma" class="svelte-zslw0j"></span> </div> <a href="https://automator.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Automator for Figma 
Automate your Figma tasks in one click" style="">Automator for Figma</h3> <p class="description svelte-zslw0j">Automate your Figma tasks in one click</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://automator.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.getfigit.com/&amp;size=32" alt="Figit" class="svelte-zslw0j"></span> </div> <a href="https://www.getfigit.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figit 
Supercharge Your workflow" style="">Figit</h3> <p class="description svelte-zslw0j">Supercharge Your workflow</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.getfigit.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/951652764251042235/All-Hands-Mockup-Generator-%7C-MetaLab-x-Nappy&amp;size=32" alt="All Hands Figma Plugin" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/951652764251042235/All-Hands-Mockup-Generator-%7C-MetaLab-x-Nappy" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="All Hands Figma Plugin 
The easiest way to diversify your product mockups" style="">All Hands Figma Plugin</h3> <p class="description svelte-zslw0j">The easiest way to diversify your product mockups</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/951652764251042235/All-Hands-Mockup-Generator-%7C-MetaLab-x-Nappy" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.meshgradients.com/figma&amp;size=32" alt="Mesh Gradients" class="svelte-zslw0j"></span> </div> <a href="https://www.meshgradients.com/figma" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mesh Gradients 
Create awesome mesh gradients right in Figma" style="">Mesh Gradients</h3> <p class="description svelte-zslw0j">Create awesome mesh gradients right in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.meshgradients.com/figma" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://figment.so/&amp;size=32" alt="Figment" class="svelte-zslw0j"></span> </div> <a href="https://figment.so/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figment 
Create a Website from any Figma design" style="">Figment</h3> <p class="description svelte-zslw0j">Create a Website from any Figma design</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://figment.so/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/952689592792995578/Scribe&amp;size=32" alt="Scribe" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/952689592792995578/Scribe" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Scribe 
The mail merge for Figma for crafting data-driven graphics" style="">Scribe</h3> <p class="description svelte-zslw0j">The mail merge for Figma for crafting data-driven graphics</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/952689592792995578/Scribe" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1068276416739369342/Physical&amp;size=32" alt="Physical" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1068276416739369342/Physical" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Physical 
View your design at 100% physical scale" style="">Physical</h3> <p class="description svelte-zslw0j">View your design at 100% physical scale</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1068276416739369342/Physical" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1068093559622021183/Mini-Photo-Editor&amp;size=32" alt="Mini Photo Editor" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1068093559622021183/Mini-Photo-Editor" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mini Photo Editor 
Quickly crop, rotate, flip, finetune, and redact images" style="">Mini Photo Editor</h3> <p class="description svelte-zslw0j">Quickly crop, rotate, flip, finetune, and redact images</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1068093559622021183/Mini-Photo-Editor" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://drawkit.com/3d-builder&amp;size=32" alt="DrawKit 3D Builder" class="svelte-zslw0j"></span> </div> <a href="https://drawkit.com/3d-builder" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="DrawKit 3D Builder 
Build beautiful 3D scenes for any projects easily" style="">DrawKit 3D Builder</h3> <p class="description svelte-zslw0j">Build beautiful 3D scenes for any projects easily</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://drawkit.com/3d-builder" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://run.gumroad.com/l/DesignAnatomy&amp;size=32" alt="Design Anatomy" class="svelte-zslw0j"></span> </div> <a href="https://run.gumroad.com/l/DesignAnatomy" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Anatomy 
Figma Design System Generator with root components." style="">Design Anatomy</h3> <p class="description svelte-zslw0j">Figma Design System Generator with root components.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://run.gumroad.com/l/DesignAnatomy" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1049715741730726129/Amounter&amp;size=32" alt="Amounter" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1049715741730726129/Amounter" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Amounter 
Figma plugin to generate properly formatted currencies" style="">Amounter</h3> <p class="description svelte-zslw0j">Figma plugin to generate properly formatted currencies</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1049715741730726129/Amounter" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/file/1057608352816733790&amp;size=32" alt="Lockscreen Tasks" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/file/1057608352816733790" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lockscreen Tasks 
See your tasks list on your lock screen" style="">Lockscreen Tasks</h3> <p class="description svelte-zslw0j">See your tasks list on your lock screen</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/file/1057608352816733790" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ui-lib.com/downloads/uko-ui-figma-design-system/&amp;size=32" alt="UKO" class="svelte-zslw0j"></span> </div> <a href="https://ui-lib.com/downloads/uko-ui-figma-design-system/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UKO 
Free Figma dashboards &amp; design system" style="">UKO</h3> <p class="description svelte-zslw0j">Free Figma dashboards &amp; design system</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ui-lib.com/downloads/uko-ui-figma-design-system/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dlex.io/products/marketing-components-figma&amp;size=32" alt="Marketing Components" class="svelte-zslw0j"></span> </div> <a href="https://dlex.io/products/marketing-components-figma" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Marketing Components 
Landing sections library for Figma" style="">Marketing Components</h3> <p class="description svelte-zslw0j">Landing sections library for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dlex.io/products/marketing-components-figma" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1040340750434492789/Text-Volume&amp;size=32" alt="Text Volume plugin" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1040340750434492789/Text-Volume" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Text Volume plugin 
Find how much text is in any design" style="">Text Volume plugin</h3> <p class="description svelte-zslw0j">Find how much text is in any design</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1040340750434492789/Text-Volume" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/941336520474170939/Moodz&amp;size=32" alt="Moodz" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/941336520474170939/Moodz" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Moodz 
Mood Board plugin for Figma" style="">Moodz</h3> <p class="description svelte-zslw0j">Mood Board plugin for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/941336520474170939/Moodz" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://darkvader.zerox.me/&amp;size=32" alt="Dark Vader for Figma" class="svelte-zslw0j"></span> </div> <a href="https://darkvader.zerox.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dark Vader for Figma 
Design in one theme &amp; automate the rest" style="">Dark Vader for Figma</h3> <p class="description svelte-zslw0j">Design in one theme &amp; automate the rest</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://darkvader.zerox.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1027629657711671993/Spirous&amp;size=32" alt="Spirous" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1027629657711671993/Spirous" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Spirous 
Figma plugin to create spirograph patterns" style="">Spirous</h3> <p class="description svelte-zslw0j">Figma plugin to create spirograph patterns</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1027629657711671993/Spirous" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icons8.com/lunacy&amp;size=32" alt="Lunacy" class="svelte-zslw0j"></span> </div> <a href="https://icons8.com/lunacy" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lunacy 
Cross-platform app, faster than Figma, smarter than Sketch" style="">Lunacy</h3> <p class="description svelte-zslw0j">Cross-platform app, faster than Figma, smarter than Sketch</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icons8.com/lunacy" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://bm.khagwal.co/&amp;size=32" alt="Bookmark" class="svelte-zslw0j"></span> </div> <a href="https://bm.khagwal.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Bookmark 
Keep all your files and links organised right inside Figma" style="">Bookmark</h3> <p class="description svelte-zslw0j">Keep all your files and links organised right inside Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://bm.khagwal.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uidesigndaily.gumroad.com/l/zaqBU&amp;size=32" alt="Ventana UI Kit" class="svelte-zslw0j"></span> </div> <a href="https://uidesigndaily.gumroad.com/l/zaqBU" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ventana UI Kit 
Web application UI kit created in Figma" style="">Ventana UI Kit</h3> <p class="description svelte-zslw0j">Web application UI kit created in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uidesigndaily.gumroad.com/l/zaqBU" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/widget/1030161589655245054&amp;size=32" alt="Stark for FigJam" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/widget/1030161589655245054" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stark for FigJam 
Accessibility whiteboarding meets FigJam" style="">Stark for FigJam</h3> <p class="description svelte-zslw0j">Accessibility whiteboarding meets FigJam</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/widget/1030161589655245054" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1021879782774011952/Protofly?utm_source=product_hunt&amp;utm_medium=homepage&amp;utm_campaign=launch&amp;size=32" alt="Protofly" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1021879782774011952/Protofly?utm_source=product_hunt&amp;utm_medium=homepage&amp;utm_campaign=launch" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Protofly 
Create, save and reuse prototype interactions in Figma" style="">Protofly</h3> <p class="description svelte-zslw0j">Create, save and reuse prototype interactions in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1021879782774011952/Protofly?utm_source=product_hunt&amp;utm_medium=homepage&amp;utm_campaign=launch" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://figmaop.netlify.app/&amp;size=32" alt="FigmaOP" class="svelte-zslw0j"></span> </div> <a href="https://figmaop.netlify.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FigmaOP 
Set of open source Figma plugins" style="">FigmaOP</h3> <p class="description svelte-zslw0j">Set of open source Figma plugins</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://figmaop.netlify.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1021499620946646699/Warp-Tools&amp;size=32" alt="Warp Tools" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1021499620946646699/Warp-Tools" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Warp Tools 
Smudge, twirl, pinch, arc and free transform tools for Figma" style="">Warp Tools</h3> <p class="description svelte-zslw0j">Smudge, twirl, pinch, arc and free transform tools for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1021499620946646699/Warp-Tools" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/1002305807367001638/Figsplosion&amp;size=32" alt="Figsplosion" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/1002305807367001638/Figsplosion" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figsplosion 
Blow off steam by blowing up your Figma designs!" style="">Figsplosion</h3> <p class="description svelte-zslw0j">Blow off steam by blowing up your Figma designs!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/1002305807367001638/Figsplosion" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.thepentool.co/handy-components&amp;size=32" alt="Handy components" class="svelte-zslw0j"></span> </div> <a href="https://www.thepentool.co/handy-components" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Handy components 
Figma plugin to instantly drop components with auto layout " style="">Handy components</h3> <p class="description svelte-zslw0j">Figma plugin to instantly drop components with auto layout </p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.thepentool.co/handy-components" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.behance.net/gallery/126690167/eData-v10&amp;size=32" alt="eData Library" class="svelte-zslw0j"></span> </div> <a href="https://www.behance.net/gallery/126690167/eData-v10" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="eData Library 
Charts and graphs for Figma" style="">eData Library</h3> <p class="description svelte-zslw0j">Charts and graphs for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.behance.net/gallery/126690167/eData-v10" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.cabanaforfigma.com/&amp;size=32" alt="Cabana 5 Design System for Figma" class="svelte-zslw0j"></span> </div> <a href="https://www.cabanaforfigma.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Cabana 5 Design System for Figma 
Design System for Figma" style="">Cabana 5 Design System for Figma</h3> <p class="description svelte-zslw0j">Design System for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.cabanaforfigma.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/990910408295947511/Lazy-Load&amp;size=32" alt="Lazy Load" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/990910408295947511/Lazy-Load" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lazy Load 
Convert Figma screens into loading skeleton" style="">Lazy Load</h3> <p class="description svelte-zslw0j">Convert Figma screens into loading skeleton</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/990910408295947511/Lazy-Load" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://iamrahulrao.gumroad.com/l/olson-style-guide&amp;size=32" alt="Olson Brand Guide for Figma" class="svelte-zslw0j"></span> </div> <a href="https://iamrahulrao.gumroad.com/l/olson-style-guide" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Olson Brand Guide for Figma 
A style guide generator using Figma components" style="">Olson Brand Guide for Figma</h3> <p class="description svelte-zslw0j">A style guide generator using Figma components</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://iamrahulrao.gumroad.com/l/olson-style-guide" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/997126103738146818/HEIC-Import?ref=producthunt&amp;size=32" alt="HEIC Image Import" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/997126103738146818/HEIC-Import?ref=producthunt" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="HEIC Image Import 
Import .HEIC images into Figma as PNG, JPEG or GIF." style="">HEIC Image Import</h3> <p class="description svelte-zslw0j">Import .HEIC images into Figma as PNG, JPEG or GIF.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/997126103738146818/HEIC-Import?ref=producthunt" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://quickrdesignsystem.com/&amp;size=32" alt="Quickr Design System" class="svelte-zslw0j"></span> </div> <a href="https://quickrdesignsystem.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Quickr Design System 
2000+ Figma components library to design web app &amp; SaaS" style="">Quickr Design System</h3> <p class="description svelte-zslw0j">2000+ Figma components library to design web app &amp; SaaS</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://quickrdesignsystem.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://graphicle.notion.site/graphicle/Startup-Pitch-Deck-Figma-Template-f99206b2fa6c4a6b817748b7616792b9&amp;size=32" alt="Startup Pitch Deck" class="svelte-zslw0j"></span> </div> <a href="https://graphicle.notion.site/graphicle/Startup-Pitch-Deck-Figma-Template-f99206b2fa6c4a6b817748b7616792b9" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Startup Pitch Deck 
An all-in-one Figma template for your startup pitch deck" style="">Startup Pitch Deck</h3> <p class="description svelte-zslw0j">An all-in-one Figma template for your startup pitch deck</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://graphicle.notion.site/graphicle/Startup-Pitch-Deck-Figma-Template-f99206b2fa6c4a6b817748b7616792b9" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://maleksander.gumroad.com/l/uxrkit&amp;size=32" alt="UX and Research Kit for Figma" class="svelte-zslw0j"></span> </div> <a href="https://maleksander.gumroad.com/l/uxrkit" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX and Research Kit for Figma 
You can add great-looking research docs next to your designs" style="">UX and Research Kit for Figma</h3> <p class="description svelte-zslw0j">You can add great-looking research docs next to your designs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://maleksander.gumroad.com/l/uxrkit" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sketchkeys.com/&amp;size=32" alt="SketchKeys" class="svelte-zslw0j"></span> </div> <a href="https://sketchkeys.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="SketchKeys 
Keyboard stickers for Figma, Notion, Sketch, etc." style="">SketchKeys</h3> <p class="description svelte-zslw0j">Keyboard stickers for Figma, Notion, Sketch, etc.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sketchkeys.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/990407184454470770/Procreate-Import&amp;size=32" alt="Procreate Import for Figma" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/990407184454470770/Procreate-Import" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Procreate Import for Figma 
Import your .procreate files into Figma." style="">Procreate Import for Figma</h3> <p class="description svelte-zslw0j">Import your .procreate files into Figma.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/990407184454470770/Procreate-Import" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://browserfigma.com/&amp;size=32" alt="Browser Kit for Figma" class="svelte-zslw0j"></span> </div> <a href="https://browserfigma.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Browser Kit for Figma 
One smart component to rule them all" style="">Browser Kit for Figma</h3> <p class="description svelte-zslw0j">One smart component to rule them all</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://browserfigma.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://venusdesignsystem.com/cgi-sys/suspendedpage.cgi&amp;size=32" alt="Venus Dashboard Builder" class="svelte-zslw0j"></span> </div> <a href="https://venusdesignsystem.com/cgi-sys/suspendedpage.cgi" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Venus Dashboard Builder 
Premium dashboard builder for Figma based on Venus Design" style="">Venus Dashboard Builder</h3> <p class="description svelte-zslw0j">Premium dashboard builder for Figma based on Venus Design</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://venusdesignsystem.com/cgi-sys/suspendedpage.cgi" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://store.123d.one/l/universal-data-visualization&amp;size=32" alt="Universal Data Visualization 1.0" class="svelte-zslw0j"></span> </div> <a href="https://store.123d.one/l/universal-data-visualization" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Universal Data Visualization 1.0 
Charts and infographics constructor in Figma" style="">Universal Data Visualization 1.0</h3> <p class="description svelte-zslw0j">Charts and infographics constructor in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://store.123d.one/l/universal-data-visualization" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.vuetifyforfigma.com/&amp;size=32" alt="Vuetify for Figma" class="svelte-zslw0j"></span> </div> <a href="https://www.vuetifyforfigma.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Vuetify for Figma 
A huge component library now available for Figma" style="">Vuetify for Figma</h3> <p class="description svelte-zslw0j">A huge component library now available for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.vuetifyforfigma.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://resume.gg/&amp;size=32" alt="Resume" class="svelte-zslw0j"></span> </div> <a href="https://resume.gg/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Resume 
10+ free resume templates for Figma" style="">Resume</h3> <p class="description svelte-zslw0j">10+ free resume templates for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://resume.gg/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://despoth.gumroad.com/l/full-ios-ui-kit&amp;size=32" alt="Full iOS 15 UI Kit " class="svelte-zslw0j"></span> </div> <a href="https://despoth.gumroad.com/l/full-ios-ui-kit" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Full iOS 15 UI Kit  
Design System for mobile apps creators in Figma" style="">Full iOS 15 UI Kit </h3> <p class="description svelte-zslw0j">Design System for mobile apps creators in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://despoth.gumroad.com/l/full-ios-ui-kit" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.nextmockup.com/product/email-shots-1b4d4f9a090344c8952ef8ba3b8cbaf1&amp;size=32" alt="Email &amp; Newsletter Designs" class="svelte-zslw0j"></span> </div> <a href="https://www.nextmockup.com/product/email-shots-1b4d4f9a090344c8952ef8ba3b8cbaf1" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Email &amp; Newsletter Designs 
Multi-purpose Figma designs for email and newsletter" style="">Email &amp; Newsletter Designs</h3> <p class="description svelte-zslw0j">Multi-purpose Figma designs for email and newsletter</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.nextmockup.com/product/email-shots-1b4d4f9a090344c8952ef8ba3b8cbaf1" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/961270034818256057/Jitter-%C2%B7-Animate-your-Figma-designs&amp;size=32" alt="Jitter" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/961270034818256057/Jitter-%C2%B7-Animate-your-Figma-designs" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Jitter 
Animate your Figma designs in Jitter, easily" style="">Jitter</h3> <p class="description svelte-zslw0j">Animate your Figma designs in Jitter, easily</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/961270034818256057/Jitter-%C2%B7-Animate-your-Figma-designs" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/973621811122426089/Figma-Tips&amp;size=32" alt="Figma Tips Plugin" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/973621811122426089/Figma-Tips" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figma Tips Plugin 
Watch short tutorials on Figma, while designing in Figma!" style="">Figma Tips Plugin</h3> <p class="description svelte-zslw0j">Watch short tutorials on Figma, while designing in Figma!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/973621811122426089/Figma-Tips" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/878338850782783595/GIF-Export&amp;size=32" alt="GIF Export" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/878338850782783595/GIF-Export" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="GIF Export 
Export GIFs from Figma" style="">GIF Export</h3> <p class="description svelte-zslw0j">Export GIFs from Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/878338850782783595/GIF-Export" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://modulesystem.design/&amp;size=32" alt="Module" class="svelte-zslw0j"></span> </div> <a href="https://modulesystem.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Module 
Drag and drop design system for Figma" style="">Module</h3> <p class="description svelte-zslw0j">Drag and drop design system for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://modulesystem.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sliday.gumroad.com/l/ebook-ui-kit-for-figma&amp;size=32" alt="eBook Kit for Figma" class="svelte-zslw0j"></span> </div> <a href="https://sliday.gumroad.com/l/ebook-ui-kit-for-figma" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="eBook Kit for Figma 
Build and sell your ebook in minutes, not days" style="">eBook Kit for Figma</h3> <p class="description svelte-zslw0j">Build and sell your ebook in minutes, not days</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sliday.gumroad.com/l/ebook-ui-kit-for-figma" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://duckly.com/&amp;size=32" alt="Duckly" class="svelte-zslw0j"></span> </div> <a href="https://duckly.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Duckly 
Collaborate on any page with a Figma-like experience" style="">Duckly</h3> <p class="description svelte-zslw0j">Collaborate on any page with a Figma-like experience</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://duckly.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figmaster.co/&amp;size=32" alt="Figmaster" class="svelte-zslw0j"></span> </div> <a href="https://www.figmaster.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figmaster 
Build your design system by doing exercises in Figma" style="">Figmaster</h3> <p class="description svelte-zslw0j">Build your design system by doing exercises in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figmaster.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.bicaforfigma.com/&amp;size=32" alt="Bica for Figma 3.0" class="svelte-zslw0j"></span> </div> <a href="https://www.bicaforfigma.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Bica for Figma 3.0 
A flexible UI starter kit for Figma" style="">Bica for Figma 3.0</h3> <p class="description svelte-zslw0j">A flexible UI starter kit for Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.bicaforfigma.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://stratumkit.com/&amp;size=32" alt="Stratum UI Design Kit for Figma" class="svelte-zslw0j"></span> </div> <a href="https://stratumkit.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stratum UI Design Kit for Figma 
Turn into UI maestro with 9000+ life-saving components" style="">Stratum UI Design Kit for Figma</h3> <p class="description svelte-zslw0j">Turn into UI maestro with 9000+ life-saving components</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://stratumkit.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pixsellz.io/figma-design-system&amp;size=32" alt="Figma Design System" class="svelte-zslw0j"></span> </div> <a href="https://www.pixsellz.io/figma-design-system" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figma Design System 
Starter kit for your UI design projects in Figma" style="">Figma Design System</h3> <p class="description svelte-zslw0j">Starter kit for your UI design projects in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pixsellz.io/figma-design-system" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/community/plugin/963138214942646066/QR-Coder&amp;size=32" alt="QR Coder" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/community/plugin/963138214942646066/QR-Coder" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="QR Coder 
Generate QR codes with urls and insert into Figma." style="">QR Coder</h3> <p class="description svelte-zslw0j">Generate QR codes with urls and insert into Figma.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/community/plugin/963138214942646066/QR-Coder" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.phigma.app/&amp;size=32" alt="Phigma" class="svelte-zslw0j"></span> </div> <a href="https://www.phigma.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Phigma 
100+ Figma templates for your Product Hunt images" style="">Phigma</h3> <p class="description svelte-zslw0j">100+ Figma templates for your Product Hunt images</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.phigma.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designencyclopedia.io/&amp;size=32" alt="The Design Encyclopedia for Figma" class="svelte-zslw0j"></span> </div> <a href="https://www.designencyclopedia.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="The Design Encyclopedia for Figma 
The world's largest Figma UI kit." style="">The Design Encyclopedia for Figma</h3> <p class="description svelte-zslw0j">The world's largest Figma UI kit.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designencyclopedia.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.token-master.com/&amp;size=32" alt="Token Master" class="svelte-zslw0j"></span> </div> <a href="https://www.token-master.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Token Master 
Edit design tokens and create new color modes in Figma" style="">Token Master</h3> <p class="description svelte-zslw0j">Edit design tokens and create new color modes in Figma</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.token-master.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorspectrum.design/&amp;size=32" alt="Spectrum: Figma Plugin &amp; Web App" class="svelte-zslw0j"></span> </div> <a href="https://colorspectrum.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Spectrum: Figma Plugin &amp; Web App 
Generate color palettes and apply instantly to anything!" style="">Spectrum: Figma Plugin &amp; Web App</h3> <p class="description svelte-zslw0j">Generate color palettes and apply instantly to anything!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorspectrum.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


typography_html_content =''' 
<ul class="rs-list svelte-4h59nz"> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=/&amp;size=32" alt="WordMark" class="svelte-zslw0j"></span> </div> <a href="https://wordmark.it/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="WordMark 
Wordmark.it helps you choose fonts by quickly displaying your text with your fonts." style="">WordMark</h3> <p class="description svelte-zslw0j">Wordmark.it helps you choose fonts by quickly displaying your text with your fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://wordmark.it/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li>   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fonts.google.com/&amp;size=32" alt="Google Fonts" class="svelte-zslw0j"></span> </div> <a href="https://fonts.google.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Google Fonts 
Making the web more beautiful, fast, and open through great typography." style="">Google Fonts</h3> <p class="description svelte-zslw0j">Making the web more beautiful, fast, and open through great typography.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fonts.google.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dafont.com&amp;size=32" alt="Dafont" class="svelte-zslw0j"></span> </div> <a href="https://dafont.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dafont 
Archive of freely downloadable fonts. Browse by alphabetical listing, by style, by author or by popularity." style="">Dafont</h3> <p class="description svelte-zslw0j">Archive of freely downloadable fonts. Browse by alphabetical listing, by style, by author or by popularity.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dafont.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.typewolf.com/&amp;size=32" alt="Typewolf" class="svelte-zslw0j"></span> </div> <a href="https://www.typewolf.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Typewolf 
Typewolf helps designers choose the perfect font combination for their next design project—features web fonts in the wild, font recommendations and learning resources." style="">Typewolf</h3> <p class="description svelte-zslw0j">Typewolf helps designers choose the perfect font combination for their next design project—features web fonts in the wild, font recommendations and learning resources.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.typewolf.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontba.se/&amp;size=32" alt="Font Base" class="svelte-zslw0j"></span> </div> <a href="https://fontba.se/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Base 
FontBase is the font manager of the new generation, built by designers, for designers." style="">Font Base</h3> <p class="description svelte-zslw0j">FontBase is the font manager of the new generation, built by designers, for designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontba.se/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fontsquirrel.com/&amp;size=32" alt="Font Squirrel" class="svelte-zslw0j"></span> </div> <a href="https://www.fontsquirrel.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Squirrel 
Free fonts have met their match. We know how hard it is to find quality freeware that is licensed for commercial work. We've done the hard work, hand-selecting these typefaces and presenting them in an easy-to-use format. " style="">Font Squirrel</h3> <p class="description svelte-zslw0j">Free fonts have met their match. We know how hard it is to find quality freeware that is licensed for commercial work. We've done the hard work, hand-selecting these typefaces and presenting them in an easy-to-use format. </p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fontsquirrel.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://typeanything.io/&amp;size=32" alt="Type Anything" class="svelte-zslw0j"></span> </div> <a href="https://typeanything.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Type Anything 
Type Anything is a free and awesome typography tool to create and test font combinations for your projects." style="">Type Anything</h3> <p class="description svelte-zslw0j">Type Anything is a free and awesome typography tool to create and test font combinations for your projects.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://typeanything.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://typ.io/&amp;size=32" alt="Typ.io" class="svelte-zslw0j"></span> </div> <a href="https://typ.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Typ.io 
Be better at typography." style="">Typ.io</h3> <p class="description svelte-zslw0j">Be better at typography.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://typ.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontsinuse.com/&amp;size=32" alt="Fonts in Use" class="svelte-zslw0j"></span> </div> <a href="https://fontsinuse.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fonts in Use 
An independent archive of typography." style="">Fonts in Use</h3> <p class="description svelte-zslw0j">An independent archive of typography.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontsinuse.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.myfonts.com/WhatTheFont/&amp;size=32" alt="What the Font" class="svelte-zslw0j"></span> </div> <a href="https://www.myfonts.com/WhatTheFont/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="What the Font 
Instant font identification powered by the world’s largest collection of fonts." style="">What the Font</h3> <p class="description svelte-zslw0j">Instant font identification powered by the world’s largest collection of fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.myfonts.com/WhatTheFont/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fontspring.com/matcherator&amp;size=32" alt="Font Matcherator" class="svelte-zslw0j"></span> </div> <a href="https://www.fontspring.com/matcherator" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Matcherator 
Have an image with type and you don't know what the font is? Upload it and we’ll find the fonts that match." style="">Font Matcherator</h3> <p class="description svelte-zslw0j">Have an image with type and you don't know what the font is? Upload it and we’ll find the fonts that match.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fontspring.com/matcherator" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontpair.co/&amp;size=32" alt="Font Pair" class="svelte-zslw0j"></span> </div> <a href="https://fontpair.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Pair 
Font Pair helps designers pair Google Fonts together. Beautiful Google Font combinations and pairs." style="">Font Pair</h3> <p class="description svelte-zslw0j">Font Pair helps designers pair Google Fonts together. Beautiful Google Font combinations and pairs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontpair.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fontreach.com/&amp;size=32" alt="Font Reach" class="svelte-zslw0j"></span> </div> <a href="https://www.fontreach.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Reach 
FontReach scans the top million sites to show font usage across the web." style="">Font Reach</h3> <p class="description svelte-zslw0j">FontReach scans the top million sites to show font usage across the web.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fontreach.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://glyphsapp.com/&amp;size=32" alt="Glyphs" class="svelte-zslw0j"></span> </div> <a href="https://glyphsapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Glyphs 
Make everything from dingbat webfonts to full-fledged text typefaces in the most Mac-like font editor." style="">Glyphs</h3> <p class="description svelte-zslw0j">Make everything from dingbat webfonts to full-fledged text typefaces in the most Mac-like font editor.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://glyphsapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontdatabase.app/&amp;size=32" alt="Font Database" class="svelte-zslw0j"></span> </div> <a href="https://fontdatabase.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Database 
The hassle of font-hunting, gone. A designer's right hand." style="">Font Database</h3> <p class="description svelte-zslw0j">The hassle of font-hunting, gone. A designer's right hand.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontdatabase.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://archetypeapp.com/&amp;size=32" alt="Archetype" class="svelte-zslw0j"></span> </div> <a href="https://archetypeapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Archetype 
Archetype lets designers like you very quickly and easily create consistent typography styling and spacing live, in the browser." style="">Archetype</h3> <p class="description svelte-zslw0j">Archetype lets designers like you very quickly and easily create consistent typography styling and spacing live, in the browser.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://archetypeapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.abstractfonts.com/&amp;size=32" alt="Asbtract Fonts" class="svelte-zslw0j"></span> </div> <a href="https://www.abstractfonts.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Asbtract Fonts 
Download, view, test-drive, bookmark free fonts. Features more than 13,500 free fonts." style="">Asbtract Fonts</h3> <p class="description svelte-zslw0j">Download, view, test-drive, bookmark free fonts. Features more than 13,500 free fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.abstractfonts.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://practicaltypography.com/&amp;size=32" alt="Practical Typography" class="svelte-zslw0j"></span> </div> <a href="https://practicaltypography.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Practical Typography 
Practical Typography Book." style="">Practical Typography</h3> <p class="description svelte-zslw0j">Practical Typography Book.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://practicaltypography.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontreviewjournal.com&amp;size=32" alt="Font Review Journal" class="svelte-zslw0j"></span> </div> <a href="https://fontreviewjournal.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Review Journal 
The Font Review Journal is home to reviews and analysis of typeface designs both new and old." style="">Font Review Journal</h3> <p class="description svelte-zslw0j">The Font Review Journal is home to reviews and analysis of typeface designs both new and old.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontreviewjournal.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontspark.app/&amp;size=32" alt="Font Spark" class="svelte-zslw0j"></span> </div> <a href="https://fontspark.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Spark 
FontSpark is a simple tool to help designers quickly find the best fonts for their projects. By randomly generating fonts from a curated list of popular web fonts, designers are sure to break out of the habit of using the same 3 or 4 fonts in nearly every project and discover the perfect fit for their next website or design." style="">Font Spark</h3> <p class="description svelte-zslw0j">FontSpark is a simple tool to help designers quickly find the best fonts for their projects. By randomly generating fonts from a curated list of popular web fonts, designers are sure to break out of the habit of using the same 3 or 4 fonts in nearly every project and discover the perfect fit for their next website or design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontspark.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fonts.adobe.com/fonts&amp;size=32" alt="Adobe Fonts" class="svelte-zslw0j"></span> </div> <a href="https://fonts.adobe.com/fonts" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Adobe Fonts 
Search for fonts by foundry, designer, properties, languages, classifications, and more. Explore the latest additions to our font library at Adobe Fonts." style="">Adobe Fonts</h3> <p class="description svelte-zslw0j">Search for fonts by foundry, designer, properties, languages, classifications, and more. Explore the latest additions to our font library at Adobe Fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fonts.adobe.com/fonts" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontface.ninja/&amp;size=32" alt="Fontface Ninja" class="svelte-zslw0j"></span> </div> <a href="https://fontface.ninja/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fontface Ninja 
Fontface ninja is a browser extension to identify try and buy fonts." style="">Fontface Ninja</h3> <p class="description svelte-zslw0j">Fontface ninja is a browser extension to identify try and buy fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontface.ninja/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://google-webfonts-helper.herokuapp.com/fonts&amp;size=32" alt="Google Fonts Helper" class="svelte-zslw0j"></span> </div> <a href="https://google-webfonts-helper.herokuapp.com/fonts" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Google Fonts Helper 
A Hassle-Free way to self-host Google Fonts." style="">Google Fonts Helper</h3> <p class="description svelte-zslw0j">A Hassle-Free way to self-host Google Fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://google-webfonts-helper.herokuapp.com/fonts" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://rightfontapp.com/&amp;size=32" alt="Right Font App" class="svelte-zslw0j"></span> </div> <a href="https://rightfontapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Right Font App 
Professional font management app for Mac." style="">Right Font App</h3> <p class="description svelte-zslw0j">Professional font management app for Mac.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://rightfontapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://webfontapp.com/&amp;size=32" alt="Webfont App" class="svelte-zslw0j"></span> </div> <a href="https://webfontapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Webfont App 
Streamline the process of creating and maintaining custom SVG icon fonts. Create a shared library of icons, invite your team and export your font in minutes." style="">Webfont App</h3> <p class="description svelte-zslw0j">Streamline the process of creating and maintaining custom SVG icon fonts. Create a shared library of icons, invite your team and export your font in minutes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://webfontapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://letterformarchive.org/&amp;size=32" alt="Letterform Archive" class="svelte-zslw0j"></span> </div> <a href="https://letterformarchive.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Letterform Archive 
Inspiration, education, publishing &amp; community in graphic design." style="">Letterform Archive</h3> <p class="description svelte-zslw0j">Inspiration, education, publishing &amp; community in graphic design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://letterformarchive.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fontfabric.com/fonts/&amp;size=32" alt="Font Fabric" class="svelte-zslw0j"></span> </div> <a href="https://www.fontfabric.com/fonts/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font Fabric 
High-quality typefaces, calligraphy and lettering." style="">Font Fabric</h3> <p class="description svelte-zslw0j">High-quality typefaces, calligraphy and lettering.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fontfabric.com/fonts/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fonts.ilovetypography.com/&amp;size=32" alt="I love Typography" class="svelte-zslw0j"></span> </div> <a href="https://fonts.ilovetypography.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="I love Typography 
World’s favorite typography blog and new shop for indie foundries." style="">I love Typography</h3> <p class="description svelte-zslw0j">World’s favorite typography blog and new shop for indie foundries.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fonts.ilovetypography.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fontshare.com/&amp;size=32" alt="Fontshare" class="svelte-zslw0j"></span> </div> <a href="https://www.fontshare.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fontshare 
Fontshare is a free fonts service from ITF, making quality fonts accessible to all." style="">Fontshare</h3> <p class="description svelte-zslw0j">Fontshare is a free fonts service from ITF, making quality fonts accessible to all.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fontshare.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


font_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontark.net/farkwp/&amp;size=32" alt="FontArk" class="svelte-zslw0j"></span> </div> <a href="https://fontark.net/farkwp/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FontArk 
FontArk is an innovative new browser based online font editor, font creator, featuring a unique real time Multiple-Character-Editing tool." style="">FontArk</h3> <p class="description svelte-zslw0j">FontArk is an innovative new browser based online font editor, font creator, featuring a unique real time Multiple-Character-Editing tool.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontark.net/farkwp/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.calligraphr.com/en/&amp;size=32" alt="Calligraphr" class="svelte-zslw0j"></span> </div> <a href="https://www.calligraphr.com/en/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Calligraphr 
Transform your handwriting and calligraphy into fully functional vector fonts with our web application. Creating your own font has never been easier." style="">Calligraphr</h3> <p class="description svelte-zslw0j">Transform your handwriting and calligraphy into fully functional vector fonts with our web application. Creating your own font has never been easier.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.calligraphr.com/en/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://birdfont.org/&amp;size=32" alt="BirdFont" class="svelte-zslw0j"></span> </div> <a href="https://birdfont.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="BirdFont 
Birdfont is a free font editor which lets you create vector graphics and export TTF, OTF and SVG fonts." style="">BirdFont</h3> <p class="description svelte-zslw0j">Birdfont is a free font editor which lets you create vector graphics and export TTF, OTF and SVG fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://birdfont.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontforge.org/en-US/&amp;size=32" alt="FontForge" class="svelte-zslw0j"></span> </div> <a href="https://fontforge.org/en-US/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FontForge 
FontForge is a free and open source font editor brought to you by a community of fellow type lovers." style="">FontForge</h3> <p class="description svelte-zslw0j">FontForge is a free and open source font editor brought to you by a community of fellow type lovers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontforge.org/en-US/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fontstruct.com/&amp;size=32" alt="FontStruct" class="svelte-zslw0j"></span> </div> <a href="https://fontstruct.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FontStruct 
FontStruct is a free font-building tool, funded by advertising and some generous sponsors." style="">FontStruct</h3> <p class="description svelte-zslw0j">FontStruct is a free font-building tool, funded by advertising and some generous sponsors.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fontstruct.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.glyphrstudio.com/&amp;size=32" alt="Glyphr Studio" class="svelte-zslw0j"></span> </div> <a href="https://www.glyphrstudio.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Glyphr Studio 
Glyphr Studio is a free, web based font designer. Version 1 is here! Font design has a high barrier of entry." style="">Glyphr Studio</h3> <p class="description svelte-zslw0j">Glyphr Studio is a free, web based font designer. Version 1 is here! Font design has a high barrier of entry.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.glyphrstudio.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pentacom.jp/pentacom/bitfontmaker2/&amp;size=32" alt="BitFontMaker2" class="svelte-zslw0j"></span> </div> <a href="https://www.pentacom.jp/pentacom/bitfontmaker2/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="BitFontMaker2 
BitFontCreator is a professional bitmap font creator tool for your embedded project, which helps you create monochrome (1-bpp) bitmap fonts and antialiased (2-bpp and 4-bpp) bitmap fonts for graphical LCD / LED." style="">BitFontMaker2</h3> <p class="description svelte-zslw0j">BitFontCreator is a professional bitmap font creator tool for your embedded project, which helps you create monochrome (1-bpp) bitmap fonts and antialiased (2-bpp and 4-bpp) bitmap fonts for graphical LCD / LED.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pentacom.jp/pentacom/bitfontmaker2/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sourceforge.net/projects/ttfedit/&amp;size=32" alt="TTFEdit" class="svelte-zslw0j"></span> </div> <a href="https://sourceforge.net/projects/ttfedit/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="TTFEdit 
TTFEdit is a GPL editor for TrueType fonts. TrueType is a standard used by modern operating systems like Mac OS X, Windows XP and Linux." style="">TTFEdit</h3> <p class="description svelte-zslw0j">TTFEdit is a GPL editor for TrueType fonts. TrueType is a standard used by modern operating systems like Mac OS X, Windows XP and Linux.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sourceforge.net/projects/ttfedit/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.cr8software.net/typelight.html&amp;size=32" alt="cr8software" class="svelte-zslw0j"></span> </div> <a href="https://www.cr8software.net/typelight.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="cr8software 
CR8 Software Solutions for easy-to-use font making and ID card printing software." style="">cr8software</h3> <p class="description svelte-zslw0j">CR8 Software Solutions for easy-to-use font making and ID card printing software.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.cr8software.net/typelight.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fontlab.com/&amp;size=32" alt="FontLab Studio" class="svelte-zslw0j"></span> </div> <a href="https://www.fontlab.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FontLab Studio 
FontLab Studio is our classic font editor. Designers, typographers and graphic design studios, allowing them to design typefaces and create or modify fonts." style="">FontLab Studio</h3> <p class="description svelte-zslw0j">FontLab Studio is our classic font editor. Designers, typographers and graphic design studios, allowing them to design typefaces and create or modify fonts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fontlab.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.myfonts.com/WhatTheFont/&amp;size=32" alt="What The Font" class="svelte-zslw0j"></span> </div> <a href="https://www.myfonts.com/WhatTheFont/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="What The Font 
How it works: WhatTheFont uses deep learning to search our collection of over 133,000 font styles and find the best match for the fonts in your photo." style="">What The Font</h3> <p class="description svelte-zslw0j">How it works: WhatTheFont uses deep learning to search our collection of over 133,000 font styles and find the best match for the fonts in your photo.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.myfonts.com/WhatTheFont/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://stylifyme.com/&amp;size=32" alt="Stylify Me" class="svelte-zslw0j"></span> </div> <a href="https://stylifyme.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stylify Me 
Stylify Me was created to help designers quickly gain an overview of the style guide of a site, including colours, fonts, sizing and spacing." style="">Stylify Me</h3> <p class="description svelte-zslw0j">Stylify Me was created to help designers quickly gain an overview of the style guide of a site, including colours, fonts, sizing and spacing.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://stylifyme.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.colorsandfonts.com/&amp;size=32" alt="Colors and fonts" class="svelte-zslw0j"></span> </div> <a href="https://www.colorsandfonts.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colors and fonts 
Color and typography for Web Developers and Digital Designers." style="">Colors and fonts</h3> <p class="description svelte-zslw0j">Color and typography for Web Developers and Digital Designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.colorsandfonts.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


gradient_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.grabient.com/&amp;size=32" alt="Grabient" class="svelte-zslw0j"></span> </div> <a href="https://www.grabient.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Grabient 
Beautiful and simple UI for generating web gradients." style="">Grabient</h3> <p class="description svelte-zslw0j">Beautiful and simple UI for generating web gradients.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.grabient.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uigradients.com/&amp;size=32" alt="uiGradients" class="svelte-zslw0j"></span> </div> <a href="https://uigradients.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="uiGradients 
A handpicked collection of beautiful color gradients for designers and developers." style="">uiGradients</h3> <p class="description svelte-zslw0j">A handpicked collection of beautiful color gradients for designers and developers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uigradients.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://products.ls.graphics/mesh-gradients/&amp;size=32" alt="Mesh Gradients" class="svelte-zslw0j"></span> </div> <a href="https://products.ls.graphics/mesh-gradients/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mesh Gradients 
Free mesh gradient collection." style="">Mesh Gradients</h3> <p class="description svelte-zslw0j">Free mesh gradient collection.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://products.ls.graphics/mesh-gradients/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gradienthunt.com&amp;size=32" alt="Gradient Hunt" class="svelte-zslw0j"></span> </div> <a href="https://gradienthunt.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gradient Hunt 
Gradient Hunt is a free and open platform for color inspiration with thousands of trendy hand-made color gradients." style="">Gradient Hunt</h3> <p class="description svelte-zslw0j">Gradient Hunt is a free and open platform for color inspiration with thousands of trendy hand-made color gradients.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gradienthunt.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mycolor.space/gradient&amp;size=32" alt="Mycolor Space" class="svelte-zslw0j"></span> </div> <a href="https://mycolor.space/gradient" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mycolor Space 
Generate CSS gradients." style="">Mycolor Space</h3> <p class="description svelte-zslw0j">Generate CSS gradients.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mycolor.space/gradient" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://webkul.github.io/coolhue/&amp;size=32" alt="CoolHue 2.0" class="svelte-zslw0j"></span> </div> <a href="https://webkul.github.io/coolhue/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CoolHue 2.0 
Get coolest handpicked gradient colors collection palette for your next project, alternatively copy css or download as image too." style="">CoolHue 2.0</h3> <p class="description svelte-zslw0j">Get coolest handpicked gradient colors collection palette for your next project, alternatively copy css or download as image too.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://webkul.github.io/coolhue/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://cssgradient.io/&amp;size=32" alt="CSS Gradient" class="svelte-zslw0j"></span> </div> <a href="https://cssgradient.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CSS Gradient 
As a free css gradient generator tool, this website lets you create a colorful gradient background for your website, blog, or social media profile." style="">CSS Gradient</h3> <p class="description svelte-zslw0j">As a free css gradient generator tool, this website lets you create a colorful gradient background for your website, blog, or social media profile.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://cssgradient.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://webgradients.com/&amp;size=32" alt="WebGradients" class="svelte-zslw0j"></span> </div> <a href="https://webgradients.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="WebGradients 
WebGradients is a free collection of 180 linear gradients that you can use as content backdrops in any part of your website." style="">WebGradients</h3> <p class="description svelte-zslw0j">WebGradients is a free collection of 180 linear gradients that you can use as content backdrops in any part of your website.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://webgradients.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://htmlcolors.com/gradients&amp;size=32" alt="HTML Colors" class="svelte-zslw0j"></span> </div> <a href="https://htmlcolors.com/gradients" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="HTML Colors 
HTML Colors offers you our users most sophisticated Gradients. Take a look or create your unique gradient!" style="">HTML Colors</h3> <p class="description svelte-zslw0j">HTML Colors offers you our users most sophisticated Gradients. Take a look or create your unique gradient!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://htmlcolors.com/gradients" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gradientsguru.com/&amp;size=32" alt="Gradients Guru" class="svelte-zslw0j"></span> </div> <a href="https://gradientsguru.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gradients Guru 
198 beautiful gradients and 15 Blend mode images effects, This cool &amp; strong collection is created by Trionn Design's designers and it's totally free." style="">Gradients Guru</h3> <p class="description svelte-zslw0j">198 beautiful gradients and 15 Blend mode images effects, This cool &amp; strong collection is created by Trionn Design's designers and it's totally free.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gradientsguru.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colorfulgradients.tumblr.com/&amp;size=32" alt="Colorful Gradients" class="svelte-zslw0j"></span> </div> <a href="https://colorfulgradients.tumblr.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colorful Gradients 
Gradients automatically created by a computer. 48 times daily." style="">Colorful Gradients</h3> <p class="description svelte-zslw0j">Gradients automatically created by a computer. 48 times daily.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colorfulgradients.tumblr.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gradientbuttons.colorion.co/&amp;size=32" alt="Gradient Buttons" class="svelte-zslw0j"></span> </div> <a href="https://gradientbuttons.colorion.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gradient Buttons 
Gradient buttons with hover effects." style="">Gradient Buttons</h3> <p class="description svelte-zslw0j">Gradient buttons with hover effects.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gradientbuttons.colorion.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://coolbackgrounds.io/&amp;size=32" alt="Cool Backgrounds" class="svelte-zslw0j"></span> </div> <a href="https://coolbackgrounds.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Cool Backgrounds 
Cool Backgrounds is a collection of tools to create compelling, colorful images for blogs, social media, and websites." style="">Cool Backgrounds</h3> <p class="description svelte-zslw0j">Cool Backgrounds is a collection of tools to create compelling, colorful images for blogs, social media, and websites.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://coolbackgrounds.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.colorffy.com/gradients&amp;size=32" alt="Colorffy" class="svelte-zslw0j"></span> </div> <a href="https://www.colorffy.com/gradients" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colorffy 
Color gradients and palettes daily! " style="">Colorffy</h3> <p class="description svelte-zslw0j">Color gradients and palettes daily! </p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.colorffy.com/gradients" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://launchoice.com/gradients&amp;size=32" alt="TailwindCSS Gradients" class="svelte-zslw0j"></span> </div> <a href="https://launchoice.com/gradients" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="TailwindCSS Gradients 
Collection of linear gradients made with TailwindCSS Classes" style="">TailwindCSS Gradients</h3> <p class="description svelte-zslw0j">Collection of linear gradients made with TailwindCSS Classes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://launchoice.com/gradients" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://slick-gradient.vercel.app/&amp;size=32" alt="Slick Gradient" class="svelte-zslw0j"></span> </div> <a href="https://slick-gradient.vercel.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Slick Gradient 
A curated collection of beautiful gradients " style="">Slick Gradient</h3> <p class="description svelte-zslw0j">A curated collection of beautiful gradients </p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://slick-gradient.vercel.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://colpic.netlify.app/gradients&amp;size=32" alt="Colpic" class="svelte-zslw0j"></span> </div> <a href="https://colpic.netlify.app/gradients" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Colpic 
Color and gradient picker" style="">Colpic</h3> <p class="description svelte-zslw0j">Color and gradient picker</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://colpic.netlify.app/gradients" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.weareheroes.digital/resources/grainients&amp;size=32" alt="Grainients" class="svelte-zslw0j"></span> </div> <a href="https://www.weareheroes.digital/resources/grainients" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Grainients 
Over 2000+ high resolution, grainy gradients" style="">Grainients</h3> <p class="description svelte-zslw0j">Over 2000+ high resolution, grainy gradients</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.weareheroes.digital/resources/grainients" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://meshy.uxie.io/&amp;size=32" alt="Mesh·y" class="svelte-zslw0j"></span> </div> <a href="https://meshy.uxie.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mesh·y 
Generate custom beautiful mesh gradients" style="">Mesh·y</h3> <p class="description svelte-zslw0j">Generate custom beautiful mesh gradients</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://meshy.uxie.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designgradients.com/&amp;size=32" alt="Design Gradients" class="svelte-zslw0j"></span> </div> <a href="https://www.designgradients.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Gradients 
Free gradients curated by designers to use anywhere you want" style="">Design Gradients</h3> <p class="description svelte-zslw0j">Free gradients curated by designers to use anywhere you want</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designgradients.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fffuel.co/gggrain/&amp;size=32" alt="gggrain" class="svelte-zslw0j"></span> </div> <a href="https://fffuel.co/gggrain/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="gggrain 
SVG generator for grainy analog-feeling gradients" style="">gggrain</h3> <p class="description svelte-zslw0j">SVG generator for grainy analog-feeling gradients</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fffuel.co/gggrain/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.gradientos.app/&amp;size=32" alt="Gradientos" class="svelte-zslw0j"></span> </div> <a href="https://www.gradientos.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gradientos 
Find gradients easily" style="">Gradientos</h3> <p class="description svelte-zslw0j">Find gradients easily</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.gradientos.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fffuel.co/ffflux/&amp;size=32" alt="ffflux" class="svelte-zslw0j"></span> </div> <a href="https://fffuel.co/ffflux/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ffflux 
SVG generator for fluid gradient backgrounds" style="">ffflux</h3> <p class="description svelte-zslw0j">SVG generator for fluid gradient backgrounds</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fffuel.co/ffflux/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gradient-king.vercel.app/&amp;size=32" alt="Gradient King" class="svelte-zslw0j"></span> </div> <a href="https://gradient-king.vercel.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gradient King 
Curated collection of 125+ fresh gradients" style="">Gradient King</h3> <p class="description svelte-zslw0j">Curated collection of 125+ fresh gradients</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gradient-king.vercel.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.meshgradients.com/&amp;size=32" alt="Mesh Gradients Plugin" class="svelte-zslw0j"></span> </div> <a href="https://www.meshgradients.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mesh Gradients Plugin 
Create awesome mesh gradients right inside of Sketch" style="">Mesh Gradients Plugin</h3> <p class="description svelte-zslw0j">Create awesome mesh gradients right inside of Sketch</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.meshgradients.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gradienta.io/&amp;size=32" alt="Multicolor Gradients" class="svelte-zslw0j"></span> </div> <a href="https://gradienta.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Multicolor Gradients 
Open-source multi-layered CSS gradients with JPG downloads." style="">Multicolor Gradients</h3> <p class="description svelte-zslw0j">Open-source multi-layered CSS gradients with JPG downloads.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gradienta.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.eggradients.com/&amp;size=32" alt="EggGradients" class="svelte-zslw0j"></span> </div> <a href="https://www.eggradients.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="EggGradients 
Ready to use gradient background colors. Cool Gradients are prepared according to the latest design trends." style="">EggGradients</h3> <p class="description svelte-zslw0j">Ready to use gradient background colors. Cool Gradients are prepared according to the latest design trends.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.eggradients.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gradients.cssgears.com/&amp;size=32" alt="Gradient Cards" class="svelte-zslw0j"></span> </div> <a href="https://gradients.cssgears.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gradient Cards 
The Ultimate gradients guide for your next project sketch,Adobe xd and css Gradients." style="">Gradient Cards</h3> <p class="description svelte-zslw0j">The Ultimate gradients guide for your next project sketch,Adobe xd and css Gradients.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gradients.cssgears.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://digitalsynopsis.com/design/beautiful-color-gradients-backgrounds/&amp;size=32" alt="Digital Synopsis" class="svelte-zslw0j"></span> </div> <a href="https://digitalsynopsis.com/design/beautiful-color-gradients-backgrounds/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Digital Synopsis 
Digital Synopsis showcases the best ideas in design, advertising and visual communication." style="">Digital Synopsis</h3> <p class="description svelte-zslw0j">Digital Synopsis showcases the best ideas in design, advertising and visual communication.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://digitalsynopsis.com/design/beautiful-color-gradients-backgrounds/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://meshgradient.com/&amp;size=32" alt="Mesh Gradient" class="svelte-zslw0j"></span> </div> <a href="https://meshgradient.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mesh Gradient 
Create beautiful gradients right in your browser" style="">Mesh Gradient</h3> <p class="description svelte-zslw0j">Create beautiful gradients right in your browser</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://meshgradient.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.meshgradients.design/&amp;size=32" alt="Mesh Gradients Collection" class="svelte-zslw0j"></span> </div> <a href="https://www.meshgradients.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mesh Gradients Collection 
100 Beautiful Mesh Gradients - Free Download" style="">Mesh Gradients Collection</h3> <p class="description svelte-zslw0j">100 Beautiful Mesh Gradients - Free Download</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.meshgradients.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ruri.design/gradiator&amp;size=32" alt="Ruri Gradiator" class="svelte-zslw0j"></span> </div> <a href="https://ruri.design/gradiator" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ruri Gradiator 
Mini tools that boost your creativity" style="">Ruri Gradiator</h3> <p class="description svelte-zslw0j">Mini tools that boost your creativity</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ruri.design/gradiator" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


image_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fococlipping.com/clip&amp;size=32" alt="FocoClipping" class="svelte-zslw0j"></span> </div> <a href="https://www.fococlipping.com/clip" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FocoClipping 
FocoClipping is an online image background remover to remove image background freely by smart AI. Then edit, crop, change background, add shadows to perfect ..." style="">FocoClipping</h3> <p class="description svelte-zslw0j">FocoClipping is an online image background remover to remove image background freely by smart AI. Then edit, crop, change background, add shadows to perfect ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fococlipping.com/clip" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tinyjpg.com/&amp;size=32" alt="TinyJPG" class="svelte-zslw0j"></span> </div> <a href="https://tinyjpg.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="TinyJPG 
Make your website faster and save bandwidth. TinyJPG is the best automatic WEBP, JPEG and PNG optimizer and compresses your WEBP, JPEG and PNG images by ..." style="">TinyJPG</h3> <p class="description svelte-zslw0j">Make your website faster and save bandwidth. TinyJPG is the best automatic WEBP, JPEG and PNG optimizer and compresses your WEBP, JPEG and PNG images by ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tinyjpg.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.remove.bg/&amp;size=32" alt="Remove bg" class="svelte-zslw0j"></span> </div> <a href="https://www.remove.bg/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Remove bg 
Thanks to remove.bg's clever AI, you can slash editing time - and have more fun! No matter if you want to make a background transparent (PNG) or add a white ..." style="">Remove bg</h3> <p class="description svelte-zslw0j">Thanks to remove.bg's clever AI, you can slash editing time - and have more fun! No matter if you want to make a background transparent (PNG) or add a white ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.remove.bg/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://imagematting.com/&amp;size=32" alt="ImageMatting" class="svelte-zslw0j"></span> </div> <a href="https://imagematting.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ImageMatting 
Image background removal AI trained on 1.5M handcrafted pics" style="">ImageMatting</h3> <p class="description svelte-zslw0j">Image background removal AI trained on 1.5M handcrafted pics</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://imagematting.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://socialbook.io/remove-background&amp;size=32" alt="SocialBook" class="svelte-zslw0j"></span> </div> <a href="https://socialbook.io/remove-background" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="SocialBook 
Remove any background for free" style="">SocialBook</h3> <p class="description svelte-zslw0j">Remove any background for free</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://socialbook.io/remove-background" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.upscale.media/&amp;size=32" alt="Upscale.media" class="svelte-zslw0j"></span> </div> <a href="https://www.upscale.media/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Upscale.media 
2x or 4x your image resolution with our free AI tool" style="">Upscale.media</h3> <p class="description svelte-zslw0j">2x or 4x your image resolution with our free AI tool</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.upscale.media/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://placy.org/&amp;size=32" alt="Placy" class="svelte-zslw0j"></span> </div> <a href="https://placy.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Placy 
Simple tool for generating placeholders" style="">Placy</h3> <p class="description svelte-zslw0j">Simple tool for generating placeholders</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://placy.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://imagetocartoon.com/&amp;size=32" alt="Image to Cartoon" class="svelte-zslw0j"></span> </div> <a href="https://imagetocartoon.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Image to Cartoon 
Best AI cartoonizer online for free" style="">Image to Cartoon</h3> <p class="description svelte-zslw0j">Best AI cartoonizer online for free</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://imagetocartoon.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://glitchyimage.com/&amp;size=32" alt="Glitch Image Generator" class="svelte-zslw0j"></span> </div> <a href="https://glitchyimage.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Glitch Image Generator 
A generative tool to create glitchy images" style="">Glitch Image Generator</h3> <p class="description svelte-zslw0j">A generative tool to create glitchy images</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://glitchyimage.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://imgupscaler.com/&amp;size=32" alt="Image Upscaler" class="svelte-zslw0j"></span> </div> <a href="https://imgupscaler.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Image Upscaler 
Upscale and enhance your photo, animes and cartoons in batch" style="">Image Upscaler</h3> <p class="description svelte-zslw0j">Upscale and enhance your photo, animes and cartoons in batch</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://imgupscaler.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://compressio.app/&amp;size=32" alt="Compressio" class="svelte-zslw0j"></span> </div> <a href="https://compressio.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Compressio 
Free, open source image compression API &amp; webapp" style="">Compressio</h3> <p class="description svelte-zslw0j">Free, open source image compression API &amp; webapp</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://compressio.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://lorem.space/&amp;size=32" alt="Lorem.Space" class="svelte-zslw0j"></span> </div> <a href="https://lorem.space/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lorem.Space 
Placeholder images, but useful" style="">Lorem.Space</h3> <p class="description svelte-zslw0j">Placeholder images, but useful</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://lorem.space/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sagrafix.co/free-online-photo-editor/&amp;size=32" alt="Grafix" class="svelte-zslw0j"></span> </div> <a href="https://sagrafix.co/free-online-photo-editor/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Grafix 
A free online image editor - No registrations required" style="">Grafix</h3> <p class="description svelte-zslw0j">A free online image editor - No registrations required</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sagrafix.co/free-online-photo-editor/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gpic.site/&amp;size=32" alt="gpic" class="svelte-zslw0j"></span> </div> <a href="https://gpic.site/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="gpic 
Free image optimizer &amp; hosting service" style="">gpic</h3> <p class="description svelte-zslw0j">Free image optimizer &amp; hosting service</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gpic.site/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://studios.lol/&amp;size=32" alt="Studios.lol" class="svelte-zslw0j"></span> </div> <a href="https://studios.lol/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Studios.lol 
Discover product, design, and other creative agencies" style="">Studios.lol</h3> <p class="description svelte-zslw0j">Discover product, design, and other creative agencies</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://studios.lol/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dialo.app/&amp;size=32" alt="Dialo" class="svelte-zslw0j"></span> </div> <a href="https://dialo.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dialo 
Design your digital business card" style="">Dialo</h3> <p class="description svelte-zslw0j">Design your digital business card</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dialo.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


builder_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thunkable.com/&amp;size=32" alt="Thunkable" class="svelte-zslw0j"></span> </div> <a href="https://thunkable.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Thunkable 
Thunkable enables anyone to create beautiful and powerful mobile apps." style="">Thunkable</h3> <p class="description svelte-zslw0j">Thunkable enables anyone to create beautiful and powerful mobile apps.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thunkable.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://webullar.com/&amp;size=32" alt="Webullar" class="svelte-zslw0j"></span> </div> <a href="https://webullar.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Webullar 
Create a website in 5 minutes with your phone" style="">Webullar</h3> <p class="description svelte-zslw0j">Create a website in 5 minutes with your phone</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://webullar.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sites.ng/&amp;size=32" alt="Sites" class="svelte-zslw0j"></span> </div> <a href="https://sites.ng/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sites 
No-code website building platform" style="">Sites</h3> <p class="description svelte-zslw0j">No-code website building platform</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sites.ng/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://devfolio.io/&amp;size=32" alt="devfolio" class="svelte-zslw0j"></span> </div> <a href="https://devfolio.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="devfolio 
Create a professional-grade portfolio website" style="">devfolio</h3> <p class="description svelte-zslw0j">Create a professional-grade portfolio website</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://devfolio.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.upsitely.com/&amp;size=32" alt="Upsitely" class="svelte-zslw0j"></span> </div> <a href="https://www.upsitely.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Upsitely 
Build beautiful websites, portfolios, blogs &amp; stores" style="">Upsitely</h3> <p class="description svelte-zslw0j">Build beautiful websites, portfolios, blogs &amp; stores</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.upsitely.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.framer.com/sites/&amp;size=32" alt="Framer Sites Beta" class="svelte-zslw0j"></span> </div> <a href="https://www.framer.com/sites/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Framer Sites Beta 
Design real websites right on the canvas. Publish in seconds" style="">Framer Sites Beta</h3> <p class="description svelte-zslw0j">Design real websites right on the canvas. Publish in seconds</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.framer.com/sites/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://build.mmm.page/&amp;size=32" alt="mmm.page" class="svelte-zslw0j"></span> </div> <a href="https://build.mmm.page/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="mmm.page 
Dead simple, drag &amp; drop personal websites" style="">mmm.page</h3> <p class="description svelte-zslw0j">Dead simple, drag &amp; drop personal websites</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://build.mmm.page/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://super.so&amp;size=32" alt="Super 2.0" class="svelte-zslw0j"></span> </div> <a href="https://super.so" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Super 2.0 
Build websites with the simplicity of Notion ⚡️" style="">Super 2.0</h3> <p class="description svelte-zslw0j">Build websites with the simplicity of Notion ⚡️</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://super.so" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.ycode.com/&amp;size=32" alt="Ycode" class="svelte-zslw0j"></span> </div> <a href="https://www.ycode.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ycode 
No-code web app builder where design meets function" style="">Ycode</h3> <p class="description svelte-zslw0j">No-code web app builder where design meets function</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.ycode.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pagecloud.com/pagecloud-start&amp;size=32" alt="Pagecloud Start" class="svelte-zslw0j"></span> </div> <a href="https://www.pagecloud.com/pagecloud-start" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pagecloud Start 
Create your free, custom, no-code, one page website" style="">Pagecloud Start</h3> <p class="description svelte-zslw0j">Create your free, custom, no-code, one page website</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pagecloud.com/pagecloud-start" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.umso.com&amp;size=32" alt="Umso" class="svelte-zslw0j"></span> </div> <a href="https://www.umso.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Umso 
The website builder for startups" style="">Umso</h3> <p class="description svelte-zslw0j">The website builder for startups</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.umso.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://designmodo.com/startup/&amp;size=32" alt="Startup 5" class="svelte-zslw0j"></span> </div> <a href="https://designmodo.com/startup/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Startup 5 
Create websites online using the Startup Bootstrap builder" style="">Startup 5</h3> <p class="description svelte-zslw0j">Create websites online using the Startup Bootstrap builder</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://designmodo.com/startup/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.gocodeless.com/&amp;size=32" alt="Codeless" class="svelte-zslw0j"></span> </div> <a href="https://www.gocodeless.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Codeless 
One platform for native apps and websites" style="">Codeless</h3> <p class="description svelte-zslw0j">One platform for native apps and websites</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.gocodeless.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://storipress.com/&amp;size=32" alt="Storipress" class="svelte-zslw0j"></span> </div> <a href="https://storipress.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Storipress 
Discover the site builder designed for publishers" style="">Storipress</h3> <p class="description svelte-zslw0j">Discover the site builder designed for publishers</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://storipress.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tell.ie/signup?invite=BEM76L&amp;size=32" alt="Tellie" class="svelte-zslw0j"></span> </div> <a href="https://tell.ie/signup?invite=BEM76L" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Tellie 
Build beautiful web2 + web3 creator sites in minutes" style="">Tellie</h3> <p class="description svelte-zslw0j">Build beautiful web2 + web3 creator sites in minutes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tell.ie/signup?invite=BEM76L" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mdbootstrap.com/presentation/builder/&amp;size=32" alt="Material Builder 2.0" class="svelte-zslw0j"></span> </div> <a href="https://mdbootstrap.com/presentation/builder/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Material Builder 2.0 
Website creator based on Material Design &amp; Bootstrap 5" style="">Material Builder 2.0</h3> <p class="description svelte-zslw0j">Website creator based on Material Design &amp; Bootstrap 5</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mdbootstrap.com/presentation/builder/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.psd2newsletters.com/&amp;size=32" alt="Modules Composer" class="svelte-zslw0j"></span> </div> <a href="https://www.psd2newsletters.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Modules Composer 
Design your email templates without writing a line of code" style="">Modules Composer</h3> <p class="description svelte-zslw0j">Design your email templates without writing a line of code</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.psd2newsletters.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.bondlayer.com/&amp;size=32" alt="Bondlayer" class="svelte-zslw0j"></span> </div> <a href="https://www.bondlayer.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Bondlayer 
All-in-one nocode tool to build custom sites &amp; native apps" style="">Bondlayer</h3> <p class="description svelte-zslw0j">All-in-one nocode tool to build custom sites &amp; native apps</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.bondlayer.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gizi.site/&amp;size=32" alt="GIZI" class="svelte-zslw0j"></span> </div> <a href="https://gizi.site/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="GIZI 
Create Professional Websites from your iPhone" style="">GIZI</h3> <p class="description svelte-zslw0j">Create Professional Websites from your iPhone</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gizi.site/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://unicornplatform.com/&amp;size=32" alt="Unicorn Platform 4.0" class="svelte-zslw0j"></span> </div> <a href="https://unicornplatform.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Unicorn Platform 4.0 
Simple drag &amp; drop landing page builder for startups" style="">Unicorn Platform 4.0</h3> <p class="description svelte-zslw0j">Simple drag &amp; drop landing page builder for startups</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://unicornplatform.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://temper.one/&amp;size=32" alt="temper" class="svelte-zslw0j"></span> </div> <a href="https://temper.one/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="temper 
Create a text-based one pager website in a few clicks" style="">temper</h3> <p class="description svelte-zslw0j">Create a text-based one pager website in a few clicks</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://temper.one/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://jemi.so/&amp;size=32" alt="Jemi 2.0" class="svelte-zslw0j"></span> </div> <a href="https://jemi.so/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Jemi 2.0 
Website builder for creators and entrepreneurs" style="">Jemi 2.0</h3> <p class="description svelte-zslw0j">Website builder for creators and entrepreneurs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://jemi.so/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://achate.flow.ninja/&amp;size=32" alt="Achate" class="svelte-zslw0j"></span> </div> <a href="https://achate.flow.ninja/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Achate 
Use Achate to launch your marketing website in minutes" style="">Achate</h3> <p class="description svelte-zslw0j">Use Achate to launch your marketing website in minutes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://achate.flow.ninja/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.devwares.com/windframe/&amp;size=32" alt="Windframe" class="svelte-zslw0j"></span> </div> <a href="https://www.devwares.com/windframe/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Windframe 
No code TailwindCSS page builder" style="">Windframe</h3> <p class="description svelte-zslw0j">No code TailwindCSS page builder</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.devwares.com/windframe/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://systeme.io/&amp;size=32" alt="Systeme 2.0" class="svelte-zslw0j"></span> </div> <a href="https://systeme.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Systeme 2.0 
Free marketing platform and website-builder for creators" style="">Systeme 2.0</h3> <p class="description svelte-zslw0j">Free marketing platform and website-builder for creators</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://systeme.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://en.wayto.me/&amp;size=32" alt="Wayto.me" class="svelte-zslw0j"></span> </div> <a href="https://en.wayto.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Wayto.me 
Create your own website without code" style="">Wayto.me</h3> <p class="description svelte-zslw0j">Create your own website without code</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://en.wayto.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://identid.me&amp;size=32" alt="identid.me" class="svelte-zslw0j"></span> </div> <a href="https://identid.me" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="identid.me 
Create an awesome online portfolio in minutes" style="">identid.me</h3> <p class="description svelte-zslw0j">Create an awesome online portfolio in minutes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://identid.me" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.vsble.me/&amp;size=32" alt="Vsble" class="svelte-zslw0j"></span> </div> <a href="https://www.vsble.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Vsble 
Beautiful websites for creative minds" style="">Vsble</h3> <p class="description svelte-zslw0j">Beautiful websites for creative minds</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.vsble.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.boxmode.com/&amp;size=32" alt="Boxmode" class="svelte-zslw0j"></span> </div> <a href="https://www.boxmode.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Boxmode 
A free, easy to use website builder" style="">Boxmode</h3> <p class="description svelte-zslw0j">A free, easy to use website builder</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.boxmode.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://websmith.digital/&amp;size=32" alt="WebSmith" class="svelte-zslw0j"></span> </div> <a href="https://websmith.digital/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="WebSmith 
Easy to use drag &amp; drop website builder" style="">WebSmith</h3> <p class="description svelte-zslw0j">Easy to use drag &amp; drop website builder</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://websmith.digital/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://forms.app/en&amp;size=32" alt="Forms.app" class="svelte-zslw0j"></span> </div> <a href="https://forms.app/en" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Forms.app 
Free online form builder" style="">Forms.app</h3> <p class="description svelte-zslw0j">Free online form builder</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://forms.app/en" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://boardy.app/&amp;size=32" alt="Boardy" class="svelte-zslw0j"></span> </div> <a href="https://boardy.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Boardy 
Dashboards for everyone" style="">Boardy</h3> <p class="description svelte-zslw0j">Dashboards for everyone</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://boardy.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://library.relume.io/&amp;size=32" alt="Relume Library" class="svelte-zslw0j"></span> </div> <a href="https://library.relume.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Relume Library 
The world's largest Webflow component library" style="">Relume Library</h3> <p class="description svelte-zslw0j">The world's largest Webflow component library</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://library.relume.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.marcomrobot.com/landing-page-builder&amp;size=32" alt="Marcom Robot" class="svelte-zslw0j"></span> </div> <a href="https://www.marcomrobot.com/landing-page-builder" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Marcom Robot 
Create high-converting landing pages at scale" style="">Marcom Robot</h3> <p class="description svelte-zslw0j">Create high-converting landing pages at scale</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.marcomrobot.com/landing-page-builder" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mssg.me/&amp;size=32" alt="mssg.me" class="svelte-zslw0j"></span> </div> <a href="https://mssg.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="mssg.me 
Mobile. No-code. Free and simple to use website builder." style="">mssg.me</h3> <p class="description svelte-zslw0j">Mobile. No-code. Free and simple to use website builder.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mssg.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.vitaely.me/&amp;size=32" alt="Vitaely.me" class="svelte-zslw0j"></span> </div> <a href="https://www.vitaely.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Vitaely.me 
Turn your LinkedIn Profile into a landing page" style="">Vitaely.me</h3> <p class="description svelte-zslw0j">Turn your LinkedIn Profile into a landing page</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.vitaely.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://freepodcastwebsites.com/&amp;size=32" alt="Transistor" class="svelte-zslw0j"></span> </div> <a href="https://freepodcastwebsites.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Transistor 
Automatically generates a website for your podcast using your RSS feed" style="">Transistor</h3> <p class="description svelte-zslw0j">Automatically generates a website for your podcast using your RSS feed</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://freepodcastwebsites.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


collaboration_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://witeboard.com/&amp;size=32" alt="Witeboard" class="svelte-zslw0j"></span> </div> <a href="https://witeboard.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Witeboard 
Witeboard is the fastest way to collaborate real-time with your team anywhere." style="">Witeboard</h3> <p class="description svelte-zslw0j">Witeboard is the fastest way to collaborate real-time with your team anywhere.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://witeboard.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://realtimeboard.com/&amp;size=32" alt="Real Time Board" class="svelte-zslw0j"></span> </div> <a href="https://realtimeboard.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Real Time Board 
Collaboration without constraints." style="">Real Time Board</h3> <p class="description svelte-zslw0j">Collaboration without constraints.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://realtimeboard.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designsystems.com/&amp;size=32" alt="Design Systems" class="svelte-zslw0j"></span> </div> <a href="https://www.designsystems.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Systems 
A Figma publication for design systems creators, designers, developers, and managers" style="">Design Systems</h3> <p class="description svelte-zslw0j">A Figma publication for design systems creators, designers, developers, and managers</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designsystems.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mural.co/&amp;size=32" alt="Mural" class="svelte-zslw0j"></span> </div> <a href="https://mural.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mural 
Think and collaborate visually. Anywhere, anytime." style="">Mural</h3> <p class="description svelte-zslw0j">Think and collaborate visually. Anywhere, anytime.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mural.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://airtable.com/&amp;size=32" alt="Airtable" class="svelte-zslw0j"></span> </div> <a href="https://airtable.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Airtable 
Part spreadsheet, part database, and entirely flexible, teams use Airtable to organize their work, their way." style="">Airtable</h3> <p class="description svelte-zslw0j">Part spreadsheet, part database, and entirely flexible, teams use Airtable to organize their work, their way.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://airtable.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://milanote.com/&amp;size=32" alt="Milanote" class="svelte-zslw0j"></span> </div> <a href="https://milanote.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Milanote 
Easy-to-use, collaborative tool to organize your ideas and projects into visual boards." style="">Milanote</h3> <p class="description svelte-zslw0j">Easy-to-use, collaborative tool to organize your ideas and projects into visual boards.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://milanote.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mattermost.com/&amp;size=32" alt="Mattermost" class="svelte-zslw0j"></span> </div> <a href="https://mattermost.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mattermost 
Flexible, open source messaging platform that meets even the most demanding privacy and security standards." style="">Mattermost</h3> <p class="description svelte-zslw0j">Flexible, open source messaging platform that meets even the most demanding privacy and security standards.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mattermost.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.hivedesk.com/&amp;size=32" alt="HiveDesk" class="svelte-zslw0j"></span> </div> <a href="https://www.hivedesk.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="HiveDesk 
Automatic time tracking for remote employees with screenshots. It makes it easier to monitor productivity of remote employees and manage projects." style="">HiveDesk</h3> <p class="description svelte-zslw0j">Automatic time tracking for remote employees with screenshots. It makes it easier to monitor productivity of remote employees and manage projects.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.hivedesk.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://asana.com/&amp;size=32" alt="Asana" class="svelte-zslw0j"></span> </div> <a href="https://asana.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Asana 
The work management platform teams use to stay focused on the goals, projects, and daily tasks that grow business." style="">Asana</h3> <p class="description svelte-zslw0j">The work management platform teams use to stay focused on the goals, projects, and daily tasks that grow business.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://asana.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://basecamp.com/&amp;size=32" alt="Basecamp" class="svelte-zslw0j"></span> </div> <a href="https://basecamp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Basecamp 
The project management suite designed to organize employees, delegate tasks, and monitor progress right from one place." style="">Basecamp</h3> <p class="description svelte-zslw0j">The project management suite designed to organize employees, delegate tasks, and monitor progress right from one place.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://basecamp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.atlassian.com/software/jira&amp;size=32" alt="Jira" class="svelte-zslw0j"></span> </div> <a href="https://www.atlassian.com/software/jira" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Jira 
Software development tool used by agile teams." style="">Jira</h3> <p class="description svelte-zslw0j">Software development tool used by agile teams.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.atlassian.com/software/jira" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.notion.so&amp;size=32" alt="Notion" class="svelte-zslw0j"></span> </div> <a href="https://www.notion.so" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion 
Write, plan, collaborate, and get organized. Notion is all you need — in one tool." style="">Notion</h3> <p class="description svelte-zslw0j">Write, plan, collaborate, and get organized. Notion is all you need — in one tool.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.notion.so" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.proofhub.com/&amp;size=32" alt="ProofHub" class="svelte-zslw0j"></span> </div> <a href="https://www.proofhub.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ProofHub 
The one place for all your projects, teams and communications." style="">ProofHub</h3> <p class="description svelte-zslw0j">The one place for all your projects, teams and communications.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.proofhub.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://taskade.com/&amp;size=32" alt="Taskade" class="svelte-zslw0j"></span> </div> <a href="https://taskade.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Taskade 
Team productivity made simple, fun and designed for remote teams. Taskade is collaborative and syncs in real-time across web, mobile and desktop." style="">Taskade</h3> <p class="description svelte-zslw0j">Team productivity made simple, fun and designed for remote teams. Taskade is collaborative and syncs in real-time across web, mobile and desktop.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://taskade.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.workzone.com/&amp;size=32" alt="Workzone" class="svelte-zslw0j"></span> </div> <a href="https://www.workzone.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Workzone 
A simple, powerful project management software." style="">Workzone</h3> <p class="description svelte-zslw0j">A simple, powerful project management software.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.workzone.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.wrike.com/&amp;size=32" alt="Wrike" class="svelte-zslw0j"></span> </div> <a href="https://www.wrike.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Wrike 
Online project management software that gives you full visibility and control over your tasks." style="">Wrike</h3> <p class="description svelte-zslw0j">Online project management software that gives you full visibility and control over your tasks.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.wrike.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://filestage.io/&amp;size=32" alt="Filestage" class="svelte-zslw0j"></span> </div> <a href="https://filestage.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Filestage 
Agile content approval software that helps you to review videos, designs and documents with clients and co-workers." style="">Filestage</h3> <p class="description svelte-zslw0j">Agile content approval software that helps you to review videos, designs and documents with clients and co-workers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://filestage.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://zenkit.com/&amp;size=32" alt="Zenkit" class="svelte-zslw0j"></span> </div> <a href="https://zenkit.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Zenkit 
A tool to schedule meetings, track project’s progress and brainstorm new ideas." style="">Zenkit</h3> <p class="description svelte-zslw0j">A tool to schedule meetings, track project’s progress and brainstorm new ideas.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://zenkit.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sunsama.com/&amp;size=32" alt="Sunsama" class="svelte-zslw0j"></span> </div> <a href="https://sunsama.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sunsama 
Beautifully designed, team oriented task manager that consolidates Trello/Jira/Asana tickets into a single, calendar-oriented view." style="">Sunsama</h3> <p class="description svelte-zslw0j">Beautifully designed, team oriented task manager that consolidates Trello/Jira/Asana tickets into a single, calendar-oriented view.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sunsama.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://graha.io/&amp;size=32" alt="Graha" class="svelte-zslw0j"></span> </div> <a href="https://graha.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Graha 
Figma for live websites" style="">Graha</h3> <p class="description svelte-zslw0j">Figma for live websites</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://graha.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.kinety.app/&amp;size=32" alt="Kinety" class="svelte-zslw0j"></span> </div> <a href="https://www.kinety.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Kinety 
Align strategy, culture &amp; personal goals in one workspace" style="">Kinety</h3> <p class="description svelte-zslw0j">Align strategy, culture &amp; personal goals in one workspace</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.kinety.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.spinach.io/&amp;size=32" alt="Spinach.io" class="svelte-zslw0j"></span> </div> <a href="https://www.spinach.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Spinach.io 
Crush your daily standup" style="">Spinach.io</h3> <p class="description svelte-zslw0j">Crush your daily standup</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.spinach.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://flexibits.com/fantastical/scheduling&amp;size=32" alt="Fantastical Scheduling" class="svelte-zslw0j"></span> </div> <a href="https://flexibits.com/fantastical/scheduling" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fantastical Scheduling 
A better and secure way to schedule calls and events" style="">Fantastical Scheduling</h3> <p class="description svelte-zslw0j">A better and secure way to schedule calls and events</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://flexibits.com/fantastical/scheduling" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.dashworks.ai/&amp;size=32" alt="Dashworks" class="svelte-zslw0j"></span> </div> <a href="https://www.dashworks.ai/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dashworks 
Your team's intelligent start page" style="">Dashworks</h3> <p class="description svelte-zslw0j">Your team's intelligent start page</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.dashworks.ai/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.range.co/product/goals&amp;size=32" alt="Range Goals" class="svelte-zslw0j"></span> </div> <a href="https://www.range.co/product/goals" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Range Goals 
The easiest way for teams to connect goals to daily work" style="">Range Goals</h3> <p class="description svelte-zslw0j">The easiest way for teams to connect goals to daily work</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.range.co/product/goals" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fable.to/&amp;size=32" alt="Fable" class="svelte-zslw0j"></span> </div> <a href="https://www.fable.to/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fable 
Smoother, faster product process" style="">Fable</h3> <p class="description svelte-zslw0j">Smoother, faster product process</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fable.to/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://paperbackhq.com/&amp;size=32" alt="Paperback" class="svelte-zslw0j"></span> </div> <a href="https://paperbackhq.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Paperback 
Simpler and tidier alternative to wiki pages." style="">Paperback</h3> <p class="description svelte-zslw0j">Simpler and tidier alternative to wiki pages.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://paperbackhq.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://coast.so&amp;size=32" alt="Coast" class="svelte-zslw0j"></span> </div> <a href="https://coast.so" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Coast 
Design &amp; product photo streams for teams." style="">Coast</h3> <p class="description svelte-zslw0j">Design &amp; product photo streams for teams.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://coast.so" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thegrapevine.tech/&amp;size=32" alt="Grapevine" class="svelte-zslw0j"></span> </div> <a href="https://thegrapevine.tech/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Grapevine 
Chat and work together in a 3D virtual world" style="">Grapevine</h3> <p class="description svelte-zslw0j">Chat and work together in a 3D virtual world</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thegrapevine.tech/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.springworks.in/engagewith/pulse-survey/&amp;size=32" alt="Pulse by EngageWith" class="svelte-zslw0j"></span> </div> <a href="https://www.springworks.in/engagewith/pulse-survey/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pulse by EngageWith 
Get instant feedback from your team on Slack &amp; MS Teams" style="">Pulse by EngageWith</h3> <p class="description svelte-zslw0j">Get instant feedback from your team on Slack &amp; MS Teams</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.springworks.in/engagewith/pulse-survey/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.kosyoffice.com/&amp;size=32" alt="Kosy" class="svelte-zslw0j"></span> </div> <a href="https://www.kosyoffice.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Kosy 
A virtual space where remote teams work and hang out in" style="">Kosy</h3> <p class="description svelte-zslw0j">A virtual space where remote teams work and hang out in</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.kosyoffice.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.airtable.com/product/interface-designer&amp;size=32" alt="Airtable Interface Designer" class="svelte-zslw0j"></span> </div> <a href="https://www.airtable.com/product/interface-designer" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Airtable Interface Designer 
Create custom interfaces to fit your team's specific needs" style="">Airtable Interface Designer</h3> <p class="description svelte-zslw0j">Create custom interfaces to fit your team's specific needs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.airtable.com/product/interface-designer" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.digstack.com/&amp;size=32" alt="DigStack" class="svelte-zslw0j"></span> </div> <a href="https://www.digstack.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="DigStack 
Free digital cardboard for teams of any size" style="">DigStack</h3> <p class="description svelte-zslw0j">Free digital cardboard for teams of any size</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.digstack.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


design_systems_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designsystems.com/&amp;size=32" alt="Design Systems" class="svelte-zslw0j"></span> </div> <a href="https://www.designsystems.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Systems 
A Figma publication for design systems creators, designers, developers, and managers" style="">Design Systems</h3> <p class="description svelte-zslw0j">A Figma publication for design systems creators, designers, developers, and managers</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designsystems.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ui-lib.com/downloads/uko-ui-figma/&amp;size=32" alt="UKO" class="svelte-zslw0j"></span> </div> <a href="https://ui-lib.com/downloads/uko-ui-figma/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UKO 
Free Figma dashboards &amp; design system" style="">UKO</h3> <p class="description svelte-zslw0j">Free Figma dashboards &amp; design system</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ui-lib.com/downloads/uko-ui-figma/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://polaris.shopify.com/&amp;size=32" alt="Polaris" class="svelte-zslw0j"></span> </div> <a href="https://polaris.shopify.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Polaris 
Our components are a collection of interface elements that can be reused across the Shopify system." style="">Polaris</h3> <p class="description svelte-zslw0j">Our components are a collection of interface elements that can be reused across the Shopify system.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://polaris.shopify.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://design-system.pluralsight.com/&amp;size=32" alt="Pluralsight" class="svelte-zslw0j"></span> </div> <a href="https://design-system.pluralsight.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pluralsight 
The UI building blocks for creating a cohesive design across Pluralsight products." style="">Pluralsight</h3> <p class="description svelte-zslw0j">The UI building blocks for creating a cohesive design across Pluralsight products.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://design-system.pluralsight.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://auth0-cosmos.vercel.app/#/&amp;size=32" alt="Cosmos" class="svelte-zslw0j"></span> </div> <a href="https://auth0-cosmos.vercel.app/#/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Cosmos 
Cosmos is a Design System to build Auth0 products." style="">Cosmos</h3> <p class="description svelte-zslw0j">Cosmos is a Design System to build Auth0 products.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://auth0-cosmos.vercel.app/#/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.radix-ui.com/&amp;size=32" alt="Radix UI" class="svelte-zslw0j"></span> </div> <a href="https://www.radix-ui.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Radix UI 
Radix Primitives is a low-level UI component library with a focus on accessibility, customization, and developer experience." style="">Radix UI</h3> <p class="description svelte-zslw0j">Radix Primitives is a low-level UI component library with a focus on accessibility, customization, and developer experience.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.radix-ui.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://bufferapp.github.io/ui/#/ui/GettingStarted/getting-started&amp;size=32" alt="Buffer" class="svelte-zslw0j"></span> </div> <a href="https://bufferapp.github.io/ui/#/ui/GettingStarted/getting-started" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Buffer 
A collection of reusable styles and components for faster product development." style="">Buffer</h3> <p class="description svelte-zslw0j">A collection of reusable styles and components for faster product development.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://bufferapp.github.io/ui/#/ui/GettingStarted/getting-started" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://canvas.workday.com/&amp;size=32" alt="Workday Canvas" class="svelte-zslw0j"></span> </div> <a href="https://canvas.workday.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Workday Canvas 
Delve into our design standards, writing guidelines, and playbook to create exceptional enterprise experiences." style="">Workday Canvas</h3> <p class="description svelte-zslw0j">Delve into our design standards, writing guidelines, and playbook to create exceptional enterprise experiences.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://canvas.workday.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thumbprint.design/&amp;size=32" alt="Thumbprint" class="svelte-zslw0j"></span> </div> <a href="https://thumbprint.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Thumbprint 
Assets for building high-quality, consistent user experiences at Thumbtack." style="">Thumbprint</h3> <p class="description svelte-zslw0j">Assets for building high-quality, consistent user experiences at Thumbtack.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thumbprint.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://solid.buzzfeed.com/&amp;size=32" alt="Solid" class="svelte-zslw0j"></span> </div> <a href="https://solid.buzzfeed.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Solid 
Solid uses immutable, atomic CSS classes to rapidly prototype and develop features, providing consistent styling options along with the flexibility to create new layouts and designs without the need to write additional CSS." style="">Solid</h3> <p class="description svelte-zslw0j">Solid uses immutable, atomic CSS classes to rapidly prototype and develop features, providing consistent styling options along with the flexibility to create new layouts and designs without the need to write additional CSS.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://solid.buzzfeed.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://primer.style/&amp;size=32" alt="Primer" class="svelte-zslw0j"></span> </div> <a href="https://primer.style/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Primer 
We chose to open-source it to allow the community to design and build their own projects with Primer." style="">Primer</h3> <p class="description svelte-zslw0j">We chose to open-source it to allow the community to design and build their own projects with Primer.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://primer.style/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://marvelapp.com/styleguide/overview/introduction&amp;size=32" alt="Marvel" class="svelte-zslw0j"></span> </div> <a href="https://marvelapp.com/styleguide/overview/introduction" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Marvel 
As Marvel continues to grow we created this styleguide to act as a central location where we house a live inventory of UI components, brand guidelines, brand assets, code snippets, developer guidelines, and more." style="">Marvel</h3> <p class="description svelte-zslw0j">As Marvel continues to grow we created this styleguide to act as a central location where we house a live inventory of UI components, brand guidelines, brand assets, code snippets, developer guidelines, and more.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://marvelapp.com/styleguide/overview/introduction" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.microsoft.com/design/fluent/#/&amp;size=32" alt="Fluent" class="svelte-zslw0j"></span> </div> <a href="https://www.microsoft.com/design/fluent/#/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fluent 
A collection of UX frameworks you can use to build Fluent experiences that fit seamlessly into a broad range of Microsoft products." style="">Fluent</h3> <p class="description svelte-zslw0j">A collection of UX frameworks you can use to build Fluent experiences that fit seamlessly into a broad range of Microsoft products.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.microsoft.com/design/fluent/#/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://evergreen.segment.com/&amp;size=32" alt="Evergreen" class="svelte-zslw0j"></span> </div> <a href="https://evergreen.segment.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Evergreen 
Evergreen is a React UI Framework for building ambitious products on the web." style="">Evergreen</h3> <p class="description svelte-zslw0j">Evergreen is a React UI Framework for building ambitious products on the web.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://evergreen.segment.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://atlassian.design/&amp;size=32" alt="Atlassian" class="svelte-zslw0j"></span> </div> <a href="https://atlassian.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Atlassian 
Atlassian's official UI library, built according to the Atlassian Design Guidelines." style="">Atlassian</h3> <p class="description svelte-zslw0j">Atlassian's official UI library, built according to the Atlassian Design Guidelines.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://atlassian.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ant.design/&amp;size=32" alt="Ant Design" class="svelte-zslw0j"></span> </div> <a href="https://ant.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ant Design 
A design system for enterprise-level products. Create an efficient and enjoyable work experience." style="">Ant Design</h3> <p class="description svelte-zslw0j">A design system for enterprise-level products. Create an efficient and enjoyable work experience.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ant.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://veritas.udacity.com/&amp;size=32" alt="Veritas" class="svelte-zslw0j"></span> </div> <a href="https://veritas.udacity.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Veritas 
Veritas Design System forms an underlying language that unites our visual style, components, and interaction patterns across design and code." style="">Veritas</h3> <p class="description svelte-zslw0j">Veritas Design System forms an underlying language that unites our visual style, components, and interaction patterns across design and code.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://veritas.udacity.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://paste.twilio.design/&amp;size=32" alt="Paste" class="svelte-zslw0j"></span> </div> <a href="https://paste.twilio.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Paste 
Build inclusive, delightful Twilio customer experiences with Paste." style="">Paste</h3> <p class="description svelte-zslw0j">Build inclusive, delightful Twilio customer experiences with Paste.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://paste.twilio.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://garden.zendesk.com/&amp;size=32" alt="Zendesk Garden" class="svelte-zslw0j"></span> </div> <a href="https://garden.zendesk.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Zendesk Garden 
Welcome to our curated collection of UI goodness, the Zendesk Garden. The Garden is where we grow user interface components for Zendesk products." style="">Zendesk Garden</h3> <p class="description svelte-zslw0j">Welcome to our curated collection of UI goodness, the Zendesk Garden. The Garden is where we grow user interface components for Zendesk products.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://garden.zendesk.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ux.mailchimp.com/patterns/color&amp;size=32" alt="UX Mailchimp" class="svelte-zslw0j"></span> </div> <a href="https://ux.mailchimp.com/patterns/color" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Mailchimp 
Mailchimp’s platform helps you scale faster with pre-built templates, time-saving automations, and intelligent reports and recommendations that keep you moving in the right direction." style="">UX Mailchimp</h3> <p class="description svelte-zslw0j">Mailchimp’s platform helps you scale faster with pre-built templates, time-saving automations, and intelligent reports and recommendations that keep you moving in the right direction.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ux.mailchimp.com/patterns/color" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://spectrum.adobe.com/&amp;size=32" alt="Spectrum Adobe" class="svelte-zslw0j"></span> </div> <a href="https://spectrum.adobe.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Spectrum Adobe 
Spectrum provides components and tools to help product teams work more efficiently, and to make Adobe’s applications more cohesive." style="">Spectrum Adobe</h3> <p class="description svelte-zslw0j">Spectrum provides components and tools to help product teams work more efficiently, and to make Adobe’s applications more cohesive.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://spectrum.adobe.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://material.io/design&amp;size=32" alt="Material Design" class="svelte-zslw0j"></span> </div> <a href="https://material.io/design" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Material Design 
Material is a design system – backed by open-source code – that helps teams build high-quality digital experiences." style="">Material Design</h3> <p class="description svelte-zslw0j">Material is a design system – backed by open-source code – that helps teams build high-quality digital experiences.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://material.io/design" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.lightningdesignsystem.com/&amp;size=32" alt="Lightning" class="svelte-zslw0j"></span> </div> <a href="https://www.lightningdesignsystem.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lightning 
The Lightning Design System enables you to build rich enterprise experiences and custom applications with the patterns and established best practices that are native to Salesforce." style="">Lightning</h3> <p class="description svelte-zslw0j">The Lightning Design System enables you to build rich enterprise experiences and custom applications with the patterns and established best practices that are native to Salesforce.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.lightningdesignsystem.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://design.gitlab.com/&amp;size=32" alt="Pajamas" class="svelte-zslw0j"></span> </div> <a href="https://design.gitlab.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pajamas 
Resources, components, and design guidelines behind GitLab" style="">Pajamas</h3> <p class="description svelte-zslw0j">Resources, components, and design guidelines behind GitLab</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://design.gitlab.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fast.design/&amp;size=32" alt="Fast DNA" class="svelte-zslw0j"></span> </div> <a href="https://www.fast.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fast DNA 
Use Fluent by default or customize design system properties to make it your own. Or, create your own design system to use with FAST components." style="">Fast DNA</h3> <p class="description svelte-zslw0j">Use Fluent by default or customize design system properties to make it your own. Or, create your own design system to use with FAST components.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fast.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.carbondesignsystem.com/&amp;size=32" alt="Carbon" class="svelte-zslw0j"></span> </div> <a href="https://www.carbondesignsystem.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Carbon 
Carbon is IBM’s open-source design system for products and experiences." style="">Carbon</h3> <p class="description svelte-zslw0j">Carbon is IBM’s open-source design system for products and experiences.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.carbondesignsystem.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://workbench.gusto.com/&amp;size=32" alt="Workbench" class="svelte-zslw0j"></span> </div> <a href="https://workbench.gusto.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Workbench 
Workbench design system contains documentation, tools, and standards that enable us to develop beautiful, cohesive, and accessible experiences for Gusto’s platform." style="">Workbench</h3> <p class="description svelte-zslw0j">Workbench design system contains documentation, tools, and standards that enable us to develop beautiful, cohesive, and accessible experiences for Gusto’s platform.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://workbench.gusto.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gestalt.netlify.app/home&amp;size=32" alt="Gestalt" class="svelte-zslw0j"></span> </div> <a href="https://gestalt.netlify.app/home" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gestalt 
Gestalt is Pinterest's design system." style="">Gestalt</h3> <p class="description svelte-zslw0j">Gestalt is Pinterest's design system.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gestalt.netlify.app/home" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


designer_podcasts_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://drunkenux.com/&amp;size=32" alt="Drunken UX" class="svelte-zslw0j"></span> </div> <a href="https://drunkenux.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Drunken UX 
An irreverent show where we drink and talk about building things on the internet." style="">Drunken UX</h3> <p class="description svelte-zslw0j">An irreverent show where we drink and talk about building things on the internet.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://drunkenux.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designcuts.com/honest-designers/&amp;size=32" alt="Honest Designers" class="svelte-zslw0j"></span> </div> <a href="https://www.designcuts.com/honest-designers/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Honest Designers 
Honest discussion from real designers." style="">Honest Designers</h3> <p class="description svelte-zslw0j">Honest discussion from real designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designcuts.com/honest-designers/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.intercom.com/blog/podcasts/&amp;size=32" alt="Inside Intercom" class="svelte-zslw0j"></span> </div> <a href="https://www.intercom.com/blog/podcasts/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="" style="">Inside Intercom</h3> <p class="description svelte-zslw0j"></p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.intercom.com/blog/podcasts/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://anchor.fm/layer&amp;size=32" alt="Layer Podcast" class="svelte-zslw0j"></span> </div> <a href="https://anchor.fm/layer" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Layer Podcast 
A series of conversations with designer founders about their careers and the design industry. hosted by Antonio Pratas" style="">Layer Podcast</h3> <p class="description svelte-zslw0j">A series of conversations with designer founders about their careers and the design industry. hosted by Antonio Pratas</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://anchor.fm/layer" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.indiehackers.com/podcast&amp;size=32" alt="Indie Hackers" class="svelte-zslw0j"></span> </div> <a href="https://www.indiehackers.com/podcast" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Indie Hackers 
Raw conversations with the founders behind profitable online businesses. Hosted by Courtland Allen." style="">Indie Hackers</h3> <p class="description svelte-zslw0j">Raw conversations with the founders behind profitable online businesses. Hosted by Courtland Allen.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.indiehackers.com/podcast" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.highresolution.design/&amp;size=32" alt="High Resolution" class="svelte-zslw0j"></span> </div> <a href="https://www.highresolution.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="High Resolution 
High Resolution is a video podcast series with 25 masters of the design industry hosted by Bobby Ghoshal and Jared Erondu. Learn how the world's best companies approach, communicate and deploy design." style="">High Resolution</h3> <p class="description svelte-zslw0j">High Resolution is a video podcast series with 25 masters of the design industry hosted by Bobby Ghoshal and Jared Erondu. Learn how the world's best companies approach, communicate and deploy design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.highresolution.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dribbble.com/overtime&amp;size=32" alt="Overtime" class="svelte-zslw0j"></span> </div> <a href="https://dribbble.com/overtime" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Overtime 
Dribbble’s official podcast goes behind the shots of your favorite designers." style="">Overtime</h3> <p class="description svelte-zslw0j">Dribbble’s official podcast goes behind the shots of your favorite designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dribbble.com/overtime" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://designyourlife.com.au/podcasts/&amp;size=32" alt="Design Your Life" class="svelte-zslw0j"></span> </div> <a href="https://designyourlife.com.au/podcasts/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="" style="">Design Your Life</h3> <p class="description svelte-zslw0j"></p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://designyourlife.com.au/podcasts/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://layout.fm/&amp;size=32" alt="Layout" class="svelte-zslw0j"></span> </div> <a href="https://layout.fm/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Layout 
A weekly podcast about design, technology, programming and everything else." style="">Layout</h3> <p class="description svelte-zslw0j">A weekly podcast about design, technology, programming and everything else.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://layout.fm/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designbetter.co/podcast&amp;size=32" alt="Design Better" class="svelte-zslw0j"></span> </div> <a href="https://www.designbetter.co/podcast" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Better 
We chat with design leaders to uncover how they achieved success. Hear stories and insights from the best in product design." style="">Design Better</h3> <p class="description svelte-zslw0j">We chat with design leaders to uncover how they achieved success. Hear stories and insights from the best in product design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designbetter.co/podcast" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uxpodcast.com/&amp;size=32" alt="UX Podcast" class="svelte-zslw0j"></span> </div> <a href="https://uxpodcast.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Podcast 
UXPodcast™ is a twice-monthly digital design podcast sharing insights about business, technology and people since 2011. We want to push the boundaries of how user experience is perceived and boost your confidence in the work you do." style="">UX Podcast</h3> <p class="description svelte-zslw0j">UXPodcast™ is a twice-monthly digital design podcast sharing insights about business, technology and people since 2011. We want to push the boundaries of how user experience is perceived and boost your confidence in the work you do.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uxpodcast.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://spec.fm/podcasts/design-details&amp;size=32" alt="Design Details" class="svelte-zslw0j"></span> </div> <a href="https://spec.fm/podcasts/design-details" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Details 
A weekly conversation about design process and culture." style="">Design Details</h3> <p class="description svelte-zslw0j">A weekly conversation about design process and culture.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://spec.fm/podcasts/design-details" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://revisionpath.com/&amp;size=32" alt="Revision Path" class="svelte-zslw0j"></span> </div> <a href="https://revisionpath.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Revision Path 
This is Revision Path — an award-winning weekly showcase of Black designers, developers, and digital creatives from all over the world." style="">Revision Path</h3> <p class="description svelte-zslw0j">This is Revision Path — an award-winning weekly showcase of Black designers, developers, and digital creatives from all over the world.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://revisionpath.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://spec.fm/podcasts/immutable&amp;size=32" alt="Immutable" class="svelte-zslw0j"></span> </div> <a href="https://spec.fm/podcasts/immutable" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Immutable 
A short, weekly show about design and development." style="">Immutable</h3> <p class="description svelte-zslw0j">A short, weekly show about design and development.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://spec.fm/podcasts/immutable" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://animalators.com/&amp;size=32" alt="Animalators" class="svelte-zslw0j"></span> </div> <a href="https://animalators.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="" style="">Animalators</h3> <p class="description svelte-zslw0j"></p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://animalators.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://anchor.fm/here-by-design/&amp;size=32" alt="Here by Design" class="svelte-zslw0j"></span> </div> <a href="https://anchor.fm/here-by-design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Here by Design 
A podcast exploring all the things my mind explores." style="">Here by Design</h3> <p class="description svelte-zslw0j">A podcast exploring all the things my mind explores.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://anchor.fm/here-by-design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://design.google/library/podcasts/&amp;size=32" alt="Google Design" class="svelte-zslw0j"></span> </div> <a href="https://design.google/library/podcasts/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Google Design 
Explore this month's featured podcast collection to get design inspiration and insights for the new year. Method explores the career journeys of designers at Google, while Design Notes goes in-depth with designers working in diverse creative disciplines." style="">Google Design</h3> <p class="description svelte-zslw0j">Explore this month's featured podcast collection to get design inspiration and insights for the new year. Method explores the career journeys of designers at Google, while Design Notes goes in-depth with designers working in diverse creative disciplines.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://design.google/library/podcasts/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://robhope.com/yo/&amp;size=32" alt="Yo!" class="svelte-zslw0j"></span> </div> <a href="https://robhope.com/yo/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Yo! 
Yo! is a celebration of great design and development online." style="">Yo!</h3> <p class="description svelte-zslw0j">Yo! is a celebration of great design and development online.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://robhope.com/yo/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://anchor.fm/students-who-design&amp;size=32" alt="Students Who Design" class="svelte-zslw0j"></span> </div> <a href="https://anchor.fm/students-who-design" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Students Who Design 
A podcast bridging the gap between students and the design industry. For Students, By Students." style="">Students Who Design</h3> <p class="description svelte-zslw0j">A podcast bridging the gap between students and the design industry. For Students, By Students.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://anchor.fm/students-who-design" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://responsivewebdesign.com/podcast/&amp;size=32" alt="Responsive Webdesign" class="svelte-zslw0j"></span> </div> <a href="https://responsivewebdesign.com/podcast/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Responsive Webdesign 
This is a Responsive Web Design Podcast, co-hosted by Karen McGrane and Ethan Marcotte. In each episode, Karen and Ethan interview the people who make responsive redesigns happen." style="">Responsive Webdesign</h3> <p class="description svelte-zslw0j">This is a Responsive Web Design Podcast, co-hosted by Karen McGrane and Ethan Marcotte. In each episode, Karen and Ethan interview the people who make responsive redesigns happen.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://responsivewebdesign.com/podcast/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://99percentinvisible.org/episodes/&amp;size=32" alt="99 Percent Invisible" class="svelte-zslw0j"></span> </div> <a href="https://99percentinvisible.org/episodes/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="99 Percent Invisible 
99% Invisible is about all the thought that goes into the things we don’t think about — the unnoticed architecture and design that shape our world." style="">99 Percent Invisible</h3> <p class="description svelte-zslw0j">99% Invisible is about all the thought that goes into the things we don’t think about — the unnoticed architecture and design that shape our world.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://99percentinvisible.org/episodes/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designmattersmedia.com/designmatters&amp;size=32" alt="Design Matters" class="svelte-zslw0j"></span> </div> <a href="https://www.designmattersmedia.com/designmatters" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Matters 
The world's first podcast about design and an inquiry into the broader world of creative culture through wide-ranging conversations with designers, writers, artists, curators, musicians, and other luminaries of contemporary thought" style="">Design Matters</h3> <p class="description svelte-zslw0j">The world's first podcast about design and an inquiry into the broader world of creative culture through wide-ranging conversations with designers, writers, artists, curators, musicians, and other luminaries of contemporary thought</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designmattersmedia.com/designmatters" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://scratchingthesurface.fm/&amp;size=32" alt="Scratching Surface" class="svelte-zslw0j"></span> </div> <a href="https://scratchingthesurface.fm/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Scratching Surface 
Is a podcast about the intersection of criticism and practice for graphic designers by Jarrett Fuller." style="">Scratching Surface</h3> <p class="description svelte-zslw0j">Is a podcast about the intersection of criticism and practice for graphic designers by Jarrett Fuller.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://scratchingthesurface.fm/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designlife.fm/&amp;size=32" alt="Design Life" class="svelte-zslw0j"></span> </div> <a href="https://www.designlife.fm/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Life 
Design Life is a podcast about design and side projects for motivated creators." style="">Design Life</h3> <p class="description svelte-zslw0j">Design Life is a podcast about design and side projects for motivated creators.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designlife.fm/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.usersknow.com/podcast/&amp;size=32" alt="Users Know" class="svelte-zslw0j"></span> </div> <a href="https://www.usersknow.com/podcast/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Users Know 
Kate Rutter and Laura Klein have a podcast! We get together once in awhile and argue about UX, tech, or what to drink." style="">Users Know</h3> <p class="description svelte-zslw0j">Kate Rutter and Laura Klein have a podcast! We get together once in awhile and argue about UX, tech, or what to drink.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.usersknow.com/podcast/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://itunes.apple.com/us/podcast/ramblings-of-a-designer-podcast/id1410850598?mt=2&amp;size=32" alt="Ramblings of a Designer" class="svelte-zslw0j"></span> </div> <a href="https://itunes.apple.com/us/podcast/ramblings-of-a-designer-podcast/id1410850598?mt=2" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="" style="">Ramblings of a Designer</h3> <p class="description svelte-zslw0j"></p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://itunes.apple.com/us/podcast/ramblings-of-a-designer-podcast/id1410850598?mt=2" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://shoptalkshow.com/&amp;size=32" alt="Shop Talk Show" class="svelte-zslw0j"></span> </div> <a href="https://shoptalkshow.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Shop Talk Show 
A live podcast about front end web design and UX." style="">Shop Talk Show</h3> <p class="description svelte-zslw0j">A live podcast about front end web design and UX.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://shoptalkshow.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://designer.fm/&amp;size=32" alt="Designer &amp; Designer" class="svelte-zslw0j"></span> </div> <a href="https://designer.fm/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Designer &amp; Designer 
Designer &amp; Designer is a podcast about design. Each episode dives into a design topic with candor and humor, exposing the rarely talked about challenges ..." style="">Designer &amp; Designer</h3> <p class="description svelte-zslw0j">Designer &amp; Designer is a podcast about design. Each episode dives into a design topic with candor and humor, exposing the rarely talked about challenges ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://designer.fm/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://anchor.fm/worldclass-designer&amp;size=32" alt="World-class" class="svelte-zslw0j"></span> </div> <a href="https://anchor.fm/worldclass-designer" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="World-class 
This podcast is a series of interviews with world-class designers. I interview designers from world-leading tech companies such as IDEO, Dropbox, Airbnb, ..." style="">World-class</h3> <p class="description svelte-zslw0j">This podcast is a series of interviews with world-class designers. I interview designers from world-leading tech companies such as IDEO, Dropbox, Airbnb, ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://anchor.fm/worldclass-designer" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uibreakfast.com/category/podcast/&amp;size=32" alt="UI Breakfast" class="svelte-zslw0j"></span> </div> <a href="https://uibreakfast.com/category/podcast/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Breakfast 
UI Breakfast Podcast. Join us for exciting conversations about UI/UX design, products, marketing, and so much more." style="">UI Breakfast</h3> <p class="description svelte-zslw0j">UI Breakfast Podcast. Join us for exciting conversations about UI/UX design, products, marketing, and so much more.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uibreakfast.com/category/podcast/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://designnotes.fm/&amp;size=32" alt="Design Notes" class="svelte-zslw0j"></span> </div> <a href="https://designnotes.fm/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Notes 
Design Notes is a podcast about creative work and what it teaches us, hosted by Google's Liam Spradlin. Each episode we talk with people from unique ..." style="">Design Notes</h3> <p class="description svelte-zslw0j">Design Notes is a podcast about creative work and what it teaches us, hosted by Google's Liam Spradlin. Each episode we talk with people from unique ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://designnotes.fm/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://podcasts.apple.com/us/podcast/99-invisible/id394775318?mt=2&amp;size=32" alt="99% Invisible" class="svelte-zslw0j"></span> </div> <a href="https://podcasts.apple.com/us/podcast/99-invisible/id394775318?mt=2" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="99% Invisible 
99% Invisible is a weekly exploration of the process and power of design and architecture. From award winning producer Roman Mars." style="">99% Invisible</h3> <p class="description svelte-zslw0j">99% Invisible is a weekly exploration of the process and power of design and architecture. From award winning producer Roman Mars.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://podcasts.apple.com/us/podcast/99-invisible/id394775318?mt=2" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://coachscottyrussell.com/side-hustlers-perspective&amp;size=32" alt="Perspective" class="svelte-zslw0j"></span> </div> <a href="https://coachscottyrussell.com/side-hustlers-perspective" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Perspective 
The Side Hustler's Perspective Podcast is fuel for your mind and creative grind. Each week, Coach Scotty Russell and his industry-leading guests break down ..." style="">Perspective</h3> <p class="description svelte-zslw0j">The Side Hustler's Perspective Podcast is fuel for your mind and creative grind. Each week, Coach Scotty Russell and his industry-leading guests break down ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://coachscottyrussell.com/side-hustlers-perspective" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ondesignpodcast.com/&amp;size=32" alt="On Design" class="svelte-zslw0j"></span> </div> <a href="https://ondesignpodcast.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="On Design 
On Design brings you insightful conversations with design's most inspiring figures - from designers to artists, creative directors to entrepreneurs and ..." style="">On Design</h3> <p class="description svelte-zslw0j">On Design brings you insightful conversations with design's most inspiring figures - from designers to artists, creative directors to entrepreneurs and ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ondesignpodcast.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://maze.co/podcast/&amp;size=32" alt="The Optimal Path Podcast" class="svelte-zslw0j"></span> </div> <a href="https://maze.co/podcast/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="The Optimal Path Podcast 
A podcast about product decision-making" style="">The Optimal Path Podcast</h3> <p class="description svelte-zslw0j">A podcast about product decision-making</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://maze.co/podcast/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://app.nooble.xyz/&amp;size=32" alt="Nooble: Tune into Crypto, News, Tech!" class="svelte-zslw0j"></span> </div> <a href="https://app.nooble.xyz/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Nooble: Tune into Crypto, News, Tech! 
🎙 Easiest way to get into podcasting" style="">Nooble: Tune into Crypto, News, Tech!</h3> <p class="description svelte-zslw0j">🎙 Easiest way to get into podcasting</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://app.nooble.xyz/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://disctopia.com/&amp;size=32" alt="Disctopia" class="svelte-zslw0j"></span> </div> <a href="https://disctopia.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Disctopia 
A podcasting &amp; streaming platform for creatives" style="">Disctopia</h3> <p class="description svelte-zslw0j">A podcasting &amp; streaming platform for creatives</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://disctopia.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.startcasts.com/&amp;size=32" alt="Startcasts" class="svelte-zslw0j"></span> </div> <a href="https://www.startcasts.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Startcasts 
Search engine for great startup &amp; product podcasts" style="">Startcasts</h3> <p class="description svelte-zslw0j">Search engine for great startup &amp; product podcasts</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.startcasts.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://podcatalysts.substack.com/&amp;size=32" alt="Podcatalyst Newsletter" class="svelte-zslw0j"></span> </div> <a href="https://podcatalysts.substack.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Podcatalyst Newsletter 
Weekly podcast recommendations, right in your inbox" style="">Podcatalyst Newsletter</h3> <p class="description svelte-zslw0j">Weekly podcast recommendations, right in your inbox</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://podcatalysts.substack.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.podopolo.com&amp;size=32" alt="Podopolo" class="svelte-zslw0j"></span> </div> <a href="https://www.podopolo.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Podopolo 
Social podcasting app to discover, listen and engage" style="">Podopolo</h3> <p class="description svelte-zslw0j">Social podcasting app to discover, listen and engage</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.podopolo.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://rephonic.com/discover?utm_source=producthunt&amp;size=32" alt="Discover New Podcasts" class="svelte-zslw0j"></span> </div> <a href="https://rephonic.com/discover?utm_source=producthunt" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Discover New Podcasts 
Podcast recommendations based on what you already listen to." style="">Discover New Podcasts</h3> <p class="description svelte-zslw0j">Podcast recommendations based on what you already listen to.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://rephonic.com/discover?utm_source=producthunt" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://play.google.com/store/apps/details?id=com.lisny.android&amp;size=32" alt="Lisny" class="svelte-zslw0j"></span> </div> <a href="https://play.google.com/store/apps/details?id=com.lisny.android" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lisny 
Discover new podcasts" style="">Lisny</h3> <p class="description svelte-zslw0j">Discover new podcasts</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://play.google.com/store/apps/details?id=com.lisny.android" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.moonbeam.fm&amp;size=32" alt="Moonbeam" class="svelte-zslw0j"></span> </div> <a href="https://www.moonbeam.fm" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Moonbeam 
Easiest way to discover your next favorite podcast" style="">Moonbeam</h3> <p class="description svelte-zslw0j">Easiest way to discover your next favorite podcast</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.moonbeam.fm" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://anchor.fm/talktoyourusers&amp;size=32" alt="Talk To Your Users" class="svelte-zslw0j"></span> </div> <a href="https://anchor.fm/talktoyourusers" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Talk To Your Users 
Top pieces of advice in the startup world, through a podcast" style="">Talk To Your Users</h3> <p class="description svelte-zslw0j">Top pieces of advice in the startup world, through a podcast</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://anchor.fm/talktoyourusers" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.note-bytes.com/&amp;size=32" alt="NoteBytes" class="svelte-zslw0j"></span> </div> <a href="https://www.note-bytes.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="NoteBytes 
Turn your notes into podcasts and share them with the world" style="">NoteBytes</h3> <p class="description svelte-zslw0j">Turn your notes into podcasts and share them with the world</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.note-bytes.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://podcastcharts.byspotify.com/&amp;size=32" alt="The Podcast Charts" class="svelte-zslw0j"></span> </div> <a href="https://podcastcharts.byspotify.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="The Podcast Charts 
Your daily guide to popular podcasts on Spotify" style="">The Podcast Charts</h3> <p class="description svelte-zslw0j">Your daily guide to popular podcasts on Spotify</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://podcastcharts.byspotify.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://origin.fm/now/&amp;size=32" alt="Backup My Podcast" class="svelte-zslw0j"></span> </div> <a href="https://origin.fm/now/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Backup My Podcast 
Disaster recovery for the work you're most proud of" style="">Backup My Podcast</h3> <p class="description svelte-zslw0j">Disaster recovery for the work you're most proud of</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://origin.fm/now/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


ux_research_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://crowdsignal.com/&amp;size=32" alt="Crowd Signal" class="svelte-zslw0j"></span> </div> <a href="https://crowdsignal.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Crowd Signal 
Collect, organize and analyze data from a variety of sources, including social media and mobile." style="">Crowd Signal</h3> <p class="description svelte-zslw0j">Collect, organize and analyze data from a variety of sources, including social media and mobile.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://crowdsignal.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.yesinsights.com/&amp;size=32" alt="Yes Insights" class="svelte-zslw0j"></span> </div> <a href="https://www.yesinsights.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Yes Insights 
Simple one question and NPS surveys to improve your business." style="">Yes Insights</h3> <p class="description svelte-zslw0j">Simple one question and NPS surveys to improve your business.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.yesinsights.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.airsquirrels.com/reflector&amp;size=32" alt="Reflector" class="svelte-zslw0j"></span> </div> <a href="https://www.airsquirrels.com/reflector" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Reflector 
Reflector is a basic screen-mirroring and recording tool so you can conduct user tests remotely, using any existing wireframes or prototypes." style="">Reflector</h3> <p class="description svelte-zslw0j">Reflector is a basic screen-mirroring and recording tool so you can conduct user tests remotely, using any existing wireframes or prototypes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.airsquirrels.com/reflector" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://userbitapp.com/&amp;size=32" alt="UserBit" class="svelte-zslw0j"></span> </div> <a href="https://userbitapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UserBit 
Create interview notes, personas, sitemaps and research documents that bring founders, designers and developers on the same page." style="">UserBit</h3> <p class="description svelte-zslw0j">Create interview notes, personas, sitemaps and research documents that bring founders, designers and developers on the same page.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://userbitapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.typeform.com/&amp;size=32" alt="Typeform" class="svelte-zslw0j"></span> </div> <a href="https://www.typeform.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Typeform 
Use a simple drag-and-drop interface to create any kind of form, survey, or questionnaire, and even take credit card payments." style="">Typeform</h3> <p class="description svelte-zslw0j">Use a simple drag-and-drop interface to create any kind of form, survey, or questionnaire, and even take credit card payments.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.typeform.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://surveymonkey.com/&amp;size=32" alt="Survey Monkey" class="svelte-zslw0j"></span> </div> <a href="https://surveymonkey.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Survey Monkey 
Online survey tool to capture the voices and opinions of the people who matter most to you." style="">Survey Monkey</h3> <p class="description svelte-zslw0j">Online survey tool to capture the voices and opinions of the people who matter most to you.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://surveymonkey.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.wufoo.com/&amp;size=32" alt="Wufoo" class="svelte-zslw0j"></span> </div> <a href="https://www.wufoo.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Wufoo 
Create online forms, collect data and payments, and automate your workflows." style="">Wufoo</h3> <p class="description svelte-zslw0j">Create online forms, collect data and payments, and automate your workflows.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.wufoo.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.feedbacklite.com/&amp;size=32" alt="Feedback Lite" class="svelte-zslw0j"></span> </div> <a href="https://www.feedbacklite.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Feedback Lite 
Collect high quality customer feedback using Voice of Customer solutions designed to improve your website performance and boost customer engagement." style="">Feedback Lite</h3> <p class="description svelte-zslw0j">Collect high quality customer feedback using Voice of Customer solutions designed to improve your website performance and boost customer engagement.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.feedbacklite.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.keepitusable.com/&amp;size=32" alt="Keep It Usable" class="svelte-zslw0j"></span> </div> <a href="https://www.keepitusable.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Keep It Usable 
User experience agency specialising in research and user-centred design services. They create digital platforms that people enjoy using and increase sales." style="">Keep It Usable</h3> <p class="description svelte-zslw0j">User experience agency specialising in research and user-centred design services. They create digital platforms that people enjoy using and increase sales.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.keepitusable.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uxmyths.com/&amp;size=32" alt="UX Myths" class="svelte-zslw0j"></span> </div> <a href="https://uxmyths.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Myths 
UX Myths is aimed at both product designers and clients. They set themselves the task to end the battles of personal opinions and – often false – beliefs and move design conversations into the realm of facts and evidence." style="">UX Myths</h3> <p class="description svelte-zslw0j">UX Myths is aimed at both product designers and clients. They set themselves the task to end the battles of personal opinions and – often false – beliefs and move design conversations into the realm of facts and evidence.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uxmyths.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uxmovement.com/&amp;size=32" alt="UX Movement" class="svelte-zslw0j"></span> </div> <a href="https://uxmovement.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Movement 
The most innovative UX design publication challenging the status quo." style="">UX Movement</h3> <p class="description svelte-zslw0j">The most innovative UX design publication challenging the status quo.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uxmovement.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://baymard.com/&amp;size=32" alt="Baymard Institute" class="svelte-zslw0j"></span> </div> <a href="https://baymard.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Baymard Institute 
They are an independent web usability research institute." style="">Baymard Institute</h3> <p class="description svelte-zslw0j">They are an independent web usability research institute.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://baymard.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ux.stackexchange.com/&amp;size=32" alt="UX Stack Exchange" class="svelte-zslw0j"></span> </div> <a href="https://ux.stackexchange.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Stack Exchange 
User Experience Stack Exchange is a question and answer site for user experience researchers and experts." style="">UX Stack Exchange</h3> <p class="description svelte-zslw0j">User Experience Stack Exchange is a question and answer site for user experience researchers and experts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ux.stackexchange.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.uxmatters.com/&amp;size=32" alt="UX Matters" class="svelte-zslw0j"></span> </div> <a href="https://www.uxmatters.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Matters 
UXmatters provides insights and inspiration to experienced professionals working in every aspect of User Experience, as well as those who are just beginning their journey in the field." style="">UX Matters</h3> <p class="description svelte-zslw0j">UXmatters provides insights and inspiration to experienced professionals working in every aspect of User Experience, as well as those who are just beginning their journey in the field.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.uxmatters.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.uie.com/&amp;size=32" alt="UIE" class="svelte-zslw0j"></span> </div> <a href="https://www.uie.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UIE 
UIE is a leading research, training, and consulting firm specializing in UX, web site and product usability." style="">UIE</h3> <p class="description svelte-zslw0j">UIE is a leading research, training, and consulting firm specializing in UX, web site and product usability.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.uie.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.nngroup.com/&amp;size=32" alt="NN Group" class="svelte-zslw0j"></span> </div> <a href="https://www.nngroup.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="NN Group 
They are a UX research and consulting firm trusted by leading organizations world-wide to provide reliable guidance on user experience." style="">NN Group</h3> <p class="description svelte-zslw0j">They are a UX research and consulting firm trusted by leading organizations world-wide to provide reliable guidance on user experience.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.nngroup.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://usabilitygeek.com/&amp;size=32" alt="Usability Geek" class="svelte-zslw0j"></span> </div> <a href="https://usabilitygeek.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Usability Geek 
Usability Geek is a blog that provides practical and useful insights into topics like Usability, User Experience (UX)." style="">Usability Geek</h3> <p class="description svelte-zslw0j">Usability Geek is a blog that provides practical and useful insights into topics like Usability, User Experience (UX).</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://usabilitygeek.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pagetuner.io/&amp;size=32" alt="Pagetuner" class="svelte-zslw0j"></span> </div> <a href="https://pagetuner.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pagetuner 
Visual feedback directly on your website" style="">Pagetuner</h3> <p class="description svelte-zslw0j">Visual feedback directly on your website</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pagetuner.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.arcade.software/&amp;size=32" alt="Arcade" class="svelte-zslw0j"></span> </div> <a href="https://www.arcade.software/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Arcade 
Build playful interactive demos" style="">Arcade</h3> <p class="description svelte-zslw0j">Build playful interactive demos</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.arcade.software/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://webask.io/&amp;size=32" alt="WebAsk" class="svelte-zslw0j"></span> </div> <a href="https://webask.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="WebAsk 
A next-gen toolkit for feedback analysis" style="">WebAsk</h3> <p class="description svelte-zslw0j">A next-gen toolkit for feedback analysis</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://webask.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://reacty.net/&amp;size=32" alt="reacty" class="svelte-zslw0j"></span> </div> <a href="https://reacty.net/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="reacty 
User feedback, but simple and private." style="">reacty</h3> <p class="description svelte-zslw0j">User feedback, but simple and private.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://reacty.net/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://embedsocial.com/forms/&amp;size=32" alt="EmbedSocial Forms Builder" class="svelte-zslw0j"></span> </div> <a href="https://embedsocial.com/forms/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="EmbedSocial Forms Builder 
Build interactive web forms &amp; feedback widgets in seconds." style="">EmbedSocial Forms Builder</h3> <p class="description svelte-zslw0j">Build interactive web forms &amp; feedback widgets in seconds.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://embedsocial.com/forms/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://app.usepunchlist.com/producthunt&amp;size=32" alt="Punchlist" class="svelte-zslw0j"></span> </div> <a href="https://app.usepunchlist.com/producthunt" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Punchlist 
Feedback layer on top of websites, images, and PDFs" style="">Punchlist</h3> <p class="description svelte-zslw0j">Feedback layer on top of websites, images, and PDFs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://app.usepunchlist.com/producthunt" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.ribbonapp.com/&amp;size=32" alt="Ribbon 2.0" class="svelte-zslw0j"></span> </div> <a href="https://www.ribbonapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ribbon 2.0 
The product-first user interviewing platform" style="">Ribbon 2.0</h3> <p class="description svelte-zslw0j">The product-first user interviewing platform</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.ribbonapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://easyusertest.com/en&amp;size=32" alt="Easy User Test" class="svelte-zslw0j"></span> </div> <a href="https://easyusertest.com/en" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Easy User Test 
Validate your text &amp; design decisions with real users" style="">Easy User Test</h3> <p class="description svelte-zslw0j">Validate your text &amp; design decisions with real users</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://easyusertest.com/en" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


productivity_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://en.eagle.cool/&amp;size=32" alt="Eagle" class="svelte-zslw0j"></span> </div> <a href="https://en.eagle.cool/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Eagle 
A better way to collect, search and organize your design files in a logical way and all in one place." style="">Eagle</h3> <p class="description svelte-zslw0j">A better way to collect, search and organize your design files in a logical way and all in one place.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://en.eagle.cool/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


inspiration_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://httpster.net/&amp;size=32" alt="Httpster" class="svelte-zslw0j"></span> </div> <a href="https://httpster.net/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Httpster 
An inspiration resource showcasing rocking websites made by people from all over the world." style="">Httpster</h3> <p class="description svelte-zslw0j">An inspiration resource showcasing rocking websites made by people from all over the world.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://httpster.net/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.lapa.ninja/&amp;size=32" alt="Lapa Ninja" class="svelte-zslw0j"></span> </div> <a href="https://www.lapa.ninja/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lapa Ninja 
Landing page design inspiration from around the web. 1800+ landing page examples and updated daily." style="">Lapa Ninja</h3> <p class="description svelte-zslw0j">Landing page design inspiration from around the web. 1800+ landing page examples and updated daily.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.lapa.ninja/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://onepagelove.com/inspiration&amp;size=32" alt="One Page Love" class="svelte-zslw0j"></span> </div> <a href="https://onepagelove.com/inspiration" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="One Page Love 
A collection of beautiful unique One Page websites for website design inspiration." style="">One Page Love</h3> <p class="description svelte-zslw0j">A collection of beautiful unique One Page websites for website design inspiration.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://onepagelove.com/inspiration" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://codemyui.com/&amp;size=32" alt="CodeMyUI" class="svelte-zslw0j"></span> </div> <a href="https://codemyui.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CodeMyUI 
Handpicked collection of web design &amp; UI inspiration with code snippets." style="">CodeMyUI</h3> <p class="description svelte-zslw0j">Handpicked collection of web design &amp; UI inspiration with code snippets.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://codemyui.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.creative-portfolios.com/&amp;size=32" alt="Creative Portfolios" class="svelte-zslw0j"></span> </div> <a href="https://www.creative-portfolios.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Creative Portfolios 
A curation of the most creative portfolios made by designers &amp; developers." style="">Creative Portfolios</h3> <p class="description svelte-zslw0j">A curation of the most creative portfolios made by designers &amp; developers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.creative-portfolios.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://hoverstat.es/&amp;size=32" alt="Hover States" class="svelte-zslw0j"></span> </div> <a href="https://hoverstat.es/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Hover States 
Showcase great work from the bleeding edge of digital culture for, and with, the creative community." style="">Hover States</h3> <p class="description svelte-zslw0j">Showcase great work from the bleeding edge of digital culture for, and with, the creative community.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://hoverstat.es/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://owwly.com/feed/inspirations&amp;size=32" alt="Owwly" class="svelte-zslw0j"></span> </div> <a href="https://owwly.com/feed/inspirations" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Owwly 
Home for digital products crafted with passion to design." style="">Owwly</h3> <p class="description svelte-zslw0j">Home for digital products crafted with passion to design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://owwly.com/feed/inspirations" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pageflows.com/&amp;size=32" alt="Page Flows" class="svelte-zslw0j"></span> </div> <a href="https://pageflows.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Page Flows 
User flow videos and screenshots to inspire you when you're stuck. Discover mobile and web design patterns for over 160 different tasks." style="">Page Flows</h3> <p class="description svelte-zslw0j">User flow videos and screenshots to inspire you when you're stuck. Discover mobile and web design patterns for over 160 different tasks.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pageflows.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://reallygoodemails.com/&amp;size=32" alt="Really Good Emails" class="svelte-zslw0j"></span> </div> <a href="https://reallygoodemails.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Really Good Emails 
4,150+ handpicked email design." style="">Really Good Emails</h3> <p class="description svelte-zslw0j">4,150+ handpicked email design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://reallygoodemails.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.reallygoodux.io/&amp;size=32" alt="ReallyGoodUX" class="svelte-zslw0j"></span> </div> <a href="https://www.reallygoodux.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ReallyGoodUX 
Screenshots, and examples of great UX from real mobile and web products. Discover the best UX examples—including onboarding tours and walkthroughs." style="">ReallyGoodUX</h3> <p class="description svelte-zslw0j">Screenshots, and examples of great UX from real mobile and web products. Discover the best UX examples—including onboarding tours and walkthroughs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.reallygoodux.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://saaslandingpage.com/&amp;size=32" alt="Saas Landing Page" class="svelte-zslw0j"></span> </div> <a href="https://saaslandingpage.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Saas Landing Page 
İscover the best landing page examples created by top-class SaaS companies, and get ideas and inspiration for your next design project." style="">Saas Landing Page</h3> <p class="description svelte-zslw0j">İscover the best landing page examples created by top-class SaaS companies, and get ideas and inspiration for your next design project.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://saaslandingpage.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://saaspages.xyz/&amp;size=32" alt="Saas Pages" class="svelte-zslw0j"></span> </div> <a href="https://saaspages.xyz/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Saas Pages 
A collection of the best landing pages with a focus on copywriting and design." style="">Saas Pages</h3> <p class="description svelte-zslw0j">A collection of the best landing pages with a focus on copywriting and design.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://saaspages.xyz/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thedesignteam.io/&amp;size=32" alt="The Design Team" class="svelte-zslw0j"></span> </div> <a href="https://thedesignteam.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="The Design Team 
Comics about a design team for a tech startup in Silicon Valley." style="">The Design Team</h3> <p class="description svelte-zslw0j">Comics about a design team for a tech startup in Silicon Valley.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thedesignteam.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.uisources.com/screenshots&amp;size=32" alt="UI Sources" class="svelte-zslw0j"></span> </div> <a href="https://www.uisources.com/screenshots" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Sources 
Over 500+ interactions from the best designed and top-grossing apps on the App Store today." style="">UI Sources</h3> <p class="description svelte-zslw0j">Over 500+ interactions from the best designed and top-grossing apps on the App Store today.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.uisources.com/screenshots" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uigarage.net/&amp;size=32" alt="UI Garage" class="svelte-zslw0j"></span> </div> <a href="https://uigarage.net/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Garage 
Daily UI inspiration &amp; patterns for designers, developers to find inspiration, tools and the best resources for your project." style="">UI Garage</h3> <p class="description svelte-zslw0j">Daily UI inspiration &amp; patterns for designers, developers to find inspiration, tools and the best resources for your project.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uigarage.net/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uxarchive.com/&amp;size=32" alt="UX Archive" class="svelte-zslw0j"></span> </div> <a href="https://uxarchive.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Archive 
Browse more than 400 user flows across 120 mobile apps. Examine tasks such as booking, logging in, onboarding, purchasing, searching, and more." style="">UX Archive</h3> <p class="description svelte-zslw0j">Browse more than 400 user flows across 120 mobile apps. Examine tasks such as booking, logging in, onboarding, purchasing, searching, and more.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uxarchive.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.waveguide.io/&amp;size=32" alt="Waveguide" class="svelte-zslw0j"></span> </div> <a href="https://www.waveguide.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Waveguide 
A design knowledge bank with thousands of artificially enriched examples of product and brand experience (examples of Mobile App, Landing pages, eCommerce, CX/UX Patterns)." style="">Waveguide</h3> <p class="description svelte-zslw0j">A design knowledge bank with thousands of artificially enriched examples of product and brand experience (examples of Mobile App, Landing pages, eCommerce, CX/UX Patterns).</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.waveguide.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.webdesignmuseum.org/&amp;size=32" alt="Web Design Museum" class="svelte-zslw0j"></span> </div> <a href="https://www.webdesignmuseum.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Web Design Museum 
Over 1,200 carefully selected web sites that show web design trends between the years 1994 and 2006." style="">Web Design Museum</h3> <p class="description svelte-zslw0j">Over 1,200 carefully selected web sites that show web design trends between the years 1994 and 2006.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.webdesignmuseum.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.awwwards.com/&amp;size=32" alt="Awwwards" class="svelte-zslw0j"></span> </div> <a href="https://www.awwwards.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Awwwards 
Awwwards are the Website Awards that recognize and promote..." style="">Awwwards</h3> <p class="description svelte-zslw0j">Awwwards are the Website Awards that recognize and promote...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.awwwards.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mobbin.design/browse/ios/apps&amp;size=32" alt="Mobbin" class="svelte-zslw0j"></span> </div> <a href="https://mobbin.design/browse/ios/apps" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mobbin 
Get inspiration from over 170 iOS apps and 10,000 patterns (screenshots from iPhone X) available on the platform." style="">Mobbin</h3> <p class="description svelte-zslw0j">Get inspiration from over 170 iOS apps and 10,000 patterns (screenshots from iPhone X) available on the platform.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mobbin.design/browse/ios/apps" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.simform.com/mobile-patterns/&amp;size=32" alt="Mobile Patterns" class="svelte-zslw0j"></span> </div> <a href="https://www.simform.com/mobile-patterns/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mobile Patterns 
A design inspirational library featuring finest UI UX Patterns (iOS and Android) for designers, developers, and product makers to reference." style="">Mobile Patterns</h3> <p class="description svelte-zslw0j">A design inspirational library featuring finest UI UX Patterns (iOS and Android) for designers, developers, and product makers to reference.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.simform.com/mobile-patterns/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pttrns.com/&amp;size=32" alt="Pttrns" class="svelte-zslw0j"></span> </div> <a href="https://www.pttrns.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pttrns 
Pttrns is a collection of mobile design patterns, UI design resources, and inspiration for iPhones, iPads, Android devices, Apple Watches, and more. New York, New York, United States." style="">Pttrns</h3> <p class="description svelte-zslw0j">Pttrns is a collection of mobile design patterns, UI design resources, and inspiration for iPhones, iPads, Android devices, Apple Watches, and more. New York, New York, United States.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pttrns.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://screenlane.com/?ref=uimovement&amp;size=32" alt="UI Movement" class="svelte-zslw0j"></span> </div> <a href="https://screenlane.com/?ref=uimovement" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Movement 
UI Movement started as a newsletter that featured the best UI designs every day. The real primary difference between UI Movement and other design inspiration sites is that they focus exclusively on UI designs." style="">UI Movement</h3> <p class="description svelte-zslw0j">UI Movement started as a newsletter that featured the best UI designs every day. The real primary difference between UI Movement and other design inspiration sites is that they focus exclusively on UI designs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://screenlane.com/?ref=uimovement" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://collectui.com/&amp;size=32" alt="Collect UI" class="svelte-zslw0j"></span> </div> <a href="https://collectui.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Collect UI 
A platform for your daily inspiration collected from regular UI &amp; beyond. Based on Dribbble shots, handpicked." style="">Collect UI</h3> <p class="description svelte-zslw0j">A platform for your daily inspiration collected from regular UI &amp; beyond. Based on Dribbble shots, handpicked.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://collectui.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.uplabs.com/&amp;size=32" alt="UpLabs" class="svelte-zslw0j"></span> </div> <a href="https://www.uplabs.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UpLabs 
UpLabs is a community-powered marketplace that lets designers and developers share ready-to-ship UI designing resource — like login boxes and payment forms — to build apps and sites." style="">UpLabs</h3> <p class="description svelte-zslw0j">UpLabs is a community-powered marketplace that lets designers and developers share ready-to-ship UI designing resource — like login boxes and payment forms — to build apps and sites.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.uplabs.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uilearn.com/&amp;size=32" alt="UI Learn" class="svelte-zslw0j"></span> </div> <a href="https://uilearn.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Learn 
UI learn is set up to make you learn design step by step with a practical curriculum that focuses 100% on learn-by-doing and a great example of free UI designing resources." style="">UI Learn</h3> <p class="description svelte-zslw0j">UI learn is set up to make you learn design step by step with a practical curriculum that focuses 100% on learn-by-doing and a great example of free UI designing resources.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uilearn.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://neede.co/#/&amp;size=32" alt="Neede" class="svelte-zslw0j"></span> </div> <a href="https://neede.co/#/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Neede 
Neede started as a personal project to organize the different design resources that quickly grew to a place to share online design resources with other designers." style="">Neede</h3> <p class="description svelte-zslw0j">Neede started as a personal project to organize the different design resources that quickly grew to a place to share online design resources with other designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://neede.co/#/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ecomm.design/&amp;size=32" alt="Ecomm.design" class="svelte-zslw0j"></span> </div> <a href="https://ecomm.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ecomm.design 
Ecomm.design aims to showcase an eclectic mix of stores across many different verticals, with less of a focus on front-end experimentation and more on the metrics and UX practices that matter to ecommerce." style="">Ecomm.design</h3> <p class="description svelte-zslw0j">Ecomm.design aims to showcase an eclectic mix of stores across many different verticals, with less of a focus on front-end experimentation and more on the metrics and UX practices that matter to ecommerce.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ecomm.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dribbble.com/&amp;size=32" alt="Dribbble" class="svelte-zslw0j"></span> </div> <a href="https://dribbble.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dribbble 
Dribbble is where designers gain inspiration, feedback, community." style="">Dribbble</h3> <p class="description svelte-zslw0j">Dribbble is where designers gain inspiration, feedback, community.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dribbble.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.producthunt.com/&amp;size=32" alt="Product Hunt" class="svelte-zslw0j"></span> </div> <a href="https://www.producthunt.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Product Hunt 
Product Hunt is a curation of the best new products, every day." style="">Product Hunt</h3> <p class="description svelte-zslw0j">Product Hunt is a curation of the best new products, every day.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.producthunt.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.behance.net/&amp;size=32" alt="Behance" class="svelte-zslw0j"></span> </div> <a href="https://www.behance.net/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Behance 
Behance is the world's largest creative network." style="">Behance</h3> <p class="description svelte-zslw0j">Behance is the world's largest creative network.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.behance.net/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://maxibestof.one/&amp;size=32" alt="MaxiBestOf" class="svelte-zslw0j"></span> </div> <a href="https://maxibestof.one/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MaxiBestOf 
Daily feed of websites &amp; fonts for inspiration." style="">MaxiBestOf</h3> <p class="description svelte-zslw0j">Daily feed of websites &amp; fonts for inspiration.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://maxibestof.one/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://nicelydone.club/&amp;size=32" alt="Nicelydone" class="svelte-zslw0j"></span> </div> <a href="https://nicelydone.club/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Nicelydone 
Save hours of research by browsing 13,700+ screenshot examples." style="">Nicelydone</h3> <p class="description svelte-zslw0j">Save hours of research by browsing 13,700+ screenshot examples.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://nicelydone.club/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sesov.com/&amp;size=32" alt="Sesov" class="svelte-zslw0j"></span> </div> <a href="https://sesov.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sesov 
Anonymous design feedback. Get a free evaluation of your work." style="">Sesov</h3> <p class="description svelte-zslw0j">Anonymous design feedback. Get a free evaluation of your work.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sesov.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://superposition.design/&amp;size=32" alt="SuperPosition" class="svelte-zslw0j"></span> </div> <a href="https://superposition.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="SuperPosition 
Extract design tokens from sites &amp; use them in design tools." style="">SuperPosition</h3> <p class="description svelte-zslw0j">Extract design tokens from sites &amp; use them in design tools.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://superposition.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.bestfolios.com/&amp;size=32" alt="Bestfolios" class="svelte-zslw0j"></span> </div> <a href="https://www.bestfolios.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Bestfolios 
The best of UI,UX and product designer portfolio and resume." style="">Bestfolios</h3> <p class="description svelte-zslw0j">The best of UI,UX and product designer portfolio and resume.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.bestfolios.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://godly.website/&amp;size=32" alt="Godly" class="svelte-zslw0j"></span> </div> <a href="https://godly.website/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Godly 
Godly is a curation of the best web design inspiration, every day." style="">Godly</h3> <p class="description svelte-zslw0j">Godly is a curation of the best web design inspiration, every day.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://godly.website/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.darkmodedesign.com/&amp;size=32" alt="Dark Mode Design" class="svelte-zslw0j"></span> </div> <a href="https://www.darkmodedesign.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dark Mode Design 
Library designed websites that are either exclusively in dark mode." style="">Dark Mode Design</h3> <p class="description svelte-zslw0j">Library designed websites that are either exclusively in dark mode.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.darkmodedesign.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://visualjournal.it/&amp;size=32" alt="Visual Journal" class="svelte-zslw0j"></span> </div> <a href="https://visualjournal.it/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Visual Journal 
Strategy, branding and visual communication." style="">Visual Journal</h3> <p class="description svelte-zslw0j">Strategy, branding and visual communication.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://visualjournal.it/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uijar.com/&amp;size=32" alt="UIJar" class="svelte-zslw0j"></span> </div> <a href="https://uijar.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UIJar 
Handpicked design inspiration for your real life projects" style="">UIJar</h3> <p class="description svelte-zslw0j">Handpicked design inspiration for your real life projects</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uijar.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://screenlane.com/&amp;size=32" alt="Screenlane" class="svelte-zslw0j"></span> </div> <a href="https://screenlane.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Screenlane 
Get inspired and keep up with the latest web &amp; mobile app UI design trends." style="">Screenlane</h3> <p class="description svelte-zslw0j">Get inspired and keep up with the latest web &amp; mobile app UI design trends.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://screenlane.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://designvault.io/&amp;size=32" alt="Design Vault" class="svelte-zslw0j"></span> </div> <a href="https://designvault.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design Vault 
Design Vault is a curated library of screenshots &amp; interaction patterns from the world's best digital products. Gain insights, explore trends and understand ..." style="">Design Vault</h3> <p class="description svelte-zslw0j">Design Vault is a curated library of screenshots &amp; interaction patterns from the world's best digital products. Gain insights, explore trends and understand ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://designvault.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://interface-index.com/&amp;size=32" alt="Interface Index" class="svelte-zslw0j"></span> </div> <a href="https://interface-index.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Interface Index 
Interface elements from the best B2B, SaaS and desktop apps and services." style="">Interface Index</h3> <p class="description svelte-zslw0j">Interface elements from the best B2B, SaaS and desktop apps and services.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://interface-index.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://lookup.design/&amp;size=32" alt="Lookup.design" class="svelte-zslw0j"></span> </div> <a href="https://lookup.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lookup.design 
Browse handpicked ui and ux design examples and find inspiration for your next website or app." style="">Lookup.design</h3> <p class="description svelte-zslw0j">Browse handpicked ui and ux design examples and find inspiration for your next website or app.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://lookup.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://emptystat.es/&amp;size=32" alt="Empty States" class="svelte-zslw0j"></span> </div> <a href="https://emptystat.es/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Empty States 
A curated gallery showcasing designs where no data is available in the UI." style="">Empty States</h3> <p class="description svelte-zslw0j">A curated gallery showcasing designs where no data is available in the UI.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://emptystat.es/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.autointerfaces.com/&amp;size=32" alt="Auto Interfaces" class="svelte-zslw0j"></span> </div> <a href="https://www.autointerfaces.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Auto Interfaces 
Auto Interfaces is the best collection of modern vehicle infotainment system designs, interactions and screens." style="">Auto Interfaces</h3> <p class="description svelte-zslw0j">Auto Interfaces is the best collection of modern vehicle infotainment system designs, interactions and screens.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.autointerfaces.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.hudsandguis.com/&amp;size=32" alt="Hudsandguis" class="svelte-zslw0j"></span> </div> <a href="https://www.hudsandguis.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Hudsandguis 
HUDS and GUIS is an inspiration resource site featuring Future User Interfaces, Graphic User Interfaces, Heads Up Displays and UX/UI Design from" style="">Hudsandguis</h3> <p class="description svelte-zslw0j">HUDS and GUIS is an inspiration resource site featuring Future User Interfaces, Graphic User Interfaces, Heads Up Displays and UX/UI Design from</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.hudsandguis.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


instagram_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://apps.apple.com/us/app/meep-meep/id1547578067&amp;size=32" alt="meep • meep" class="svelte-zslw0j"></span> </div> <a href="https://apps.apple.com/us/app/meep-meep/id1547578067" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="meep • meep 
Activity tracking widget for Instagram" style="">meep • meep</h3> <p class="description svelte-zslw0j">Activity tracking widget for Instagram</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://apps.apple.com/us/app/meep-meep/id1547578067" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pallyy.com/instagram-feed-planner&amp;size=32" alt="Instagram Feed Planner by Pallyy" class="svelte-zslw0j"></span> </div> <a href="https://pallyy.com/instagram-feed-planner" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Instagram Feed Planner by Pallyy 
Visually plan your Instagram feed &amp; schedule to Instagram" style="">Instagram Feed Planner by Pallyy</h3> <p class="description svelte-zslw0j">Visually plan your Instagram feed &amp; schedule to Instagram</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pallyy.com/instagram-feed-planner" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://instantcard.co.uk&amp;size=32" alt="InstantCard" class="svelte-zslw0j"></span> </div> <a href="https://instantcard.co.uk" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="InstantCard 
Turn your articles into Instagram images" style="">InstantCard</h3> <p class="description svelte-zslw0j">Turn your articles into Instagram images</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://instantcard.co.uk" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://info.mention.com/en/instagram-engagement-report-2021&amp;size=32" alt="Instagram Engagement Report 2021" class="svelte-zslw0j"></span> </div> <a href="https://info.mention.com/en/instagram-engagement-report-2021" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Instagram Engagement Report 2021 
Data &amp; insights collected from 100M+ Instagram posts" style="">Instagram Engagement Report 2021</h3> <p class="description svelte-zslw0j">Data &amp; insights collected from 100M+ Instagram posts</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://info.mention.com/en/instagram-engagement-report-2021" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


logo_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://logolab.app/home&amp;size=32" alt="Logo Lab" class="svelte-zslw0j"></span> </div> <a href="https://logolab.app/home" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Logo Lab 
Put your logo to the test and find out where it succeeds and where improvements could be made." style="">Logo Lab</h3> <p class="description svelte-zslw0j">Put your logo to the test and find out where it succeeds and where improvements could be made.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://logolab.app/home" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.logotouse.com/&amp;size=32" alt="Logo To Use" class="svelte-zslw0j"></span> </div> <a href="https://www.logotouse.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Logo To Use 
The internet’s source of free logos" style="">Logo To Use</h3> <p class="description svelte-zslw0j">The internet’s source of free logos</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.logotouse.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://rareblocks.xyz/logos-by-larkef&amp;size=32" alt="Free Logos by Larkef" class="svelte-zslw0j"></span> </div> <a href="https://rareblocks.xyz/logos-by-larkef" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Free Logos by Larkef 
The perfect logo for your project is just a click away." style="">Free Logos by Larkef</h3> <p class="description svelte-zslw0j">The perfect logo for your project is just a click away.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://rareblocks.xyz/logos-by-larkef" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://instantlogodesign.com/&amp;size=32" alt="Instant Logo" class="svelte-zslw0j"></span> </div> <a href="https://instantlogodesign.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Instant Logo 
Get your logo with beautiful design instantly" style="">Instant Logo</h3> <p class="description svelte-zslw0j">Get your logo with beautiful design instantly</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://instantlogodesign.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://design.easeus.com/&amp;size=32" alt="EaseUS Logo Maker" class="svelte-zslw0j"></span> </div> <a href="https://design.easeus.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="EaseUS Logo Maker 
Design a stunning logo, in minutes" style="">EaseUS Logo Maker</h3> <p class="description svelte-zslw0j">Design a stunning logo, in minutes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://design.easeus.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.tenscope.co/free-logos&amp;size=32" alt="Free Logos by Tenscope" class="svelte-zslw0j"></span> </div> <a href="https://www.tenscope.co/free-logos" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Free Logos by Tenscope 
Open source logos for your projects, perfect for MVPs" style="">Free Logos by Tenscope</h3> <p class="description svelte-zslw0j">Open source logos for your projects, perfect for MVPs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.tenscope.co/free-logos" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.librelogos.org/&amp;size=32" alt="Libre Logos" class="svelte-zslw0j"></span> </div> <a href="https://www.librelogos.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Libre Logos 
Free, exclusive logos for open source projects &amp; NGOs" style="">Libre Logos</h3> <p class="description svelte-zslw0j">Free, exclusive logos for open source projects &amp; NGOs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.librelogos.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.domains.hatrio.com/product-page/sharp-smooth-free-logo-pack&amp;size=32" alt="Smooth &amp; Sharp" class="svelte-zslw0j"></span> </div> <a href="https://www.domains.hatrio.com/product-page/sharp-smooth-free-logo-pack" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Smooth &amp; Sharp 
100% free logo pack with sources included" style="">Smooth &amp; Sharp</h3> <p class="description svelte-zslw0j">100% free logo pack with sources included</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.domains.hatrio.com/product-page/sharp-smooth-free-logo-pack" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mybrandnewlogo.com/&amp;size=32" alt="My Brand New Logo" class="svelte-zslw0j"></span> </div> <a href="https://mybrandnewlogo.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="My Brand New Logo 
My Brand New Logo is an online logo maker that automatically generates professional logo designs." style="">My Brand New Logo</h3> <p class="description svelte-zslw0j">My Brand New Logo is an online logo maker that automatically generates professional logo designs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mybrandnewlogo.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://app.logopony.com/en/details/&amp;size=32" alt="Logopony" class="svelte-zslw0j"></span> </div> <a href="https://app.logopony.com/en/details/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Logopony 
Logopony is a new kind of logo maker that uses Artificial Intelligence and Machine Learning to generate unlimited creative and distinct logo ideas for your ..." style="">Logopony</h3> <p class="description svelte-zslw0j">Logopony is a new kind of logo maker that uses Artificial Intelligence and Machine Learning to generate unlimited creative and distinct logo ideas for your ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://app.logopony.com/en/details/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.fontinlogo.com/logos&amp;size=32" alt="Font In Logo" class="svelte-zslw0j"></span> </div> <a href="https://www.fontinlogo.com/logos" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Font In Logo 
Search and find fonts used by World Brands." style="">Font In Logo</h3> <p class="description svelte-zslw0j">Search and find fonts used by World Brands.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.fontinlogo.com/logos" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


mockup_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://istockphoto.com/&amp;size=32" alt="iStock" class="svelte-zslw0j"></span> </div> <a href="https://istockphoto.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="iStock 
iStock by Getty Images is your complete creative resource for original content, with millions of photos, illustrations, videos &amp; audio to choose from." style="">iStock</h3> <p class="description svelte-zslw0j">iStock by Getty Images is your complete creative resource for original content, with millions of photos, illustrations, videos &amp; audio to choose from.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.istockphoto.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://smartmockups.com/&amp;size=32" alt="Smart Mockups" class="svelte-zslw0j"></span> </div> <a href="https://smartmockups.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Smart Mockups 
Create stunning product mockups and get more sales." style="">Smart Mockups</h3> <p class="description svelte-zslw0j">Create stunning product mockups and get more sales.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://smartmockups.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dribbble.com/ahmetsulek/buckets/453428-Curated-Mockups&amp;size=32" alt="Dribbble Curated" class="svelte-zslw0j"></span> </div> <a href="https://dribbble.com/ahmetsulek/buckets/453428-Curated-Mockups" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dribbble Curated 
Free mockups curated on Dribbble." style="">Dribbble Curated</h3> <p class="description svelte-zslw0j">Free mockups curated on Dribbble.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dribbble.com/ahmetsulek/buckets/453428-Curated-Mockups" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockuuups.studio/&amp;size=32" alt="Mockuuups" class="svelte-zslw0j"></span> </div> <a href="https://mockuuups.studio/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockuuups 
Beautiful high-resolution mockups to present your designs and prototypes. Loved by designers worldwide and compatible with Photoshop &amp; Sketch." style="">Mockuuups</h3> <p class="description svelte-zslw0j">Beautiful high-resolution mockups to present your designs and prototypes. Loved by designers worldwide and compatible with Photoshop &amp; Sketch.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockuuups.studio/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockerie.io/&amp;size=32" alt="Mockerie" class="svelte-zslw0j"></span> </div> <a href="https://mockerie.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockerie 
Interactive and instant mockups on stock photography." style="">Mockerie</h3> <p class="description svelte-zslw0j">Interactive and instant mockups on stock photography.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockerie.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dunnnk.com/&amp;size=32" alt="Dunnnk" class="svelte-zslw0j"></span> </div> <a href="https://dunnnk.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dunnnk 
Dunnnk generates beautiful product mockups. Upload your design and Dunnnk give you a high resolution mockup in return." style="">Dunnnk</h3> <p class="description svelte-zslw0j">Dunnnk generates beautiful product mockups. Upload your design and Dunnnk give you a high resolution mockup in return.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dunnnk.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.mockupworld.co/all-mockups/&amp;size=32" alt="Mockup World" class="svelte-zslw0j"></span> </div> <a href="https://www.mockupworld.co/all-mockups/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockup World 
Free PSD Mockups: iPhone, iPad, MacBook, iMac, Apple Watch, Billboards &amp; Signs." style="">Mockup World</h3> <p class="description svelte-zslw0j">Free PSD Mockups: iPhone, iPad, MacBook, iMac, Apple Watch, Billboards &amp; Signs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.mockupworld.co/all-mockups/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://freedesignresources.net/category/free-mockups/&amp;size=32" alt="FDR" class="svelte-zslw0j"></span> </div> <a href="https://freedesignresources.net/category/free-mockups/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="FDR 
Handpicked free mockups to make your presentations stand out. Ranging from print, apparel, packaging, screen, logo, and more." style="">FDR</h3> <p class="description svelte-zslw0j">Handpicked free mockups to make your presentations stand out. Ranging from print, apparel, packaging, screen, logo, and more.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://freedesignresources.net/category/free-mockups/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://cleanmock.com/&amp;size=32" alt="Clean Mock" class="svelte-zslw0j"></span> </div> <a href="https://cleanmock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Clean Mock 
Create stunning mockups using latest device frames like iPhone X &amp; custom backgrounds that make your mobile or website design standout, right from your browser quickly &amp; for free." style="">Clean Mock</h3> <p class="description svelte-zslw0j">Create stunning mockups using latest device frames like iPhone X &amp; custom backgrounds that make your mobile or website design standout, right from your browser quickly &amp; for free.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://cleanmock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://rotato.xyz/&amp;size=32" alt="Rotato" class="svelte-zslw0j"></span> </div> <a href="https://rotato.xyz/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Rotato 
Animated 3D mockups for your app designs. No 3D experience required." style="">Rotato</h3> <p class="description svelte-zslw0j">Animated 3D mockups for your app designs. No 3D experience required.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://rotato.xyz/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://browserframe.com/&amp;size=32" alt="Browser Frame" class="svelte-zslw0j"></span> </div> <a href="https://browserframe.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Browser Frame 
Browser Frame is a free tool that helps you wrap screenshots in different browser frames. Supports Chrome, Firefox, Safari, and more." style="">Browser Frame</h3> <p class="description svelte-zslw0j">Browser Frame is a free tool that helps you wrap screenshots in different browser frames. Supports Chrome, Firefox, Safari, and more.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://browserframe.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockuuups.studio/&amp;size=32" alt="Mockuuups Studio" class="svelte-zslw0j"></span> </div> <a href="https://mockuuups.studio/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockuuups Studio 
Drag-and-drop tool for creating beautiful app previews and marketing materials." style="">Mockuuups Studio</h3> <p class="description svelte-zslw0j">Drag-and-drop tool for creating beautiful app previews and marketing materials.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockuuups.studio/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://placeit.net/?search=iphone&amp;size=32" alt="Place It" class="svelte-zslw0j"></span> </div> <a href="https://placeit.net/?search=iphone" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Place It 
You can make make a logo, video, mockup, flyer, business card and social media image in seconds right from your browser." style="">Place It</h3> <p class="description svelte-zslw0j">You can make make a logo, video, mockup, flyer, business card and social media image in seconds right from your browser.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://placeit.net/?search=iphone" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://datamatic.io/#showPremium=false&amp;size=32" alt="Data Matic" class="svelte-zslw0j"></span> </div> <a href="https://datamatic.io/#showPremium=false" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Data Matic 
Easily pick a data visualization template, customize it, and publish on your website." style="">Data Matic</h3> <p class="description svelte-zslw0j">Easily pick a data visualization template, customize it, and publish on your website.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://datamatic.io/#showPremium=false" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.designermill.com/&amp;size=32" alt="Designer Mill" class="svelte-zslw0j"></span> </div> <a href="https://www.designermill.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Designer Mill 
Collection of free PSDs, Sketch files, free Fonts and other resources for designers, updated every day on DesignerMill." style="">Designer Mill</h3> <p class="description svelte-zslw0j">Collection of free PSDs, Sketch files, free Fonts and other resources for designers, updated every day on DesignerMill.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.designermill.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uigenerator.org/&amp;size=32" alt="UI Generator" class="svelte-zslw0j"></span> </div> <a href="https://uigenerator.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Generator 
Get mockup UI in seconds" style="">UI Generator</h3> <p class="description svelte-zslw0j">Get mockup UI in seconds</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uigenerator.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockrocket.io/&amp;size=32" alt="MockRocket" class="svelte-zslw0j"></span> </div> <a href="https://mockrocket.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MockRocket 
3D device mockups &amp; animations, right in your browser" style="">MockRocket</h3> <p class="description svelte-zslw0j">3D device mockups &amp; animations, right in your browser</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockrocket.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.glorify.com/mockup-tool/&amp;size=32" alt="Mockups by Glorify" class="svelte-zslw0j"></span> </div> <a href="https://www.glorify.com/mockup-tool/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockups by Glorify 
Bring your designs to life with stunning mockups" style="">Mockups by Glorify</h3> <p class="description svelte-zslw0j">Bring your designs to life with stunning mockups</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.glorify.com/mockup-tool/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockover.com/&amp;size=32" alt="Mockover" class="svelte-zslw0j"></span> </div> <a href="https://mockover.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockover 
Turn any image into a custom mockup" style="">Mockover</h3> <p class="description svelte-zslw0j">Turn any image into a custom mockup</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockover.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://morflax.com/things/&amp;size=32" alt="Things 2.0" class="svelte-zslw0j"></span> </div> <a href="https://morflax.com/things/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Things 2.0 
Generate 3D device mockups in a quick &amp; engaging way" style="">Things 2.0</h3> <p class="description svelte-zslw0j">Generate 3D device mockups in a quick &amp; engaging way</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://morflax.com/things/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://previewed.app/&amp;size=32" alt="Previewed" class="svelte-zslw0j"></span> </div> <a href="https://previewed.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Previewed 
Beautiful iPhone mockups to present your app" style="">Previewed</h3> <p class="description svelte-zslw0j">Beautiful iPhone mockups to present your app</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://previewed.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockly.xyz/&amp;size=32" alt="Mockly" class="svelte-zslw0j"></span> </div> <a href="https://mockly.xyz/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockly 
Stunning ebook mockups in minutes" style="">Mockly</h3> <p class="description svelte-zslw0j">Stunning ebook mockups in minutes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockly.xyz/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://artboard.studio/&amp;size=32" alt="Artboard Studio" class="svelte-zslw0j"></span> </div> <a href="https://artboard.studio/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Artboard Studio 
Design, collaborate and present all in the browser" style="">Artboard Studio</h3> <p class="description svelte-zslw0j">Design, collaborate and present all in the browser</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://artboard.studio/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://h4academy.gumroad.com/l/claymockups&amp;size=32" alt="Clay Mockups" class="svelte-zslw0j"></span> </div> <a href="https://h4academy.gumroad.com/l/claymockups" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Clay Mockups 
Free set of beautiful device mockups for your designs" style="">Clay Mockups</h3> <p class="description svelte-zslw0j">Free set of beautiful device mockups for your designs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://h4academy.gumroad.com/l/claymockups" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pixeltrue.com/mockup-generator&amp;size=32" alt="Pixeltrue Mockup Generator" class="svelte-zslw0j"></span> </div> <a href="https://www.pixeltrue.com/mockup-generator" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pixeltrue Mockup Generator 
Create beautiful product mockups in just a few clicks" style="">Pixeltrue Mockup Generator</h3> <p class="description svelte-zslw0j">Create beautiful product mockups in just a few clicks</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pixeltrue.com/mockup-generator" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockreality.shop/&amp;size=32" alt="Mock Reality" class="svelte-zslw0j"></span> </div> <a href="https://mockreality.shop/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mock Reality 
Premium mockups made with designers at heart" style="">Mock Reality</h3> <p class="description svelte-zslw0j">Premium mockups made with designers at heart</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockreality.shop/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://angle.sh/&amp;size=32" alt="Angle 4" class="svelte-zslw0j"></span> </div> <a href="https://angle.sh/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Angle 4 
Vector device mockups for Sketch, Figma and XD." style="">Angle 4</h3> <p class="description svelte-zslw0j">Vector device mockups for Sketch, Figma and XD.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://angle.sh/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockuphunt.co/&amp;size=32" alt="MockupHunt" class="svelte-zslw0j"></span> </div> <a href="https://mockuphunt.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MockupHunt 
Hunting the best free mockups from the trusted websites." style="">MockupHunt</h3> <p class="description svelte-zslw0j">Hunting the best free mockups from the trusted websites.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockuphunt.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mrmockup.com/freebies&amp;size=32" alt="Mr Mockup" class="svelte-zslw0j"></span> </div> <a href="https://mrmockup.com/freebies" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mr Mockup 
We build unique and professional mockups." style="">Mr Mockup</h3> <p class="description svelte-zslw0j">We build unique and professional mockups.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mrmockup.com/freebies" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockups-design.com/&amp;size=32" alt="Mockup Design" class="svelte-zslw0j"></span> </div> <a href="https://mockups-design.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockup Design 
Premium quality free mockups ready for instant download." style="">Mockup Design</h3> <p class="description svelte-zslw0j">Premium quality free mockups ready for instant download.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockups-design.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pixelbuddha.net/mockups&amp;size=32" alt="Pixelbuddha" class="svelte-zslw0j"></span> </div> <a href="https://pixelbuddha.net/mockups" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pixelbuddha 
Mockups for personal and commercial use." style="">Pixelbuddha</h3> <p class="description svelte-zslw0j">Mockups for personal and commercial use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pixelbuddha.net/mockups" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://cleanshot.vercel.app/&amp;size=32" alt="Cleanshot" class="svelte-zslw0j"></span> </div> <a href="https://cleanshot.vercel.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Cleanshot 
Generate screenshots for any website from its URLs." style="">Cleanshot</h3> <p class="description svelte-zslw0j">Generate screenshots for any website from its URLs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://cleanshot.vercel.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.canva.com/&amp;size=32" alt="Canva" class="svelte-zslw0j"></span> </div> <a href="https://www.canva.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Canva 
Create beautiful designs with your team. Use Canva's drag-and-drop feature and layouts to design, share and print business cards, logos, presentations and ..." style="">Canva</h3> <p class="description svelte-zslw0j">Create beautiful designs with your team. Use Canva's drag-and-drop feature and layouts to design, share and print business cards, logos, presentations and ...</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.canva.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.anthonyboyd.graphics/mockups/&amp;size=32" alt="Anthony Boyd Graphics" class="svelte-zslw0j"></span> </div> <a href="https://www.anthonyboyd.graphics/mockups/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Anthony Boyd Graphics 
Free Graphic Design Resources, Mockups, and Textures by Anthony Boyd Graphics." style="">Anthony Boyd Graphics</h3> <p class="description svelte-zslw0j">Free Graphic Design Resources, Mockups, and Textures by Anthony Boyd Graphics.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.anthonyboyd.graphics/mockups/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.ls.graphics/free-mockups&amp;size=32" alt="LS graphics" class="svelte-zslw0j"></span> </div> <a href="https://www.ls.graphics/free-mockups" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="LS graphics 
Huge collection of free mockups, patterns, illustrations, scene creators, DIY scenes, for Photoshop, Sketch, and Figma." style="">LS graphics</h3> <p class="description svelte-zslw0j">Huge collection of free mockups, patterns, illustrations, scene creators, DIY scenes, for Photoshop, Sketch, and Figma.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.ls.graphics/free-mockups" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


placeholder_texts_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pirateipsum.me/&amp;size=32" alt="Pirate Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://pirateipsum.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pirate Ipsum 
The best Lorem Ipsum Generator in all the sea! Heave this scurvy copyfiller fer yar next adventure and cajol yar clients into walking the plank with ev'ry layout! Configure above, then get yer pirate ipsum...own the high seas, arg!" style="">Pirate Ipsum</h3> <p class="description svelte-zslw0j">The best Lorem Ipsum Generator in all the sea! Heave this scurvy copyfiller fer yar next adventure and cajol yar clients into walking the plank with ev'ry layout! Configure above, then get yer pirate ipsum...own the high seas, arg!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pirateipsum.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://hipsum.co/&amp;size=32" alt="Hipster Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://hipsum.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Hipster Ipsum 
Oh. You need a little dummy text for your mockup? How quaint." style="">Hipster Ipsum</h3> <p class="description svelte-zslw0j">Oh. You need a little dummy text for your mockup? How quaint.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://hipsum.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://bavaria-ipsum.de/&amp;size=32" alt="Bavaria Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://bavaria-ipsum.de/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Bavaria Ipsum 
Bavaria ipsum - a bavarian lorem ipsum generator." style="">Bavaria Ipsum</h3> <p class="description svelte-zslw0j">Bavaria ipsum - a bavarian lorem ipsum generator.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://bavaria-ipsum.de/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://officeipsum.com/&amp;size=32" alt="Office Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://officeipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Office Ipsum 
Dummy Copy for the Corporate World." style="">Office Ipsum</h3> <p class="description svelte-zslw0j">Dummy Copy for the Corporate World.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://officeipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tunaipsum.com/&amp;size=32" alt="Tuna Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://tunaipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Tuna Ipsum 
Does your lorem ipsum text long for something a little fishier? Give our generator a try… it’s fishy!" style="">Tuna Ipsum</h3> <p class="description svelte-zslw0j">Does your lorem ipsum text long for something a little fishier? Give our generator a try… it’s fishy!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tunaipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://deloreanipsum.com/&amp;size=32" alt="DoLorean Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://deloreanipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="DoLorean Ipsum 
DeLorean Ipsum is a jQuery plugin to generate sample text using the Back To The Future script." style="">DoLorean Ipsum</h3> <p class="description svelte-zslw0j">DeLorean Ipsum is a jQuery plugin to generate sample text using the Back To The Future script.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://deloreanipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://obamaipsum.com/&amp;size=32" alt="Obama Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://obamaipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Obama Ipsum 
The most presidential lorem ipsum in history." style="">Obama Ipsum</h3> <p class="description svelte-zslw0j">The most presidential lorem ipsum in history.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://obamaipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://yoloipsum.wordpress.com/&amp;size=32" alt="Yolo Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://yoloipsum.wordpress.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Yolo Ipsum 
Like Lorem Ipsum, bute more fun." style="">Yolo Ipsum</h3> <p class="description svelte-zslw0j">Like Lorem Ipsum, bute more fun.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://yoloipsum.wordpress.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.cipsum.com/&amp;size=32" alt="Corporate Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://www.cipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Corporate Ipsum 
Corporate Ipsum was designed to facilitate the needs of corporate paper-pushers everywhere." style="">Corporate Ipsum</h3> <p class="description svelte-zslw0j">Corporate Ipsum was designed to facilitate the needs of corporate paper-pushers everywhere.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.cipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pommyipsum.com/&amp;size=32" alt="Pommy Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://www.pommyipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pommy Ipsum 
Keep Calm and Pommy Ipsum" style="">Pommy Ipsum</h3> <p class="description svelte-zslw0j">Keep Calm and Pommy Ipsum</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pommyipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://hairylipsum.com/&amp;size=32" alt="Hairy Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://hairylipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Hairy Ipsum 
To mark Movember, you can fill in the gaps with some random hairy lipsum. After all, no project is a blank project when you’ve a luxurious moustache." style="">Hairy Ipsum</h3> <p class="description svelte-zslw0j">To mark Movember, you can fill in the gaps with some random hairy lipsum. After all, no project is a blank project when you’ve a luxurious moustache.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://hairylipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://heisenbergipsum.com/&amp;size=32" alt="Heisenberg Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://heisenbergipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Heisenberg Ipsum 
Some mad text, yo - courtesy of Mr. White. Okay, SORRY...I meant Heisenberg. B*tch." style="">Heisenberg Ipsum</h3> <p class="description svelte-zslw0j">Some mad text, yo - courtesy of Mr. White. Okay, SORRY...I meant Heisenberg. B*tch.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://heisenbergipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://baseballipsum.apphb.com/&amp;size=32" alt="Baseball Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://baseballipsum.apphb.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="" style="">Baseball Ipsum</h3> <p class="description svelte-zslw0j"></p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://baseballipsum.apphb.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://slipsum.com/&amp;size=32" alt="Samuel L Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://slipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Samuel L Ipsum 
Samuel L Ipsum is a Lorem Ipsum Generator, it uses quotes from films which Samuel L Jackson has starred in place of the standard ipsum text." style="">Samuel L Ipsum</h3> <p class="description svelte-zslw0j">Samuel L Ipsum is a Lorem Ipsum Generator, it uses quotes from films which Samuel L Jackson has starred in place of the standard ipsum text.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://slipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.cupcakeipsum.com/&amp;size=32" alt="Cup Cake Ipsum" class="svelte-zslw0j"></span> </div> <a href="https://www.cupcakeipsum.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Cup Cake Ipsum 
Awesomeness! First lorem ipsum generator that can be addictive." style="">Cup Cake Ipsum</h3> <p class="description svelte-zslw0j">Awesomeness! First lorem ipsum generator that can be addictive.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.cupcakeipsum.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.speakhuman.today/&amp;size=32" alt="Speak Human" class="svelte-zslw0j"></span> </div> <a href="https://www.speakhuman.today/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Speak Human 
Generate human centric microcopy for all purposes." style="">Speak Human</h3> <p class="description svelte-zslw0j">Generate human centric microcopy for all purposes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.speakhuman.today/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


prototyping_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://marvelapp.com/&amp;size=32" alt="Marvel" class="svelte-zslw0j"></span> </div> <a href="https://marvelapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Marvel 
Simple design, prototyping and collaboration." style="">Marvel</h3> <p class="description svelte-zslw0j">Simple design, prototyping and collaboration.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://marvelapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.meetalva.io/&amp;size=32" alt="Alva" class="svelte-zslw0j"></span> </div> <a href="https://www.meetalva.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Alva 
Create living prototypes with code components." style="">Alva</h3> <p class="description svelte-zslw0j">Create living prototypes with code components.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.meetalva.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://origami.design/&amp;size=32" alt="Origami" class="svelte-zslw0j"></span> </div> <a href="https://origami.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Origami 
Design Prototyping." style="">Origami</h3> <p class="description svelte-zslw0j">Design Prototyping.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://origami.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://balsamiq.com/&amp;size=32" alt="Balsamiq" class="svelte-zslw0j"></span> </div> <a href="https://balsamiq.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Balsamiq 
Wireframing and collaboration." style="">Balsamiq</h3> <p class="description svelte-zslw0j">Wireframing and collaboration.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://balsamiq.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://creolabs.com/&amp;size=32" alt="Creo" class="svelte-zslw0j"></span> </div> <a href="https://creolabs.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Creo 
Prototyping, code exporting and built-in mobile app builder." style="">Creo</h3> <p class="description svelte-zslw0j">Prototyping, code exporting and built-in mobile app builder.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://creolabs.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://framer.com/&amp;size=32" alt="Framer.js" class="svelte-zslw0j"></span> </div> <a href="https://framer.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Framer.js 
Design tool for creating interactive designs, interfaces and animations." style="">Framer.js</h3> <p class="description svelte-zslw0j">Design tool for creating interactive designs, interfaces and animations.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://framer.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://maze.design/&amp;size=32" alt="Maze" class="svelte-zslw0j"></span> </div> <a href="https://maze.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Maze 
a tool for designers and developers that gives analytical results with actionable KPIs for your Invision prototypes." style="">Maze</h3> <p class="description svelte-zslw0j">a tool for designers and developers that gives analytical results with actionable KPIs for your Invision prototypes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://maze.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://proto.io/&amp;size=32" alt="Proto.io" class="svelte-zslw0j"></span> </div> <a href="https://proto.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Proto.io 
Prototypes that feel real." style="">Proto.io</h3> <p class="description svelte-zslw0j">Prototypes that feel real.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://proto.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.protopie.io/&amp;size=32" alt="ProtoPie" class="svelte-zslw0j"></span> </div> <a href="https://www.protopie.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ProtoPie 
Piece hi-fi interactions together, build sensor-aided prototypes and share your amazing creations in a matter of minutes." style="">ProtoPie</h3> <p class="description svelte-zslw0j">Piece hi-fi interactions together, build sensor-aided prototypes and share your amazing creations in a matter of minutes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.protopie.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.justinmind.com/&amp;size=32" alt="Justinmind" class="svelte-zslw0j"></span> </div> <a href="https://www.justinmind.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Justinmind 
Prototype Faster, Communicate Better." style="">Justinmind</h3> <p class="description svelte-zslw0j">Prototype Faster, Communicate Better.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.justinmind.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://principleformac.com/&amp;size=32" alt="Principle" class="svelte-zslw0j"></span> </div> <a href="https://principleformac.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Principle 
Animate Your Ideas, Design Better Apps." style="">Principle</h3> <p class="description svelte-zslw0j">Animate Your Ideas, Design Better Apps.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://principleformac.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.flinto.com/&amp;size=32" alt="Flinto" class="svelte-zslw0j"></span> </div> <a href="https://www.flinto.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Flinto 
App prototyping tools for designers." style="">Flinto</h3> <p class="description svelte-zslw0j">App prototyping tools for designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.flinto.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.axure.com/&amp;size=32" alt="Axure" class="svelte-zslw0j"></span> </div> <a href="https://www.axure.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Axure 
Design the right solution and align your team." style="">Axure</h3> <p class="description svelte-zslw0j">Design the right solution and align your team.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.axure.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.relativewave.com/form/&amp;size=32" alt="Form" class="svelte-zslw0j"></span> </div> <a href="https://www.relativewave.com/form/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Form 
Build and customize native prototypes directly on device." style="">Form</h3> <p class="description svelte-zslw0j">Build and customize native prototypes directly on device.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.relativewave.com/form/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://bootstrapstudio.io/&amp;size=32" alt="Bootstrap Studio" class="svelte-zslw0j"></span> </div> <a href="https://bootstrapstudio.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Bootstrap Studio 
A powerful desktop app for creating responsive websites using the Bootstrap framework." style="">Bootstrap Studio</h3> <p class="description svelte-zslw0j">A powerful desktop app for creating responsive websites using the Bootstrap framework.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://bootstrapstudio.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.adobe.com/products/experience-design.html&amp;size=32" alt="Adobe XD" class="svelte-zslw0j"></span> </div> <a href="https://www.adobe.com/products/experience-design.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Adobe XD 
Design, prototype and quickly share user experiences." style="">Adobe XD</h3> <p class="description svelte-zslw0j">Design, prototype and quickly share user experiences.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.adobe.com/products/experience-design.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.uxpin.com/&amp;size=32" alt="UXPin" class="svelte-zslw0j"></span> </div> <a href="https://www.uxpin.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UXPin 
High fidelity animated prototypes created in minutes." style="">UXPin</h3> <p class="description svelte-zslw0j">High fidelity animated prototypes created in minutes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.uxpin.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://modao.cc/&amp;size=32" alt="MockingBot" class="svelte-zslw0j"></span> </div> <a href="https://modao.cc/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MockingBot 
Mobile prototyping tool without headache." style="">MockingBot</h3> <p class="description svelte-zslw0j">Mobile prototyping tool without headache.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://modao.cc/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://marvelapp.com/pop/&amp;size=32" alt="POP" class="svelte-zslw0j"></span> </div> <a href="https://marvelapp.com/pop/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="POP 
Transform pen and paper ideas into a real working prototype." style="">POP</h3> <p class="description svelte-zslw0j">Transform pen and paper ideas into a real working prototype.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://marvelapp.com/pop/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://prottapp.com/&amp;size=32" alt="Prott" class="svelte-zslw0j"></span> </div> <a href="https://prottapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Prott 
Prototyping tool for Web, iOS, Android apps." style="">Prott</h3> <p class="description svelte-zslw0j">Prototyping tool for Web, iOS, Android apps.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://prottapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.invisionapp.com/&amp;size=32" alt="InVision" class="svelte-zslw0j"></span> </div> <a href="https://www.invisionapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="InVision 
The world's leading prototyping, collaboration &amp; workflow platform." style="">InVision</h3> <p class="description svelte-zslw0j">The world's leading prototyping, collaboration &amp; workflow platform.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.invisionapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://stage.so/&amp;size=32" alt="Stage" class="svelte-zslw0j"></span> </div> <a href="https://stage.so/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stage 
Stage makes it easy for teams and individuals to design and prototype mobile apps. No design skills required." style="">Stage</h3> <p class="description svelte-zslw0j">Stage makes it easy for teams and individuals to design and prototype mobile apps. No design skills required.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://stage.so/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


wireframe_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://whimsical.co/wireframes/&amp;size=32" alt="Whimsical Wireframes" class="svelte-zslw0j"></span> </div> <a href="https://whimsical.co/wireframes/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Whimsical Wireframes 
Instant wireframing at your fingertips. Rich library of configurable elements like buttons, inputs, checkboxes." style="">Whimsical Wireframes</h3> <p class="description svelte-zslw0j">Instant wireframing at your fingertips. Rich library of configurable elements like buttons, inputs, checkboxes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://whimsical.co/wireframes/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.gliffy.com/&amp;size=32" alt="Gliffy" class="svelte-zslw0j"></span> </div> <a href="https://www.gliffy.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gliffy 
A tool for creating the framework, UML diagrams, flowcharts, wireframes and more." style="">Gliffy</h3> <p class="description svelte-zslw0j">A tool for creating the framework, UML diagrams, flowcharts, wireframes and more.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.gliffy.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://balsamiq.cloud/&amp;size=32" alt="Balsamiq Cloud" class="svelte-zslw0j"></span> </div> <a href="https://balsamiq.cloud/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Balsamiq Cloud 
Effortless UI sketching. Capture your ideas, collaborate on your designs, get everyone on board." style="">Balsamiq Cloud</h3> <p class="description svelte-zslw0j">Effortless UI sketching. Capture your ideas, collaborate on your designs, get everyone on board.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://balsamiq.cloud/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://moqups.com/&amp;size=32" alt="Moqups" class="svelte-zslw0j"></span> </div> <a href="https://moqups.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Moqups 
A streamlined web app that helps you create and collaborate in real-time on wireframes, mockups, diagrams and prototypes." style="">Moqups</h3> <p class="description svelte-zslw0j">A streamlined web app that helps you create and collaborate in real-time on wireframes, mockups, diagrams and prototypes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://moqups.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.mockflow.com/&amp;size=32" alt="Mockflow" class="svelte-zslw0j"></span> </div> <a href="https://www.mockflow.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mockflow 
The quickest way to brainstorm user interface ideas" style="">Mockflow</h3> <p class="description svelte-zslw0j">The quickest way to brainstorm user interface ideas</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.mockflow.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://1200px.com/&amp;size=32" alt="1200px Grid System" class="svelte-zslw0j"></span> </div> <a href="https://1200px.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="1200px Grid System 
Helps you build a grid system for much wider website designs than the 960-pixel style." style="">1200px Grid System</h3> <p class="description svelte-zslw0j">Helps you build a grid system for much wider website designs than the 960-pixel style.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://1200px.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sketchsheets.com/&amp;size=32" alt="Sketchsheets" class="svelte-zslw0j"></span> </div> <a href="https://sketchsheets.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sketchsheets 
Ready to print sketch sheet templates for UX designers." style="">Sketchsheets</h3> <p class="description svelte-zslw0j">Ready to print sketch sheet templates for UX designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sketchsheets.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gridzzly.com/&amp;size=32" alt="Gridzzly" class="svelte-zslw0j"></span> </div> <a href="https://gridzzly.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gridzzly 
The easiest way to create custom grid paper printable." style="">Gridzzly</h3> <p class="description svelte-zslw0j">The easiest way to create custom grid paper printable.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gridzzly.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pidoco.com/en&amp;size=32" alt="Pidoco" class="svelte-zslw0j"></span> </div> <a href="https://pidoco.com/en" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pidoco 
Software that lets you quickly create click-through wireframes and fully interactive UX prototypes." style="">Pidoco</h3> <p class="description svelte-zslw0j">Software that lets you quickly create click-through wireframes and fully interactive UX prototypes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pidoco.com/en" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://wireframe.cc/&amp;size=32" alt="Wireframe.cc" class="svelte-zslw0j"></span> </div> <a href="https://wireframe.cc/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Wireframe.cc 
A simple wireframing tool that doesn't get in your way." style="">Wireframe.cc</h3> <p class="description svelte-zslw0j">A simple wireframing tool that doesn't get in your way.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://wireframe.cc/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://grid.layoutit.com/&amp;size=32" alt="CSS Grid Layout" class="svelte-zslw0j"></span> </div> <a href="https://grid.layoutit.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CSS Grid Layout 
Layoutit! Get the code! Your grid has been saved!" style="">CSS Grid Layout</h3> <p class="description svelte-zslw0j">Layoutit! Get the code! Your grid has been saved!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://grid.layoutit.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


animation_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fable.app&amp;size=32" alt="Fable" class="svelte-zslw0j"></span> </div> <a href="https://fable.app" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fable 
The web-based motion design platform" style="">Fable</h3> <p class="description svelte-zslw0j">The web-based motion design platform</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fable.app" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://spiritapp.io/&amp;size=32" alt="Spirit" class="svelte-zslw0j"></span> </div> <a href="https://spiritapp.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Spirit 
The animation tool that helps you to create and manage the animations real-time in the browser." style="">Spirit</h3> <p class="description svelte-zslw0j">The animation tool that helps you to create and manage the animations real-time in the browser.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://spiritapp.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://rive.app/&amp;size=32" alt="Rive" class="svelte-zslw0j"></span> </div> <a href="https://rive.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Rive 
Create and ship interactive animations to any platform" style="">Rive</h3> <p class="description svelte-zslw0j">Create and ship interactive animations to any platform</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://rive.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://jitter.video/&amp;size=32" alt="Jitter" class="svelte-zslw0j"></span> </div> <a href="https://jitter.video/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Jitter 
Animate your designs easily. Export your creations as videos or GIFs. All in your browser." style="">Jitter</h3> <p class="description svelte-zslw0j">Animate your designs easily. Export your creations as videos or GIFs. All in your browser.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://jitter.video/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://moos.app&amp;size=32" alt="Moos.app" class="svelte-zslw0j"></span> </div> <a href="https://moos.app" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Moos.app 
Create interactive animated product pages without code" style="">Moos.app</h3> <p class="description svelte-zslw0j">Create interactive animated product pages without code</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://moos.app" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://play.google.com/store/apps/details?id=com.ezen.optic&amp;size=32" alt="Optic Editor" class="svelte-zslw0j"></span> </div> <a href="https://play.google.com/store/apps/details?id=com.ezen.optic" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Optic Editor 
Make amazing animation images with effects" style="">Optic Editor</h3> <p class="description svelte-zslw0j">Make amazing animation images with effects</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://play.google.com/store/apps/details?id=com.ezen.optic" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.quickytools.com/character/open/8W4pjNF8DDjz2C1zGXpg?utm_source=product_hunt&amp;size=32" alt="Day6" class="svelte-zslw0j"></span> </div> <a href="https://www.quickytools.com/character/open/8W4pjNF8DDjz2C1zGXpg?utm_source=product_hunt" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Day6 
Generate characters for video games and 3D animations" style="">Day6</h3> <p class="description svelte-zslw0j">Generate characters for video games and 3D animations</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.quickytools.com/character/open/8W4pjNF8DDjz2C1zGXpg?utm_source=product_hunt" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.adobe.com/products/aftereffects.html&amp;size=32" alt="After Effects" class="svelte-zslw0j"></span> </div> <a href="https://www.adobe.com/products/aftereffects.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="After Effects 
Digital visual effects, motion graphics, and compositing application developed by Adobe." style="">After Effects</h3> <p class="description svelte-zslw0j">Digital visual effects, motion graphics, and compositing application developed by Adobe.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.adobe.com/products/aftereffects.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://beatflyer.com/&amp;size=32" alt="BeatFlyer" class="svelte-zslw0j"></span> </div> <a href="https://beatflyer.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="BeatFlyer 
A web tool that lets you create very quickly loopy and catchy animations from your multi-layer compositions." style="">BeatFlyer</h3> <p class="description svelte-zslw0j">A web tool that lets you create very quickly loopy and catchy animations from your multi-layer compositions.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://beatflyer.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://createwithflow.com/&amp;size=32" alt="Flow" class="svelte-zslw0j"></span> </div> <a href="https://createwithflow.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Flow 
A professional animation tool for Sketch designs that also exports production-ready code for iOS, Web or SVG files." style="">Flow</h3> <p class="description svelte-zslw0j">A professional animation tool for Sketch designs that also exports production-ready code for iOS, Web or SVG files.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://createwithflow.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://greensock.com/&amp;size=32" alt="GreenSock" class="svelte-zslw0j"></span> </div> <a href="https://greensock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="GreenSock 
A suite of tools for scripted, high-performance HTML5 animations in all major browsers." style="">GreenSock</h3> <p class="description svelte-zslw0j">A suite of tools for scripted, high-performance HTML5 animations in all major browsers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://greensock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.haikuanimator.com/&amp;size=32" alt="Haiku Animator" class="svelte-zslw0j"></span> </div> <a href="https://www.haikuanimator.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Haiku Animator 
Keyframe-based animation connecting your UI tools to code that developers can easily use." style="">Haiku Animator</h3> <p class="description svelte-zslw0j">Keyframe-based animation connecting your UI tools to code that developers can easily use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.haikuanimator.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.keyshapeapp.com/&amp;size=32" alt="Keyshape" class="svelte-zslw0j"></span> </div> <a href="https://www.keyshapeapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Keyshape 
2D animation tool that allows for animated SVG export." style="">Keyshape</h3> <p class="description svelte-zslw0j">2D animation tool that allows for animated SVG export.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.keyshapeapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://kiteapp.co/&amp;size=32" alt="Kite Compositor" class="svelte-zslw0j"></span> </div> <a href="https://kiteapp.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Kite Compositor 
A powerful animation and prototyping application for Mac &amp; iOS." style="">Kite Compositor</h3> <p class="description svelte-zslw0j">A powerful animation and prototyping application for Mac &amp; iOS.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://kiteapp.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://airbnb.io/lottie/&amp;size=32" alt="Lottie" class="svelte-zslw0j"></span> </div> <a href="https://airbnb.io/lottie/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lottie 
A mobile library for Android and iOS that parses Adobe After Effects animations exported as JSON with Bodymovin and renders them natively on mobile and the web." style="">Lottie</h3> <p class="description svelte-zslw0j">A mobile library for Android and iOS that parses Adobe After Effects animations exported as JSON with Bodymovin and renders them natively on mobile and the web.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://airbnb.io/lottie/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://jeremyckahn.github.io/mantra/&amp;size=32" alt="Mantra" class="svelte-zslw0j"></span> </div> <a href="https://jeremyckahn.github.io/mantra/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Mantra 
A web-based timeline animation tool." style="">Mantra</h3> <p class="description svelte-zslw0j">A web-based timeline animation tool.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://jeremyckahn.github.io/mantra/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://app.naker.io/back/&amp;size=32" alt="Naker.Back" class="svelte-zslw0j"></span> </div> <a href="https://app.naker.io/back/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Naker.Back 
İntegrate an interactive background for free to draw more attention to your website." style="">Naker.Back</h3> <p class="description svelte-zslw0j">İntegrate an interactive background for free to draw more attention to your website.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://app.naker.io/back/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://offeo.com/&amp;size=32" alt="OFFEO" class="svelte-zslw0j"></span> </div> <a href="https://offeo.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="OFFEO 
An online video maker for small businesses to create video ads like the Big Brands without the big budget." style="">OFFEO</h3> <p class="description svelte-zslw0j">An online video maker for small businesses to create video ads like the Big Brands without the big budget.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://offeo.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://jeremyckahn.github.io/stylie/&amp;size=32" alt="Stylie" class="svelte-zslw0j"></span> </div> <a href="https://jeremyckahn.github.io/stylie/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Stylie 
A web-based graphical CSS3 animation tool." style="">Stylie</h3> <p class="description svelte-zslw0j">A web-based graphical CSS3 animation tool.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://jeremyckahn.github.io/stylie/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tumult.com/hype/&amp;size=32" alt="Tumult Hype" class="svelte-zslw0j"></span> </div> <a href="https://tumult.com/hype/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Tumult Hype 
The HTML5 animation/interactives creation app for macOS." style="">Tumult Hype</h3> <p class="description svelte-zslw0j">The HTML5 animation/interactives creation app for macOS.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tumult.com/hype/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


social_media_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://songrender.com/&amp;size=32" alt="Song Render" class="svelte-zslw0j"></span> </div> <a href="https://songrender.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Song Render 
SongRender is an online video maker designed to get your music noticed on social media. You know your song's a hit — now you just need people to pay attention." style="">Song Render</h3> <p class="description svelte-zslw0j">SongRender is an online video maker designed to get your music noticed on social media. You know your song's a hit — now you just need people to pay attention.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://songrender.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://buffer.academy/&amp;size=32" alt="Social Media Academy" class="svelte-zslw0j"></span> </div> <a href="https://buffer.academy/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Social Media Academy 
Up your social media marketing game, one article at a time. Articles and examples from today's social media marketers." style="">Social Media Academy</h3> <p class="description svelte-zslw0j">Up your social media marketing game, one article at a time. Articles and examples from today's social media marketers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://buffer.academy/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://crello.com/&amp;size=32" alt="Crello" class="svelte-zslw0j"></span> </div> <a href="https://crello.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Crello 
The simplest online image editor. Create your own designs — posts, covers, graphics, and posters using the best software on the web." style="">Crello</h3> <p class="description svelte-zslw0j">The simplest online image editor. Create your own designs — posts, covers, graphics, and posters using the best software on the web.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://crello.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sproutsocial.com/landscape&amp;size=32" alt="Landscape" class="svelte-zslw0j"></span> </div> <a href="https://sproutsocial.com/landscape" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Landscape 
Streamlined Image Resizing for Social Media." style="">Landscape</h3> <p class="description svelte-zslw0j">Streamlined Image Resizing for Social Media.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sproutsocial.com/landscape" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://cards-dev.twitter.com/validator&amp;size=32" alt="Twitter Card Validator" class="svelte-zslw0j"></span> </div> <a href="https://cards-dev.twitter.com/validator" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Twitter Card Validator 
Preview your twitter card before sharing." style="">Twitter Card Validator</h3> <p class="description svelte-zslw0j">Preview your twitter card before sharing.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://cards-dev.twitter.com/validator" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pablo.buffer.com/&amp;size=32" alt="Pablo" class="svelte-zslw0j"></span> </div> <a href="https://pablo.buffer.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pablo 
Create beautiful images easily to make your posts pop." style="">Pablo</h3> <p class="description svelte-zslw0j">Create beautiful images easily to make your posts pop.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pablo.buffer.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://carrd.co/&amp;size=32" alt="Carrd" class="svelte-zslw0j"></span> </div> <a href="https://carrd.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Carrd 
Simple, free, fully responsive one-page sites for pretty much anything." style="">Carrd</h3> <p class="description svelte-zslw0j">Simple, free, fully responsive one-page sites for pretty much anything.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://carrd.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://superblog.ai/supershots/&amp;size=32" alt="Supershots" class="svelte-zslw0j"></span> </div> <a href="https://superblog.ai/supershots/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Supershots 
Turn screenshots into supershots with gradient backgrounds" style="">Supershots</h3> <p class="description svelte-zslw0j">Turn screenshots into supershots with gradient backgrounds</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://superblog.ai/supershots/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.brandbird.app/&amp;size=32" alt="BrandBird Studio" class="svelte-zslw0j"></span> </div> <a href="https://www.brandbird.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="BrandBird Studio 
Turn boring screenshot into beautiful sharable images for your socia media, blog, newsletter, and even your landing page." style="">BrandBird Studio</h3> <p class="description svelte-zslw0j">Turn boring screenshot into beautiful sharable images for your socia media, blog, newsletter, and even your landing page.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.brandbird.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://chrome.google.com/webstore/detail/youtube-notetaker-terrain/ggmegoikhdmjmbeopoplpingfmogafik&amp;size=32" alt="Youtube Notetaker" class="svelte-zslw0j"></span> </div> <a href="https://chrome.google.com/webstore/detail/youtube-notetaker-terrain/ggmegoikhdmjmbeopoplpingfmogafik" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Youtube Notetaker 
Death to the YouTube rabbit hole" style="">Youtube Notetaker</h3> <p class="description svelte-zslw0j">Death to the YouTube rabbit hole</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://chrome.google.com/webstore/detail/youtube-notetaker-terrain/ggmegoikhdmjmbeopoplpingfmogafik" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sociomata.com&amp;size=32" alt="Sociomata" class="svelte-zslw0j"></span> </div> <a href="https://sociomata.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sociomata 
Autopilot for your social media" style="">Sociomata</h3> <p class="description svelte-zslw0j">Autopilot for your social media</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sociomata.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://wang.sh/minimal-twitter&amp;size=32" alt="Minimal Theme for Twitter" class="svelte-zslw0j"></span> </div> <a href="https://wang.sh/minimal-twitter" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Minimal Theme for Twitter 
Declutter your Twitter web experience" style="">Minimal Theme for Twitter</h3> <p class="description svelte-zslw0j">Declutter your Twitter web experience</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://wang.sh/minimal-twitter" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.relink.page/&amp;size=32" alt="relink.page" class="svelte-zslw0j"></span> </div> <a href="https://www.relink.page/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="relink.page 
Customize the way your links appear on Twitter" style="">relink.page</h3> <p class="description svelte-zslw0j">Customize the way your links appear on Twitter</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.relink.page/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://graaphics.co/&amp;size=32" alt="Graaphics" class="svelte-zslw0j"></span> </div> <a href="https://graaphics.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Graaphics 
Easy, effective graphics for your social media." style="">Graaphics</h3> <p class="description svelte-zslw0j">Easy, effective graphics for your social media.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://graaphics.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


sound_and_audio_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://soundkit.io/&amp;size=32" alt="Soundkit" class="svelte-zslw0j"></span> </div> <a href="https://soundkit.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Soundkit 
Because your UI should sound as good as it looks." style="">Soundkit</h3> <p class="description svelte-zslw0j">Because your UI should sound as good as it looks.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://soundkit.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.bensound.com/&amp;size=32" alt="Ben Sound" class="svelte-zslw0j"></span> </div> <a href="https://www.bensound.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Ben Sound 
Download creative commons music, royalty free music for free and use it in your project." style="">Ben Sound</h3> <p class="description svelte-zslw0j">Download creative commons music, royalty free music for free and use it in your project.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.bensound.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://wistia.com/resources/music&amp;size=32" alt="Wistia" class="svelte-zslw0j"></span> </div> <a href="https://wistia.com/resources/music" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Wistia 
Free tracks to create emotion around your video’s message." style="">Wistia</h3> <p class="description svelte-zslw0j">Free tracks to create emotion around your video’s message.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://wistia.com/resources/music" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.wowa.me/&amp;size=32" alt="Wowa" class="svelte-zslw0j"></span> </div> <a href="https://www.wowa.me/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Wowa 
Free (do whatever you want) music." style="">Wowa</h3> <p class="description svelte-zslw0j">Free (do whatever you want) music.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.wowa.me/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://audiojungle.net/&amp;size=32" alt="Audio Jungle" class="svelte-zslw0j"></span> </div> <a href="https://audiojungle.net/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Audio Jungle 
Royalty free music and audio tracks from $1." style="">Audio Jungle</h3> <p class="description svelte-zslw0j">Royalty free music and audio tracks from $1.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://audiojungle.net/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.youtube.com/audiolibrary/music&amp;size=32" alt="Youtube Free" class="svelte-zslw0j"></span> </div> <a href="https://www.youtube.com/audiolibrary/music" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Youtube Free 
Youtube's free music library." style="">Youtube Free</h3> <p class="description svelte-zslw0j">Youtube's free music library.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.youtube.com/audiolibrary/music" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icons8.com/music&amp;size=32" alt="Icon8" class="svelte-zslw0j"></span> </div> <a href="https://icons8.com/music" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Icon8 
Much, much more picky than other marketplaces. Much, much cheaper than Hans Zimmer." style="">Icon8</h3> <p class="description svelte-zslw0j">Much, much more picky than other marketplaces. Much, much cheaper than Hans Zimmer.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icons8.com/music" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uisounds.prototypr.io/&amp;size=32" alt="UI Sounds" class="svelte-zslw0j"></span> </div> <a href="https://uisounds.prototypr.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI Sounds 
Sound design by example." style="">UI Sounds</h3> <p class="description svelte-zslw0j">Sound design by example.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uisounds.prototypr.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


user_flow_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.lucidchart.com/&amp;size=32" alt="Lucidchart" class="svelte-zslw0j"></span> </div> <a href="https://www.lucidchart.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lucidchart 
Online tool for creating diagrams, flow charts, sitemaps, and more." style="">Lucidchart</h3> <p class="description svelte-zslw0j">Online tool for creating diagrams, flow charts, sitemaps, and more.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.lucidchart.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mindnode.com/&amp;size=32" alt="MindNode" class="svelte-zslw0j"></span> </div> <a href="https://mindnode.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MindNode 
A mind mapping app that makes brainstorming simple and easy." style="">MindNode</h3> <p class="description svelte-zslw0j">A mind mapping app that makes brainstorming simple and easy.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mindnode.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sketch.systems/&amp;size=32" alt="Sketch.systems" class="svelte-zslw0j"></span> </div> <a href="https://sketch.systems/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sketch.systems 
Ui and flow design with interactive state machines." style="">Sketch.systems</h3> <p class="description svelte-zslw0j">Ui and flow design with interactive state machines.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sketch.systems/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://whimsical.co/&amp;size=32" alt="Whimsical" class="svelte-zslw0j"></span> </div> <a href="https://whimsical.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Whimsical 
Easy to create flow charts, wireframes and sticky notes." style="">Whimsical</h3> <p class="description svelte-zslw0j">Easy to create flow charts, wireframes and sticky notes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://whimsical.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://wireflow.co&amp;size=32" alt="Wireflow" class="svelte-zslw0j"></span> </div> <a href="https://wireflow.co" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Wireflow 
Free, online and open source tool for creating beautiful user flow prototypes." style="">Wireflow</h3> <p class="description svelte-zslw0j">Free, online and open source tool for creating beautiful user flow prototypes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://wireflow.co" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.xmind.net/zen/&amp;size=32" alt="Zen" class="svelte-zslw0j"></span> </div> <a href="https://www.xmind.net/zen/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Zen 
A brainstorming and mind mapping tool that can switch between outline and tree-chart. Link topics with other charts." style="">Zen</h3> <p class="description svelte-zslw0j">A brainstorming and mind mapping tool that can switch between outline and tree-chart. Link topics with other charts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.xmind.net/zen/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://maze.design/&amp;size=32" alt="Maze" class="svelte-zslw0j"></span> </div> <a href="https://maze.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Maze 
Turns your prototype into actionable insights from real users, bringing confidence to the design process." style="">Maze</h3> <p class="description svelte-zslw0j">Turns your prototype into actionable insights from real users, bringing confidence to the design process.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://maze.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.draw.io/&amp;size=32" alt="Draw.io" class="svelte-zslw0j"></span> </div> <a href="https://www.draw.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Draw.io 
A free online diagram software for making flowcharts, process diagrams, org charts, UML, ER and network diagrams." style="">Draw.io</h3> <p class="description svelte-zslw0j">A free online diagram software for making flowcharts, process diagrams, org charts, UML, ER and network diagrams.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.draw.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ninjamock.com/&amp;size=32" alt="NinjaMock" class="svelte-zslw0j"></span> </div> <a href="https://ninjamock.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="NinjaMock 
Wireframe and user flow online tool. Link your views and create logic flow prototype. All with freehand visual style." style="">NinjaMock</h3> <p class="description svelte-zslw0j">Wireframe and user flow online tool. Link your views and create logic flow prototype. All with freehand visual style.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ninjamock.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uxmisfit.com/squid/&amp;size=32" alt="Squid" class="svelte-zslw0j"></span> </div> <a href="https://uxmisfit.com/squid/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Squid 
Create beautiful User Flows in Sketch in just minutes." style="">Squid</h3> <p class="description svelte-zslw0j">Create beautiful User Flows in Sketch in just minutes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uxmisfit.com/squid/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.yworks.com/products/yed&amp;size=32" alt="yEd" class="svelte-zslw0j"></span> </div> <a href="https://www.yworks.com/products/yed" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="yEd 
Free desktop tool for making diagrams. Usable for wide variety of use cases. Auto-layout helps a lot when making flowcharts." style="">yEd</h3> <p class="description svelte-zslw0j">Free desktop tool for making diagrams. Usable for wide variety of use cases. Auto-layout helps a lot when making flowcharts.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.yworks.com/products/yed" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.omnigroup.com/omnigraffle/&amp;size=32" alt="OmniGraffle" class="svelte-zslw0j"></span> </div> <a href="https://www.omnigroup.com/omnigraffle/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="OmniGraffle 
A diagramming and digital illustration application for macOS and iOS." style="">OmniGraffle</h3> <p class="description svelte-zslw0j">A diagramming and digital illustration application for macOS and iOS.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.omnigroup.com/omnigraffle/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://flowmapp.com/&amp;size=32" alt="Flowmapp" class="svelte-zslw0j"></span> </div> <a href="https://flowmapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Flowmapp 
an online tool for creating sitemaps and user flows that helps you to effectively design and plan user experience." style="">Flowmapp</h3> <p class="description svelte-zslw0j">an online tool for creating sitemaps and user flows that helps you to effectively design and plan user experience.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://flowmapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://overflow.io/&amp;size=32" alt="Overflow" class="svelte-zslw0j"></span> </div> <a href="https://overflow.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Overflow 
Turn your designs into playable user flow diagrams that tell a story." style="">Overflow</h3> <p class="description svelte-zslw0j">Turn your designs into playable user flow diagrams that tell a story.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://overflow.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://docs.google.com/drawings/&amp;size=32" alt="Google Drawings" class="svelte-zslw0j"></span> </div> <a href="https://docs.google.com/drawings/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Google Drawings 
Create diagrams and charts, for free; all within Google Docs." style="">Google Drawings</h3> <p class="description svelte-zslw0j">Create diagrams and charts, for free; all within Google Docs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://docs.google.com/drawings/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


design_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.gimp.org/&amp;size=32" alt="Gimp" class="svelte-zslw0j"></span> </div> <a href="https://www.gimp.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gimp 
A free &amp; open source imaging and graphic design software." style="">Gimp</h3> <p class="description svelte-zslw0j">A free &amp; open source imaging and graphic design software.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.gimp.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.adobe.com/products/xd.html&amp;size=32" alt="Adobe XD" class="svelte-zslw0j"></span> </div> <a href="https://www.adobe.com/products/xd.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Adobe XD 
Design, prototype, and share any user experience, from websites and mobile apps to voice interactions." style="">Adobe XD</h3> <p class="description svelte-zslw0j">Design, prototype, and share any user experience, from websites and mobile apps to voice interactions.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.adobe.com/products/xd.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.figma.com/&amp;size=32" alt="Figma" class="svelte-zslw0j"></span> </div> <a href="https://www.figma.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Figma 
A design tool based in the browser, that allows to design and prototype with real-time collaboration." style="">Figma</h3> <p class="description svelte-zslw0j">A design tool based in the browser, that allows to design and prototype with real-time collaboration.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.figma.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://plantapp.io/&amp;size=32" alt="Plant App" class="svelte-zslw0j"></span> </div> <a href="https://plantapp.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Plant App 
Version Control for Designers." style="">Plant App</h3> <p class="description svelte-zslw0j">Version Control for Designers.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://plantapp.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://krita.org/en/&amp;size=32" alt="Krita" class="svelte-zslw0j"></span> </div> <a href="https://krita.org/en/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Krita 
Free painting and graphic design software considered a good alternative to Adobe Photoshop." style="">Krita</h3> <p class="description svelte-zslw0j">Free painting and graphic design software considered a good alternative to Adobe Photoshop.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://krita.org/en/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.sketchapp.com/&amp;size=32" alt="Sketch" class="svelte-zslw0j"></span> </div> <a href="https://www.sketchapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sketch 
Design toolkit built for Mac. " style="">Sketch</h3> <p class="description svelte-zslw0j">Design toolkit built for Mac. </p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.sketchapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://vectr.com/&amp;size=32" alt="Vectr" class="svelte-zslw0j"></span> </div> <a href="https://vectr.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Vectr 
Simple web and desktop cross-platform tool to create vector graphics easily and intuitively." style="">Vectr</h3> <p class="description svelte-zslw0j">Simple web and desktop cross-platform tool to create vector graphics easily and intuitively.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://vectr.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://affinity.serif.com/en-gb/designer/&amp;size=32" alt="Affinity Designer" class="svelte-zslw0j"></span> </div> <a href="https://affinity.serif.com/en-gb/designer/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Affinity Designer 
A vector graphics editor for macOS, iOS, and Microsoft Windows." style="">Affinity Designer</h3> <p class="description svelte-zslw0j">A vector graphics editor for macOS, iOS, and Microsoft Windows.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://affinity.serif.com/en-gb/designer/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.abstract.com/&amp;size=32" alt="Abstract" class="svelte-zslw0j"></span> </div> <a href="https://www.abstract.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Abstract 
One place to version, manage, and collaborate on your Sketch files." style="">Abstract</h3> <p class="description svelte-zslw0j">One place to version, manage, and collaborate on your Sketch files.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.abstract.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://inkscape.org/&amp;size=32" alt="Inkscape" class="svelte-zslw0j"></span> </div> <a href="https://inkscape.org/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Inkscape 
A free and open-source vector graphics editor. It has ability to create or edit vector graphics such as illustrations, diagrams, line arts, charts, logos and complex paintings." style="">Inkscape</h3> <p class="description svelte-zslw0j">A free and open-source vector graphics editor. It has ability to create or edit vector graphics such as illustrations, diagrams, line arts, charts, logos and complex paintings.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://inkscape.org/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.cleverbrush.com/&amp;size=32" alt="CleverBrush" class="svelte-zslw0j"></span> </div> <a href="https://www.cleverbrush.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CleverBrush 
a browser-based online vector editor and digital publishing tool which is possible to integrate to page as JS component." style="">CleverBrush</h3> <p class="description svelte-zslw0j">a browser-based online vector editor and digital publishing tool which is possible to integrate to page as JS component.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.cleverbrush.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://phase.com/&amp;size=32" alt="Phase" class="svelte-zslw0j"></span> </div> <a href="https://phase.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Phase 
Design and prototype websites and apps intuitively, in a new product reworked for the digital age." style="">Phase</h3> <p class="description svelte-zslw0j">Design and prototype websites and apps intuitively, in a new product reworked for the digital age.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://phase.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://studio.design/&amp;size=32" alt="Studio Design" class="svelte-zslw0j"></span> </div> <a href="https://studio.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Studio Design 
All the versatile tools to have a fully functional website running, in one simple interface." style="">Studio Design</h3> <p class="description svelte-zslw0j">All the versatile tools to have a fully functional website running, in one simple interface.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://studio.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://crello.com/&amp;size=32" alt="Crello" class="svelte-zslw0j"></span> </div> <a href="https://crello.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Crello 
The simplest online image editor. Create your own designs — posts, covers, graphics, and posters using the best software on the web." style="">Crello</h3> <p class="description svelte-zslw0j">The simplest online image editor. Create your own designs — posts, covers, graphics, and posters using the best software on the web.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://crello.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://icons8.com/lunacy&amp;size=32" alt="Lunacy" class="svelte-zslw0j"></span> </div> <a href="https://icons8.com/lunacy" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Lunacy 
Free native windows app that works offline and supports .sketch files. Flexible and light weighed. Intuitive and easy to use. Speedups and empowers UI and UX designers. The must have to produce stunning designs." style="">Lunacy</h3> <p class="description svelte-zslw0j">Free native windows app that works offline and supports .sketch files. Flexible and light weighed. Intuitive and easy to use. Speedups and empowers UI and UX designers. The must have to produce stunning designs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://icons8.com/lunacy" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://designer.io/&amp;size=32" alt="Gravit" class="svelte-zslw0j"></span> </div> <a href="https://designer.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gravit 
Free vector design app, available for macOS, Windows, Linux, ChromeOS and browser." style="">Gravit</h3> <p class="description svelte-zslw0j">Free vector design app, available for macOS, Windows, Linux, ChromeOS and browser.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://designer.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.invisionapp.com/studio&amp;size=32" alt="InVision Studio" class="svelte-zslw0j"></span> </div> <a href="https://www.invisionapp.com/studio" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="InVision Studio 
Combines design, prototyping, and collaboration into one harmonious workflow. Made by Invision." style="">InVision Studio</h3> <p class="description svelte-zslw0j">Combines design, prototyping, and collaboration into one harmonious workflow. Made by Invision.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.invisionapp.com/studio" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://studio.pixelixe.com&amp;size=32" alt="Pixelixe" class="svelte-zslw0j"></span> </div> <a href="https://studio.pixelixe.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pixelixe 
Graphic design tool built for marketers, bloggers and small businesses that needs to create stunning and unique images, graphics or static webpages in minutes." style="">Pixelixe</h3> <p class="description svelte-zslw0j">Graphic design tool built for marketers, bloggers and small businesses that needs to create stunning and unique images, graphics or static webpages in minutes.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://studio.pixelixe.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.adobe.com/products/photoshop.html&amp;size=32" alt="Photoshop" class="svelte-zslw0j"></span> </div> <a href="https://www.adobe.com/products/photoshop.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Photoshop 
Imaging and graphic design software developed by Adobe." style="">Photoshop</h3> <p class="description svelte-zslw0j">Imaging and graphic design software developed by Adobe.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.adobe.com/products/photoshop.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.photopea.com/&amp;size=32" alt="Photopea" class="svelte-zslw0j"></span> </div> <a href="https://www.photopea.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Photopea 
Free browser-based graphic design app alternative to Photoshop." style="">Photopea</h3> <p class="description svelte-zslw0j">Free browser-based graphic design app alternative to Photoshop.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.photopea.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.vectary.com/&amp;size=32" alt="Vectary" class="svelte-zslw0j"></span> </div> <a href="https://www.vectary.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Vectary 
Create beautiful 3D models with our drag and drop 3D modeling tool. Collaborate with your friends and colleagues online." style="">Vectary</h3> <p class="description svelte-zslw0j">Create beautiful 3D models with our drag and drop 3D modeling tool. Collaborate with your friends and colleagues online.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.vectary.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.pixelmator.com/pro/&amp;size=32" alt="Pixelmator Pro" class="svelte-zslw0j"></span> </div> <a href="https://www.pixelmator.com/pro/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Pixelmator Pro 
Professional image editing tools that anyone can use." style="">Pixelmator Pro</h3> <p class="description svelte-zslw0j">Professional image editing tools that anyone can use.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.pixelmator.com/pro/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://blocsapp.com/&amp;size=32" alt="Blocs for Mac" class="svelte-zslw0j"></span> </div> <a href="https://blocsapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Blocs for Mac 
Fast, easy to use and powerful visual web design tool, that lets you create responsive websites without writing code." style="">Blocs for Mac</h3> <p class="description svelte-zslw0j">Fast, easy to use and powerful visual web design tool, that lets you create responsive websites without writing code.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://blocsapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.remove.bg/&amp;size=32" alt="Remove BG" class="svelte-zslw0j"></span> </div> <a href="https://www.remove.bg/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Remove BG 
Remove image background with a simple click." style="">Remove BG</h3> <p class="description svelte-zslw0j">Remove image background with a simple click.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.remove.bg/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.canva.com/&amp;size=32" alt="Canva" class="svelte-zslw0j"></span> </div> <a href="https://www.canva.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Canva 
Create beautiful designs with your team." style="">Canva</h3> <p class="description svelte-zslw0j">Create beautiful designs with your team.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.canva.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://glyphsapp.com/&amp;size=32" alt="Glyphs App" class="svelte-zslw0j"></span> </div> <a href="https://glyphsapp.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Glyphs App 
Font editing for everyone. Create Stunning fonts on your Mac." style="">Glyphs App</h3> <p class="description svelte-zslw0j">Font editing for everyone. Create Stunning fonts on your Mac.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://glyphsapp.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.adobe.com/products/illustrator.html&amp;size=32" alt="Illustrator" class="svelte-zslw0j"></span> </div> <a href="https://www.adobe.com/products/illustrator.html" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Illustrator 
Create logos, icons, drawings, typography, and illustrations for print, web, video, and mobile. Made by Adobe." style="">Illustrator</h3> <p class="description svelte-zslw0j">Create logos, icons, drawings, typography, and illustrations for print, web, video, and mobile. Made by Adobe.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.adobe.com/products/illustrator.html" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.botmock.com&amp;size=32" alt="Botmock" class="svelte-zslw0j"></span> </div> <a href="https://www.botmock.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Botmock 
Design, prototype, and test voice and text conversational apps. Supports multiple platforms." style="">Botmock</h3> <p class="description svelte-zslw0j">Design, prototype, and test voice and text conversational apps. Supports multiple platforms.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.botmock.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gra.dient.art/&amp;size=32" alt="GradientArt" class="svelte-zslw0j"></span> </div> <a href="https://gra.dient.art/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="GradientArt 
Advanced CSS gradient editor" style="">GradientArt</h3> <p class="description svelte-zslw0j">Advanced CSS gradient editor</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gra.dient.art/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.antetype.com/&amp;size=32" alt="Antetype" class="svelte-zslw0j"></span> </div> <a href="https://www.antetype.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Antetype 
Complex UX prototypes solved- responsive, interactive &amp; free" style="">Antetype</h3> <p class="description svelte-zslw0j">Complex UX prototypes solved- responsive, interactive &amp; free</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.antetype.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://bannery.app/&amp;size=32" alt="Bannery" class="svelte-zslw0j"></span> </div> <a href="https://bannery.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Bannery 
Stop using boring 2D graphics, create 3D banners by yourself" style="">Bannery</h3> <p class="description svelte-zslw0j">Stop using boring 2D graphics, create 3D banners by yourself</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://bannery.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockflow.com/&amp;size=32" alt="MockFlow 3.0" class="svelte-zslw0j"></span> </div> <a href="https://mockflow.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MockFlow 3.0 
End to end solution for product design" style="">MockFlow 3.0</h3> <p class="description svelte-zslw0j">End to end solution for product design</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockflow.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://simplified.co/&amp;size=32" alt="Simplified Design" class="svelte-zslw0j"></span> </div> <a href="https://simplified.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Simplified Design 
One app to create, collaborate, and scale your marketing" style="">Simplified Design</h3> <p class="description svelte-zslw0j">One app to create, collaborate, and scale your marketing</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://simplified.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.iterationx.com/&amp;size=32" alt="Iteration X" class="svelte-zslw0j"></span> </div> <a href="https://www.iterationx.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Iteration X 
Iterate and collaborate directly on your live product" style="">Iteration X</h3> <p class="description svelte-zslw0j">Iterate and collaborate directly on your live product</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.iterationx.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://studios.lol/&amp;size=32" alt="Studios.lol" class="svelte-zslw0j"></span> </div> <a href="https://studios.lol/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Studios.lol 
Discover product, design, and other creative agencies" style="">Studios.lol</h3> <p class="description svelte-zslw0j">Discover product, design, and other creative agencies</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://studios.lol/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://dialo.app/&amp;size=32" alt="Dialo" class="svelte-zslw0j"></span> </div> <a href="https://dialo.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Dialo 
Design your digital business card" style="">Dialo</h3> <p class="description svelte-zslw0j">Design your digital business card</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://dialo.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


generators_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://brenna.github.io/csshexagon/&amp;size=32" alt="CSS Hexagon Generator" class="svelte-zslw0j"></span> </div> <a href="https://brenna.github.io/csshexagon/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="CSS Hexagon Generator 
Generate your own pure CSS hexagons with box-shadow, border, and background image." style="">CSS Hexagon Generator</h3> <p class="description svelte-zslw0j">Generate your own pure CSS hexagons with box-shadow, border, and background image.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://brenna.github.io/csshexagon/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fastcharts.io/&amp;size=32" alt="Fast Charts" class="svelte-zslw0j"></span> </div> <a href="https://fastcharts.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Fast Charts 
Generate charts from CSV." style="">Fast Charts</h3> <p class="description svelte-zslw0j">Generate charts from CSV.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fastcharts.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://getavataaars.com/&amp;size=32" alt="Avataaars Generator" class="svelte-zslw0j"></span> </div> <a href="https://getavataaars.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Avataaars Generator 
Free online avatar generator for anyone to make their beautiful personal avatar easily!" style="">Avataaars Generator</h3> <p class="description svelte-zslw0j">Free online avatar generator for anyone to make their beautiful personal avatar easily!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://getavataaars.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://generative.fm/&amp;size=32" alt="Generative.fm" class="svelte-zslw0j"></span> </div> <a href="https://generative.fm/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Generative.fm 
Endlessly unique ambient music." style="">Generative.fm</h3> <p class="description svelte-zslw0j">Endlessly unique ambient music.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://generative.fm/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://makeitstranger.com/&amp;size=32" alt="Make It Stranger" class="svelte-zslw0j"></span> </div> <a href="https://makeitstranger.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Make It Stranger 
Stranger Things generator." style="">Make It Stranger</h3> <p class="description svelte-zslw0j">Stranger Things generator.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://makeitstranger.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://fffuel.co/dddynamite/&amp;size=32" alt="dddynamite" class="svelte-zslw0j"></span> </div> <a href="https://fffuel.co/dddynamite/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="dddynamite 
Customizable decorative SVG shapes" style="">dddynamite</h3> <p class="description svelte-zslw0j">Customizable decorative SVG shapes</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://fffuel.co/dddynamite/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


notion_tools_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://easlo.gumroad.com/l/nrpack&amp;size=32" alt="Notion Resource Pack" class="svelte-zslw0j"></span> </div> <a href="https://easlo.gumroad.com/l/nrpack" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Resource Pack 
Explore 100+ resources for Notion" style="">Notion Resource Pack</h3> <p class="description svelte-zslw0j">Explore 100+ resources for Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://easlo.gumroad.com/l/nrpack" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.prototion.com/&amp;size=32" alt="Prototion" class="svelte-zslw0j"></span> </div> <a href="https://www.prototion.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Prototion 
Notion’s Best Handcrafted Templates" style="">Prototion</h3> <p class="description svelte-zslw0j">Notion’s Best Handcrafted Templates</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.prototion.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.simple.ink/&amp;size=32" alt="Simple.ink" class="svelte-zslw0j"></span> </div> <a href="https://www.simple.ink/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Simple.ink 
Build websites with Notion in ~10 sec" style="">Simple.ink</h3> <p class="description svelte-zslw0j">Build websites with Notion in ~10 sec</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.simple.ink/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.notionfreelance.com/&amp;size=32" alt="Notion Freelancer OS" class="svelte-zslw0j"></span> </div> <a href="https://www.notionfreelance.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Freelancer OS 
Manage and grow your freelance business in Notion." style="">Notion Freelancer OS</h3> <p class="description svelte-zslw0j">Manage and grow your freelance business in Notion.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.notionfreelance.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://notionforms.io/&amp;size=32" alt="NotionForms" class="svelte-zslw0j"></span> </div> <a href="https://notionforms.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="NotionForms 
Simple and beautiful form builder for Notion" style="">NotionForms</h3> <p class="description svelte-zslw0j">Simple and beautiful form builder for Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://notionforms.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.taskforce10.io/freebies/notion-task-prioritizer-eisenhower-matrix&amp;size=32" alt="Notion Daily Task Prioritizer" class="svelte-zslw0j"></span> </div> <a href="https://www.taskforce10.io/freebies/notion-task-prioritizer-eisenhower-matrix" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Daily Task Prioritizer 
Prioritize your important tasks using the Eisenhower matrix" style="">Notion Daily Task Prioritizer</h3> <p class="description svelte-zslw0j">Prioritize your important tasks using the Eisenhower matrix</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.taskforce10.io/freebies/notion-task-prioritizer-eisenhower-matrix" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uxnotion.com/&amp;size=32" alt="UX Notion" class="svelte-zslw0j"></span> </div> <a href="https://uxnotion.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UX Notion 
Toolkit to learn UX design on a weekend" style="">UX Notion</h3> <p class="description svelte-zslw0j">Toolkit to learn UX design on a weekend</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uxnotion.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://top30.app/&amp;size=32" alt="Top 30 Breakout Apps for 2022" class="svelte-zslw0j"></span> </div> <a href="https://top30.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Top 30 Breakout Apps for 2022 
Discover the next Notion, Figma &amp; Calendly before the world" style="">Top 30 Breakout Apps for 2022</h3> <p class="description svelte-zslw0j">Discover the next Notion, Figma &amp; Calendly before the world</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://top30.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://ireem.gumroad.com/l/NotionUSM&amp;size=32" alt="Notion Ultimate Subscription System" class="svelte-zslw0j"></span> </div> <a href="https://ireem.gumroad.com/l/NotionUSM" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Ultimate Subscription System 
You will never pay for a subscription you don't need again" style="">Notion Ultimate Subscription System</h3> <p class="description svelte-zslw0j">You will never pay for a subscription you don't need again</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://ireem.gumroad.com/l/NotionUSM" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.threado.com/communityos&amp;size=32" alt="Community OS" class="svelte-zslw0j"></span> </div> <a href="https://www.threado.com/communityos" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Community OS 
800+ community resources and Notion workbook for free" style="">Community OS</h3> <p class="description svelte-zslw0j">800+ community resources and Notion workbook for free</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.threado.com/communityos" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://yusuf.is/designers-collection&amp;size=32" alt="Notion Website Themes &amp; Templates" class="svelte-zslw0j"></span> </div> <a href="https://yusuf.is/designers-collection" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Website Themes &amp; Templates 
A collection of themes for Notion sites powered by Super." style="">Notion Website Themes &amp; Templates</h3> <p class="description svelte-zslw0j">A collection of themes for Notion sites powered by Super.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://yusuf.is/designers-collection" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://pixeltie.gumroad.com/l/ePGkX&amp;size=32" alt="Project Plan Notion Template" class="svelte-zslw0j"></span> </div> <a href="https://pixeltie.gumroad.com/l/ePGkX" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Project Plan Notion Template 
Notion template that helps you build effective project plans" style="">Project Plan Notion Template</h3> <p class="description svelte-zslw0j">Notion template that helps you build effective project plans</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://pixeltie.gumroad.com/l/ePGkX" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://notionavatars.com/&amp;size=32" alt="Notion Avatars" class="svelte-zslw0j"></span> </div> <a href="https://notionavatars.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Avatars 
Your avatar, for Notion" style="">Notion Avatars</h3> <p class="description svelte-zslw0j">Your avatar, for Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://notionavatars.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://maze.co/blog/maze-question-bank/&amp;size=32" alt="Maze Question Bank" class="svelte-zslw0j"></span> </div> <a href="https://maze.co/blog/maze-question-bank/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Maze Question Bank 
A Notion database of 350+ questions for rapid UX research" style="">Maze Question Bank</h3> <p class="description svelte-zslw0j">A Notion database of 350+ questions for rapid UX research</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://maze.co/blog/maze-question-bank/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://heyslideit.com/&amp;size=32" alt="Slideit" class="svelte-zslw0j"></span> </div> <a href="https://heyslideit.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Slideit 
Save Tweets to Notion automatically" style="">Slideit</h3> <p class="description svelte-zslw0j">Save Tweets to Notion automatically</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://heyslideit.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sidedrive.app/&amp;size=32" alt="Sidedrive" class="svelte-zslw0j"></span> </div> <a href="https://sidedrive.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sidedrive 
Google Drive with Notion's sidebar" style="">Sidedrive</h3> <p class="description svelte-zslw0j">Google Drive with Notion's sidebar</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sidedrive.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://super.so/builder&amp;size=32" alt="The Super Builder" class="svelte-zslw0j"></span> </div> <a href="https://super.so/builder" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="The Super Builder 
A drag-and-drop landing page builder for Notion" style="">The Super Builder</h3> <p class="description svelte-zslw0j">A drag-and-drop landing page builder for Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://super.so/builder" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.makework.fun/&amp;size=32" alt="Make Work Fun" class="svelte-zslw0j"></span> </div> <a href="https://www.makework.fun/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Make Work Fun 
Gamify Notion workspaces and celebrate your personal wins" style="">Make Work Fun</h3> <p class="description svelte-zslw0j">Gamify Notion workspaces and celebrate your personal wins</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.makework.fun/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://abstractlab.gumroad.com/l/noto-avatar&amp;size=32" alt="Noto" class="svelte-zslw0j"></span> </div> <a href="https://abstractlab.gumroad.com/l/noto-avatar" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Noto 
Create a Notion-style avatar with 120+ mix-and-match items" style="">Noto</h3> <p class="description svelte-zslw0j">Create a Notion-style avatar with 120+ mix-and-match items</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://abstractlab.gumroad.com/l/noto-avatar" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://feedbacklane.com/&amp;size=32" alt="Feedback Lane" class="svelte-zslw0j"></span> </div> <a href="https://feedbacklane.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Feedback Lane 
A website feedback widget powered by Notion" style="">Feedback Lane</h3> <p class="description svelte-zslw0j">A website feedback widget powered by Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://feedbacklane.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://theproducthq.com/&amp;size=32" alt="Product HQ" class="svelte-zslw0j"></span> </div> <a href="https://theproducthq.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Product HQ 
Notion dashboard to ideate, source, and order your product" style="">Product HQ</h3> <p class="description svelte-zslw0j">Notion dashboard to ideate, source, and order your product</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://theproducthq.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://lp-builder-notion.com/?utm_source=producthunt&amp;utm_medium=social&amp;size=32" alt="Landing Page Builder for Notion" class="svelte-zslw0j"></span> </div> <a href="https://lp-builder-notion.com/?utm_source=producthunt&amp;utm_medium=social" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Landing Page Builder for Notion 
Build sexy webpages in Notion. Without design skills." style="">Landing Page Builder for Notion</h3> <p class="description svelte-zslw0j">Build sexy webpages in Notion. Without design skills.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://lp-builder-notion.com/?utm_source=producthunt&amp;utm_medium=social" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.flux-academy.com/resources/notion-freelance-hub&amp;size=32" alt="Notion Web Designer Hub" class="svelte-zslw0j"></span> </div> <a href="https://www.flux-academy.com/resources/notion-freelance-hub" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Web Designer Hub 
All-in-one hub for managing your web design projects" style="">Notion Web Designer Hub</h3> <p class="description svelte-zslw0j">All-in-one hub for managing your web design projects</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.flux-academy.com/resources/notion-freelance-hub" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://product-os-notion.com/?utm_source=producthunt&amp;utm_medium=social&amp;size=32" alt="Product OS" class="svelte-zslw0j"></span> </div> <a href="https://product-os-notion.com/?utm_source=producthunt&amp;utm_medium=social" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Product OS 
Notion workspace for product and tech teams" style="">Product OS</h3> <p class="description svelte-zslw0j">Notion workspace for product and tech teams</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://product-os-notion.com/?utm_source=producthunt&amp;utm_medium=social" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://easlo.gumroad.com/l/eGHsEB&amp;size=32" alt="Notion Journal" class="svelte-zslw0j"></span> </div> <a href="https://easlo.gumroad.com/l/eGHsEB" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Journal 
The best digital journal for life" style="">Notion Journal</h3> <p class="description svelte-zslw0j">The best digital journal for life</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://easlo.gumroad.com/l/eGHsEB" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.edition.so/&amp;size=32" alt="Edition" class="svelte-zslw0j"></span> </div> <a href="https://www.edition.so/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Edition 
No-code publishing platform with the ease of Notion" style="">Edition</h3> <p class="description svelte-zslw0j">No-code publishing platform with the ease of Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.edition.so/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thomassanlis.gumroad.com/l/CDgAIG&amp;size=32" alt="Notions Plants Manager" class="svelte-zslw0j"></span> </div> <a href="https://thomassanlis.gumroad.com/l/CDgAIG" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notions Plants Manager 
Manage your plants in Notion and never forget to water them!" style="">Notions Plants Manager</h3> <p class="description svelte-zslw0j">Manage your plants in Notion and never forget to water them!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thomassanlis.gumroad.com/l/CDgAIG" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tsolution.gumroad.com/l/design-kit&amp;size=32" alt="Design KIT" class="svelte-zslw0j"></span> </div> <a href="https://tsolution.gumroad.com/l/design-kit" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Design KIT 
Collection of interaction design patterns &amp; UI kit in Notion" style="">Design KIT</h3> <p class="description svelte-zslw0j">Collection of interaction design patterns &amp; UI kit in Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tsolution.gumroad.com/l/design-kit" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.buymeacoffee.com/bryceallen/e/36700&amp;size=32" alt="Video Game Library" class="svelte-zslw0j"></span> </div> <a href="https://www.buymeacoffee.com/bryceallen/e/36700" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Video Game Library 
Notion template to level up your video game library" style="">Video Game Library</h3> <p class="description svelte-zslw0j">Notion template to level up your video game library</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.buymeacoffee.com/bryceallen/e/36700" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.prototion.com/notion-dashboard/Notion-Library-OV4tljyybSiono8r&amp;size=32" alt="Notion Library" class="svelte-zslw0j"></span> </div> <a href="https://www.prototion.com/notion-dashboard/Notion-Library-OV4tljyybSiono8r" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Library 
Notion template to save and organize books" style="">Notion Library</h3> <p class="description svelte-zslw0j">Notion template to save and organize books</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.prototion.com/notion-dashboard/Notion-Library-OV4tljyybSiono8r" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://notionway.com/notion-templates/notion-freelancer-pack/&amp;size=32" alt="Notion Freelancer Pack" class="svelte-zslw0j"></span> </div> <a href="https://notionway.com/notion-templates/notion-freelancer-pack/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Freelancer Pack 
Manage your freelance business from one place" style="">Notion Freelancer Pack</h3> <p class="description svelte-zslw0j">Manage your freelance business from one place</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://notionway.com/notion-templates/notion-freelancer-pack/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://tsolution.gumroad.com/l/doc-kit&amp;size=32" alt="Document Kit for PM &amp; UI/UX Designer" class="svelte-zslw0j"></span> </div> <a href="https://tsolution.gumroad.com/l/doc-kit" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Document Kit for PM &amp; UI/UX Designer 
All-in-one Notion template for building products" style="">Document Kit for PM &amp; UI/UX Designer</h3> <p class="description svelte-zslw0j">All-in-one Notion template for building products</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://tsolution.gumroad.com/l/doc-kit" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://notionsites.design/&amp;size=32" alt="Notion Sites" class="svelte-zslw0j"></span> </div> <a href="https://notionsites.design/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Sites 
Notion based website templates" style="">Notion Sites</h3> <p class="description svelte-zslw0j">Notion based website templates</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://notionsites.design/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.notion.so/Notion-Portfolio-Template-de2b56977486435e8e2f77bdc93574ee&amp;size=32" alt="Notion Portfolio" class="svelte-zslw0j"></span> </div> <a href="https://www.notion.so/Notion-Portfolio-Template-de2b56977486435e8e2f77bdc93574ee" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Portfolio 
Create a professional portfolio using Notion" style="">Notion Portfolio</h3> <p class="description svelte-zslw0j">Create a professional portfolio using Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.notion.so/Notion-Portfolio-Template-de2b56977486435e8e2f77bdc93574ee" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://zampzamp.gumroad.com/l/ui_ux_checklist&amp;size=32" alt="UI &amp; UX Checklist" class="svelte-zslw0j"></span> </div> <a href="https://zampzamp.gumroad.com/l/ui_ux_checklist" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="UI &amp; UX Checklist 
Learn, practice &amp; check UI UX laws on a Notion template" style="">UI &amp; UX Checklist</h3> <p class="description svelte-zslw0j">Learn, practice &amp; check UI UX laws on a Notion template</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://zampzamp.gumroad.com/l/ui_ux_checklist" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://widgetbox.app/&amp;size=32" alt="WidgetBox" class="svelte-zslw0j"></span> </div> <a href="https://widgetbox.app/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="WidgetBox 
Customizable widgets for your Notion pages" style="">WidgetBox</h3> <p class="description svelte-zslw0j">Customizable widgets for your Notion pages</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://widgetbox.app/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://thedailyplanner.gumroad.com/l/plan-the-day&amp;size=32" alt="Daily Planner" class="svelte-zslw0j"></span> </div> <a href="https://thedailyplanner.gumroad.com/l/plan-the-day" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Daily Planner 
7 days daily planner in Notion" style="">Daily Planner</h3> <p class="description svelte-zslw0j">7 days daily planner in Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://thedailyplanner.gumroad.com/l/plan-the-day" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://jolortegui-.gumroad.com/l/HsEfS&amp;size=32" alt="Easy Freelance Workspace" class="svelte-zslw0j"></span> </div> <a href="https://jolortegui-.gumroad.com/l/HsEfS" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Easy Freelance Workspace 
Organise your freelance work and projects in Notion" style="">Easy Freelance Workspace</h3> <p class="description svelte-zslw0j">Organise your freelance work and projects in Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://jolortegui-.gumroad.com/l/HsEfS" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sidharthnegi.gumroad.com/l/worksuite&amp;size=32" alt="Worksuite Notion Template" class="svelte-zslw0j"></span> </div> <a href="https://sidharthnegi.gumroad.com/l/worksuite" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Worksuite Notion Template 
All in one ultimate worksuite notion template" style="">Worksuite Notion Template</h3> <p class="description svelte-zslw0j">All in one ultimate worksuite notion template</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sidharthnegi.gumroad.com/l/worksuite" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://vyshnav.xyz/blog/notion-icons-2-0&amp;size=32" alt="Notion Icons 2.0" class="svelte-zslw0j"></span> </div> <a href="https://vyshnav.xyz/blog/notion-icons-2-0" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Notion Icons 2.0 
Create a more vibrant and modern workspace" style="">Notion Icons 2.0</h3> <p class="description svelte-zslw0j">Create a more vibrant and modern workspace</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://vyshnav.xyz/blog/notion-icons-2-0" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://potion.so/&amp;size=32" alt="Potion" class="svelte-zslw0j"></span> </div> <a href="https://potion.so/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Potion 
Create custom websites in minutes, all on Notion" style="">Potion</h3> <p class="description svelte-zslw0j">Create custom websites in minutes, all on Notion</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://potion.so/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


job_boards_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.feedir.com/&amp;size=32" alt="Feedir" class="svelte-zslw0j"></span> </div> <a href="https://www.feedir.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Feedir 
The first ever job board for Twitter" style="">Feedir</h3> <p class="description svelte-zslw0j">The first ever job board for Twitter</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.feedir.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://gwaber.com/&amp;size=32" alt="Gwaber" class="svelte-zslw0j"></span> </div> <a href="https://gwaber.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Gwaber 
Reach 1,000,000+ remote workers, apply for remote jobs" style="">Gwaber</h3> <p class="description svelte-zslw0j">Reach 1,000,000+ remote workers, apply for remote jobs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://gwaber.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://froog.co/&amp;size=32" alt="Web3 Job Board" class="svelte-zslw0j"></span> </div> <a href="https://froog.co/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Web3 Job Board 
Find your dream job in the rapidly growing Web3 space" style="">Web3 Job Board</h3> <p class="description svelte-zslw0j">Find your dream job in the rapidly growing Web3 space</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://froog.co/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.ausjobfinder.com/&amp;size=32" alt="Job Finder" class="svelte-zslw0j"></span> </div> <a href="https://www.ausjobfinder.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Job Finder 
Searching for jobs made easy" style="">Job Finder</h3> <p class="description svelte-zslw0j">Searching for jobs made easy</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.ausjobfinder.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.shipjump.work/&amp;size=32" alt="ShipJump" class="svelte-zslw0j"></span> </div> <a href="https://www.shipjump.work/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ShipJump 
Job hunting has never been this easy" style="">ShipJump</h3> <p class="description svelte-zslw0j">Job hunting has never been this easy</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.shipjump.work/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.remotway.com/&amp;size=32" alt="Remotway" class="svelte-zslw0j"></span> </div> <a href="https://www.remotway.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Remotway 
Quickly find remote jobs" style="">Remotway</h3> <p class="description svelte-zslw0j">Quickly find remote jobs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.remotway.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.trueup.io/jobs&amp;size=32" alt="TrueUp Tech Job Marketplace" class="svelte-zslw0j"></span> </div> <a href="https://www.trueup.io/jobs" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="TrueUp Tech Job Marketplace 
360,000+ open jobs at top startups, unicorns, and big tech" style="">TrueUp Tech Job Marketplace</h3> <p class="description svelte-zslw0j">360,000+ open jobs at top startups, unicorns, and big tech</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.trueup.io/jobs" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.themetaversejobs.com/&amp;size=32" alt="Metaverse Jobs" class="svelte-zslw0j"></span> </div> <a href="https://www.themetaversejobs.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Metaverse Jobs 
Top metaverse jobs" style="">Metaverse Jobs</h3> <p class="description svelte-zslw0j">Top metaverse jobs</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.themetaversejobs.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.nftgigs.xyz/&amp;size=32" alt="NFT Gigs" class="svelte-zslw0j"></span> </div> <a href="https://www.nftgigs.xyz/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="NFT Gigs 
Find NFT jobs, gigs and collab opportunities at one place" style="">NFT Gigs</h3> <p class="description svelte-zslw0j">Find NFT jobs, gigs and collab opportunities at one place</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.nftgigs.xyz/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://rocketcrew.space/&amp;size=32" alt="Rocket Crew" class="svelte-zslw0j"></span> </div> <a href="https://rocketcrew.space/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Rocket Crew 
A simple way to find space related jobs." style="">Rocket Crew</h3> <p class="description svelte-zslw0j">A simple way to find space related jobs.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://rocketcrew.space/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://remotelypro.com&amp;size=32" alt="RemotelyPro" class="svelte-zslw0j"></span> </div> <a href="https://remotelypro.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="RemotelyPro 
Remote part-time jobs for people seeking flexibility" style="">RemotelyPro</h3> <p class="description svelte-zslw0j">Remote part-time jobs for people seeking flexibility</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://remotelypro.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://threej.in/twitter-jobs&amp;size=32" alt="Twitter Job Board" class="svelte-zslw0j"></span> </div> <a href="https://threej.in/twitter-jobs" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Twitter Job Board 
We make Twitter job search easy" style="">Twitter Job Board</h3> <p class="description svelte-zslw0j">We make Twitter job search easy</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://threej.in/twitter-jobs" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://smoothremote.com&amp;size=32" alt="Smooth Remote" class="svelte-zslw0j"></span> </div> <a href="https://smoothremote.com" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Smooth Remote 
The smoothest remote job board" style="">Smooth Remote</h3> <p class="description svelte-zslw0j">The smoothest remote job board</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://smoothremote.com" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://caus.co&amp;size=32" alt="Caus" class="svelte-zslw0j"></span> </div> <a href="https://caus.co" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Caus 
The climate job board" style="">Caus</h3> <p class="description svelte-zslw0j">The climate job board</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://caus.co" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://goodjob.leapers.co&amp;size=32" alt="good job" class="svelte-zslw0j"></span> </div> <a href="https://goodjob.leapers.co" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="good job 
find and support great freelancers" style="">good job</h3> <p class="description svelte-zslw0j">find and support great freelancers</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://goodjob.leapers.co" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''


handoff_html_content =''' 
<ul class="rs-list svelte-4h59nz">   <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://github.com/utom/sketch-measure&amp;size=32" alt="Sketch Measure" class="svelte-zslw0j"></span> </div> <a href="https://github.com/utom/sketch-measure" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sketch Measure 
Open source design handoff tool." style="">Sketch Measure</h3> <p class="description svelte-zslw0j">Open source design handoff tool.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://github.com/utom/sketch-measure" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://sympli.io/&amp;size=32" alt="Sympli" class="svelte-zslw0j"></span> </div> <a href="https://sympli.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Sympli 
Enterprise-grade, integrated collaboration and workflow platform for building digital products." style="">Sympli</h3> <p class="description svelte-zslw0j">Enterprise-grade, integrated collaboration and workflow platform for building digital products.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://sympli.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.yotako.io/&amp;size=32" alt="Yotako" class="svelte-zslw0j"></span> </div> <a href="https://www.yotako.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Yotako 
Your tool to translate design into code." style="">Yotako</h3> <p class="description svelte-zslw0j">Your tool to translate design into code.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.yotako.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://uizard.io/&amp;size=32" alt="Uizard" class="svelte-zslw0j"></span> </div> <a href="https://uizard.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Uizard 
Transform your hand-drawn wireframes into digital design files and front-end code – automatically!" style="">Uizard</h3> <p class="description svelte-zslw0j">Transform your hand-drawn wireframes into digital design files and front-end code – automatically!</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://uizard.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://zeroheight.com/landing&amp;size=32" alt="ZeroHeight" class="svelte-zslw0j"></span> </div> <a href="https://zeroheight.com/landing" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="ZeroHeight 
Document your design system, together. Styleguides created by designers, extended by developers, and editable by everyone." style="">ZeroHeight</h3> <p class="description svelte-zslw0j">Document your design system, together. Styleguides created by designers, extended by developers, and editable by everyone.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://zeroheight.com/landing" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://specctr.com/cloud/home&amp;size=32" alt="Specctr" class="svelte-zslw0j"></span> </div> <a href="https://specctr.com/cloud/home" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Specctr 
Simplify your design to dev production with Specctr's new panel and new automated annotation features." style="">Specctr</h3> <p class="description svelte-zslw0j">Simplify your design to dev production with Specctr's new panel and new automated annotation features.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://specctr.com/cloud/home" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://avocode.com/&amp;size=32" alt="Avocode" class="svelte-zslw0j"></span> </div> <a href="https://avocode.com/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Avocode 
Cross-platform design hand-off tool for design collaboration, version control, and inspecting of Sketch, XD, Photoshop, and Figma design files, on Windows, Linux, or macOS." style="">Avocode</h3> <p class="description svelte-zslw0j">Cross-platform design hand-off tool for design collaboration, version control, and inspecting of Sketch, XD, Photoshop, and Figma design files, on Windows, Linux, or macOS.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://avocode.com/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://zeplin.io/&amp;size=32" alt="Zeplin" class="svelte-zslw0j"></span> </div> <a href="https://zeplin.io/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Zeplin 
Handoff designs and styleguides with accurate specs, assets, code snippets—automatically." style="">Zeplin</h3> <p class="description svelte-zslw0j">Handoff designs and styleguides with accurate specs, assets, code snippets—automatically.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://zeplin.io/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.invisionapp.com/feature/inspect/&amp;size=32" alt="Inspect" class="svelte-zslw0j"></span> </div> <a href="https://www.invisionapp.com/feature/inspect/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Inspect 
Better design and development collaboration" style="">Inspect</h3> <p class="description svelte-zslw0j">Better design and development collaboration</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.invisionapp.com/feature/inspect/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://mockingbot.com/inspect/&amp;size=32" alt="MockingBot" class="svelte-zslw0j"></span> </div> <a href="https://mockingbot.com/inspect/" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="MockingBot 
Free designers’ hands, meet developers’ needs. All from one click." style="">MockingBot</h3> <p class="description svelte-zslw0j">Free designers’ hands, meet developers’ needs. All from one click.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://mockingbot.com/inspect/" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> <li class="rsli svelte-zslw0j" role="button"><div class="tooltip-container svelte-5gkk8k"><span class="rsli-image svelte-zslw0j" style=""><img src="https://t1.gstatic.com/faviconV2?client=SOCIAL&amp;type=FAVICON&amp;fallback_opts=TYPE,SIZE,URL&amp;url=https://www.uxpin.com/merge&amp;size=32" alt="Merge by UXPin" class="svelte-zslw0j"></span> </div> <a href="https://www.uxpin.com/merge" target="_blank" rel="noopener noreferrer" class="rsli-item svelte-zslw0j"><h3 class="rsli-title svelte-zslw0j" title="Merge by UXPin 
UXPin Merge allows you to design with React components to achieve full consistency with the final product." style="">Merge by UXPin</h3> <p class="description svelte-zslw0j">UXPin Merge allows you to design with React components to achieve full consistency with the final product.</p></a> <div class="action-buttons svelte-zslw0j"><div class="sprite svelte-zslw0j"><button class="animation-button bookmark-animated svelte-1pwj9e8" style="width: 42px;height: 42px;"><span class="ab-inner svelte-1pwj9e8" style="width: 42px;height: 42px;margin: -0px;background-image: url(/img/sprite.png);background-size: 2900%;animation-duration: 0.3s;animation-timing-function: steps(28);"></span> <div class="svg-wrapper svelte-1csblc5" style=""><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg">
<path style="fill: var(--svg-fill, #000000);" d="M8.00001 3.49999L7.70002 3.9L8.00002 4.12499L8.30001 3.89999L8.00001 3.49999ZM7.05359 13.3966L6.76597 13.8056L7.05359 13.3966ZM8.94644 13.3966L8.65882 12.9876L8.94644 13.3966ZM8.00001 3.49999C8.30001 3.09999 8.29984 3.09986 8.29965 3.09972C8.29957 3.09966 8.29937 3.09951 8.2992 3.09939C8.29887 3.09914 8.29848 3.09884 8.29802 3.0985C8.29711 3.09783 8.29596 3.09697 8.29456 3.09593C8.29176 3.09386 8.288 3.09109 8.28328 3.08765C8.27386 3.08077 8.26063 3.07121 8.2438 3.05928C8.21014 3.03541 8.16196 3.00198 8.10075 2.96135C7.97848 2.88019 7.80336 2.76975 7.5873 2.64925C7.15804 2.40986 6.55329 2.12293 5.87129 1.95244C5.19057 1.78226 4.40216 1.72057 3.62827 1.96931C2.84126 2.22228 2.12137 2.77987 1.5659 3.75194L2.43414 4.24808C2.87868 3.47016 3.4088 3.09025 3.93428 2.92134C4.47289 2.74822 5.05948 2.78026 5.62876 2.92258C6.19676 3.06458 6.717 3.30889 7.10024 3.52262C7.29042 3.62868 7.44343 3.72528 7.54772 3.7945C7.59979 3.82907 7.6395 3.85667 7.66541 3.87504C7.67836 3.88422 7.68784 3.89108 7.69368 3.89534C7.69659 3.89747 7.69859 3.89894 7.69966 3.89973C7.70019 3.90013 7.70049 3.90035 7.70055 3.90039C7.70058 3.90042 7.70055 3.90039 7.70046 3.90033C7.70042 3.9003 7.70031 3.90021 7.70028 3.9002C7.70016 3.9001 7.70002 3.9 8.00001 3.49999ZM1.5659 3.75194C0.526087 5.57159 1.23202 7.65711 2.39574 9.41002C3.57618 11.1881 5.33479 12.7991 6.76597 13.8056L7.34121 12.9876C5.98403 12.0332 4.32403 10.5066 3.22886 8.85693C2.11698 7.1821 1.69031 5.54977 2.43414 4.24808L1.5659 3.75194ZM8.00001 3.49999C8.30001 3.89999 8.29987 3.9001 8.29975 3.9002C8.29972 3.90021 8.29961 3.9003 8.29957 3.90033C8.29948 3.90039 8.29945 3.90042 8.29948 3.90039C8.29954 3.90035 8.29984 3.90013 8.30037 3.89973C8.30144 3.89894 8.30344 3.89747 8.30635 3.89534C8.31219 3.89108 8.32167 3.88422 8.33462 3.87504C8.36053 3.85667 8.40024 3.82907 8.45232 3.7945C8.55661 3.72528 8.70961 3.62868 8.8998 3.52262C9.28303 3.30889 9.80328 3.06457 10.3713 2.92258C10.9406 2.78026 11.5271 2.74821 12.0658 2.92133C12.5912 3.09024 13.1214 3.47014 13.5659 4.24807L14.4341 3.75192C13.8787 2.77986 13.1588 2.22227 12.3718 1.9693C11.5979 1.72055 10.8095 1.78225 10.1287 1.95243C9.44675 2.12293 8.84199 2.40986 8.41273 2.64925C8.19667 2.76975 8.02155 2.88018 7.89928 2.96135C7.83807 3.00198 7.78989 3.03541 7.75623 3.05928C7.7394 3.07121 7.72617 3.08077 7.71675 3.08765C7.71203 3.09109 7.70827 3.09387 7.70547 3.09593C7.70407 3.09697 7.70292 3.09783 7.70201 3.09851C7.70155 3.09884 7.70116 3.09914 7.70083 3.09939C7.70066 3.09951 7.70046 3.09966 7.70038 3.09972C7.70019 3.09986 7.70002 3.09999 8.00001 3.49999ZM13.5659 4.24807C14.3097 5.54975 13.8831 7.18209 12.7712 8.85693C11.676 10.5066 10.016 12.0332 8.65882 12.9876L9.23406 13.8056C10.6652 12.7991 12.4239 11.1881 13.6043 9.41002C14.768 7.6571 15.474 5.57158 14.4341 3.75192L13.5659 4.24807ZM6.76597 13.8056C7.50991 14.3288 8.49012 14.3288 9.23406 13.8056L8.65882 12.9876C8.25998 13.2681 7.74005 13.2681 7.34121 12.9876L6.76597 13.8056Z"></path>
</svg>
</div></button></div> <a class="new-tab svelte-zslw0j" href="https://www.uxpin.com/merge" target="_blank" rel="noopener noreferrer"><div class="svg-wrapper svelte-1csblc5" style="--svg-width: 16px;--svg-height: 16px;"><svg width="12" height="12" viewBox="0 0 12 12" fill="none" xmlns="http://www.w3.org/2000/svg">
<path d="M4.875 2.625H2.625C2.00368 2.625 1.5 3.12868 1.5 3.75V9.375C1.5 9.99634 2.00368 10.5 2.625 10.5H8.25C8.87134 10.5 9.375 9.99634 9.375 9.375V7.125M7.125 1.5H10.5M10.5 1.5V4.875M10.5 1.5L4.875 7.125" stroke-linecap="round" stroke-linejoin="round" style="stroke:var(--svg-stroke, #F7F7F8)"></path>
</svg>
</div></a></div>  </li> </ul>
'''

# %%
from bs4 import BeautifulSoup


def transform_string(s):
    # Split the string by underscores
    parts = s.split("_")
    # Capitalize the first letter of each part
    capitalized_parts = [part.capitalize() for part in parts]
    # Join the parts with a space
    return " ".join(capitalized_parts)


# List of HTML contents and their corresponding categories
htmls = [
    ("stock_photos", stock_photos_html_content),
    ("stock_videos", stock_video_html_content),
    ("icons", icons_html_content),
    ("icon_finder", icon_finder_html_content),
    ("color_tools",color_tools_html_content),
    ("illustrations", illustrations_html_content),
    ("figma",figma_tools_html_content),
    ("typography",typography_html_content),
    ("font_tools", font_tools_html_content),
    ("gradient_tools", gradient_tools_html_content),
    ("image_tools", image_tools_html_content),
    ("builder", builder_html_content),
    ("collaboration_tools", collaboration_tools_html_content),
    ("design_systems", design_systems_html_content),
    ("designer_podcasts", designer_podcasts_html_content),
    ("ux_research", ux_research_html_content),
    ("productivity", productivity_html_content),
    ("inspiration", inspiration_html_content),
    ("instagram_tools", instagram_tools_html_content),
    ("logo_tools", logo_tools_html_content),
    ("mockup_tools", mockup_tools_html_content),
    ("placeholder_texts", placeholder_texts_html_content),
    ("prototyping", prototyping_html_content),
    ("wireframe_tools", wireframe_tools_html_content),
    ("animation_tools", animation_tools_html_content),
    ("social_media_tools", social_media_tools_html_content),
    ("sound_and_audio", sound_and_audio_html_content),
    ("user_flow", user_flow_html_content),
    ("design_tools", design_tools_html_content),
    ("notion_tools", notion_tools_html_content),
    ("generators", generators_html_content),
    ("job_boards", job_boards_html_content),
    ("handoff", handoff_html_content),
]

popular_links = {}

for category, html_content in htmls:
    # Parse the HTML
    soup = BeautifulSoup(html_content, "html.parser")

    # Find all 'a' tags with the class 'rsli-item'
    a_tags = soup.find_all("a", class_="rsli-item")

    # Create an array of dictionaries
    temp_results = []
    for a_tag in a_tags:
        title_tag = a_tag.find("h3", class_="rsli-title")
        description = title_tag.get("title", "") if title_tag else ""
        name = title_tag.text.strip() if title_tag else ""
        url = a_tag.get("href", "")
        temp_results.append(
            {
                "id": len(temp_results) + 1,
                "name": name,
                "url": url,
                "description": description,
                "tags": [transform_string(category)],
                "categories": f"/{transform_string(category)}",
            }
        )

    # Assign the results to the category in the popular_links dictionary
    popular_links[category] = temp_results

# popular_links now contains parsed results for each category
output_file = "constants/popularslinks.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(popular_links, f, ensure_ascii=False, indent=2)
print(f"Popular Links saved to {popular_links}")
print(f"Number of Popular Links: {len(popular_links)}")
# Out:
# Popular Links saved to {'stock_photos': [{'id': 1, 'name': 'Envato', 'url': 'https://elements.envato.com/', 'description': 'Envato \nEnvato Elements: Unlimited Stock Videos, Music, Photos & Graphics', 'tags': ['Stock Photos'], 'categories': '/Stock Photos'}, {'id': 2, 'name': 'Shutterstock', 'url': 'https://www.shutterstock.com/', 'description': '', 'tags': ['Stock Photos'], 'categories': '/Stock Photos'}, {'id': 3, 'name': 'Pixabay', 'url': 'https://pixabay.com', 'description': 'Pixabay \nPixabay is a vibrant community of creatives, sharing copyright free images, videos and music.', 'tags': ['Stock Photos'], 'categories': '/Stock Photos'}, {'id': 4, 'name': 'Free Range', 'url': 'https://freerangestock.com/', 'description': 'Free Range \nFree Stock Photos, totally Free Commercial Photography and Textures.', 'tags': ['Stock Photos'], 'categories': '/Stock Photos'}, {'id': 5, 'name': 'Little Visuals', 'url': 'https://littlevisuals.co/', 'description': 'Little Visuals \nHi-res images, u
# ...
